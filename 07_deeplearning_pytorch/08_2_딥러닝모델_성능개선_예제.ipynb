# %% [markdown]
# # 성능개선 기법 실습

# %% [markdown]
# # 모듈 정의

# %% [markdown]
# ## train.py
#
# -   모델 학습과 검증 함수 정의

# %%
import os

os.makedirs("module", exist_ok=True)

# %%
# %%writefile module/train.py

import torch
import time

def test_multi_classification(dataloader, model, loss_fn, device="cpu") -> tuple:
    """
    다중 분류 검증/평가 함수
    
    Args:
        dataloader: DataLoader - 검증할 대상 데이터로더
        model: 검증할 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
    Returns:
        tuple: (loss, accuracy)
    """
    model.to(device)
    model.eval() 
    size = len(dataloader.dataset)
    num_steps = len(dataloader)
    
    test_loss, test_accuracy = 0., 0.
    
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            # 정확도 계산
            pred_label = torch.argmax(pred, axis=-1)
            test_accuracy += torch.sum(pred_label == y).item()
            # 이진분류와 다중 분류의 차이 → pred_label, test_accuracy
            
        test_loss /= num_steps
        test_accuracy /= size
    return test_loss, test_accuracy

def test_binary_classification(dataloader, model, loss_fn, device="cpu") -> tuple:
    """
    이진 분류 검증/평가 함수
    
    Args:
        dataloader: DataLoader - 검증할 대상 데이터로더
        model: 검증할 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
    Returns:
        tuple: (loss, accuracy)
    """
    model.to(device)
    model.eval() # 모델을 평가모드로 변환
    size = len(dataloader.dataset) # 총 데이터 개수 
    num_steps = len(dataloader)
    
    test_loss, test_accuracy = 0., 0.
    
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            ## 정확도 계산
            pred_label = (pred >= 0.5).type(torch.int32)
            test_accuracy += (pred_label == y).sum().item() 
            
        test_loss /= num_steps
        test_accuracy /= size   #전체 개수로 나눈다.
    return test_loss, test_accuracy    

def train(dataloader, model, loss_fn, optimizer, device="cpu", mode:"binary or multi"='binary'):
    """
    모델을 1 epoch 학습시키는 함수

    Args:
        dataloader: DataLoader - 학습데이터셋을 제공하는 DataLoader
        model - 학습대상 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        optimizer - 최적화 함수
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
        mode: str - 분류 종류. binary 또는 multi
    
    Returns:
        tuple: 학습후 계산한 Train set에 대한  train_loss, train_accuracy
    """
    model.train()

    for X, y in dataloader:
        X, y = X.to(device), y.to(device)
        pred = model(X)

        loss = loss_fn(pred, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    if mode == 'binary':
        train_loss, train_accuracy = test_binary_classification(dataloader, model, loss_fn, device)
    else:
        train_loss, train_accuracy = test_multi_classification(dataloader, model, loss_fn, device)
    return train_loss, train_accuracy



def fit(train_loader, val_loader, model, loss_fn, optimizer, epochs, save_best_model=True, 
        save_model_path=None, early_stopping=True, patience=10, device='cpu',  mode:"binary or multi"='binary',
        lr_scheduler=None):
    """
    모델을 학습시키는 함수

    Args:
        train_loader (Dataloader): Train dataloader
        test_loader (Dataloader): validation dataloader
        model (Module): 학습시킬 모델
        loss_fn (_Loss): Loss function
        optimizer (Optimizer): Optimizer
        epochs (int): epoch수
        save_best_model (bool, optional): 학습도중 성능개선시 모델 저장 여부. Defaults to True.
        save_model_path (str, optional): save_best_model=True일 때 모델저장할 파일 경로. Defaults to None.
        early_stopping (bool, optional): 조기 종료 여부. Defaults to True.
        patience (int, optional): 조기종료 True일 때 종료전에 성능이 개선될지 몇 epoch까지 기다릴지 epoch수. Defaults to 10.
        device (str, optional): device. Defaults to 'cpu'.
        mode(str, optinal): 분류 종류. "binary(default) or multi
        lr_scheduler: Learning Rate Scheduler 객체. default: None, Epoch 단위로 LR 를 변경.
    
    Returns:
        tuple: 에폭 별 성능 리스트. (train_loss_list, train_accuracy_list, validation_loss_list, validataion_accuracy_list)
    """

    train_loss_list = []
    train_accuracy_list = []
    val_loss_list = []
    val_accuracy_list = []
    
        
    if save_best_model:
        best_score_save = torch.inf

    ############################
    # early stopping
    #############################
    if early_stopping:
        trigger_count = 0
        best_score_es = torch.inf
    
    # 모델 device로 옮기기
    model = model.to(device)
    s = time.time()
    for epoch in range(epochs):
        # train 모드
        train_loss, train_accuracy = train(train_loader, model, loss_fn, optimizer, device=device, mode=mode)
        ############ 1 epoch 학습 종료 -> LR 를 변경 ###########
        if lr_scheduler is not None:
            current_lr = lr_scheduler.get_last_lr()[0]  # log용
            lr_scheduler.step()
            new_lr = lr_scheduler.get_last_lr()[0] # log용
            if current_lr != new_lr: # LR가 변경되었으면
                print(f">>>>>>Learning Rate가 {current_lr}에서 {new_lr}로 변경됨<<<<<<")

        # 검증
        if mode == "binary":
            val_loss, val_accuracy = test_binary_classification(val_loader, model, loss_fn, device=device)
        else:
            val_loss, val_accuracy = test_multi_classification(val_loader, model, loss_fn, device=device)

        train_loss_list.append(train_loss)
        train_accuracy_list.append(train_accuracy)
        val_loss_list.append(val_loss)
        val_accuracy_list.append(val_accuracy)
        
        print(f"Epoch[{epoch+1}/{epochs}] - Train loss: {train_loss:.5f} Train Accucracy: {train_accuracy:.5f} || Validation Loss: {val_loss:.5f} Validation Accuracy: {val_accuracy:.5f}")
        print('='*100)
        
        # 모델 저장
        if save_best_model:
            if val_loss < best_score_save:
                torch.save(model, save_model_path)
                print(f"저장: {epoch+1} - 이전 : {best_score_save}, 현재: {val_loss}")
                best_score_save = val_loss
        
        # early stopping 처리            
        if early_stopping:
            # early_stopping 기능을 사용하겠냐는 if문임.
            # → early_stopping=False 이면 안쪽에 있는 코드 전체를 그냥 건너뜀.
            if val_loss < best_score_es: 
                best_score_es = val_loss  
                trigger_count = 0
                                
            else:
                trigger_count += 1                
                if patience == trigger_count:
                    print(f"Early stopping: Epoch - {epoch}")
                    break
            
    e = time.time()
    print(e-s, "초")
    return train_loss_list, train_accuracy_list, val_loss_list, val_accuracy_list
# Out:
# Overwriting module/train.py

# %% [markdown]
# ## data.py
#
# -   dataset 생성 함수 제공 모듈

# %%
# %%writefile module/data.py

from torchvision import datasets, transforms
from torch.utils.data import DataLoader

def load_mnist_dataset(root_path, batch_size, is_train=True):
    """
    mnist dataset dataloader 제공 함수
    Args:
        root_path: str|Path - 데이터파일 저장 디렉토리
        batch_size: int
        is_train: bool = True - True: Train dataset, False - Test dataset
    
    Returns:
        DataLoader 
    """
    transform = transforms.Compose([
        transforms.ToTensor()
    ])
    dataset = datasets.MNIST(root=root_path, train=is_train, download=True, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=is_train, drop_last=is_train)  # shuffle: train이면 True, test면 False 할 것이므로 is_train을 넣음.
    
    return dataloader

def load_fashion_mnist_dataset(root_path, batch_size, is_train=True):
    """
    fashion mnist dataset dataloader 제공 함수
    Args:
        root_path: str|Path - 데이터파일 저장 디렉토리
        batch_size: int
        is_train: bool = True - True: Train dataset, False - Test dataset
    
    Returns:
        DataLoader
    """
    transform = transforms.Compose([
        transforms.ToTensor()
    ])
    dataset = datasets.FashionMNIST(root=root_path, train=is_train, download=True, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=is_train, drop_last=is_train)  # shuffle: train이면 True, test면 False 할 것이므로 is_train을 넣음.
    
    return dataloader
# Out:
# Overwriting module/data.py

# %% [markdown]
# ## utils.py

# %%
# %%writefile module/utils.py
# 학습 결과를 시각화하는 함수.
import matplotlib.pyplot as plt

def plot_fit_result(train_loss_list, train_accuracy_list, valid_loss_list, valid_accuracy_list):
    """epoch별 학습 결과를 시각화하는 함수
    epoch별 loss와 accuracy를 시각화한다.

    Args:
        train_loss_list (list): Epoch별 train loss
        train_accuracy_list (list): Epoch별 train accuracy
        valid_loss_list (list): Epoch별 validation loss
        valid_accuracy_list (list): Epoch별 validation accuracy
    """
    epoch = len(train_loss_list)
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(range(epoch), train_loss_list, label="train loss")
    plt.plot(range(epoch), valid_loss_list, label="validation loss")
    plt.title("Loss")
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.grid(True, linestyle=':')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(range(epoch), train_accuracy_list, label="train accuracy")
    plt.plot(range(epoch), valid_accuracy_list, label="validation accuracy")
    plt.title("Accuracy")
    plt.xlabel("epoch")
    plt.ylabel("accuracy")
    plt.grid(True, linestyle=':')
    plt.legend()

    plt.tight_layout()
    plt.show()
# Out:
# Overwriting module/utils.py

# %% [markdown]
# ## Import

# %%
import torch
import torch.nn as nn
from torchinfo import summary

from module.train import fit
from module.data import load_mnist_dataset, load_fashion_mnist_dataset
from module.utils import plot_fit_result

# %% [markdown]
# ## 하이퍼파라미터, 변수 정의

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
root_data_path = "datasets"

epochs = 100
batch_size = 256
lr = 0.001

# %% [markdown]
# # Data 준비
#
# ## mnist 데이터 로딩

# %%
train_loader = load_mnist_dataset(root_data_path, batch_size)
test_loader = load_mnist_dataset(root_data_path, batch_size, False)

## Fashion Mnist
# train_loader = load_fashion_mnist_dataset(root_data_path, batch_size)
# test_loader = load_fashion_mnist_dataset(root_data_path, batch_size, False)

# %%
len(train_loader.dataset)
# Out:
# 60000

# %%
classes = train_loader.dataset.classes
class_to_idx = train_loader.dataset.class_to_idx

# %%
class_to_idx
# Out:
# {'0 - zero': 0,
#  '1 - one': 1,
#  '2 - two': 2,
#  '3 - three': 3,
#  '4 - four': 4,
#  '5 - five': 5,
#  '6 - six': 6,
#  '7 - seven': 7,
#  '8 - eight': 8,
#  '9 - nine': 9}

# %% [markdown]
# # 모델의 크기 변경에 따른 성능변화
# ## 작은 모델

# %%
class SmallModel(nn.Module):

    def __init__(self):
        super().__init__()
        self.lr1 = nn.Linear(784,16)
        self.lr2 = nn.Linear(16,10)
        self.relu = nn.ReLU()

    def forward(self,X) :
        out = nn.Flatten()(X) #(N, 1, 28, 28) → (N, 1*28*28)
        out = self.relu(self.lr1(out))
        out = self.lr2(out)
        return out

# %%
summary(SmallModel(),(100,1,28,28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# SmallModel                               [100, 10]                 --
# ├─Linear: 1-1                            [100, 16]                 12,560
# ├─ReLU: 1-2                              [100, 16]                 --
# ├─Linear: 1-3                            [100, 10]                 170
# ==========================================================================================
# Total params: 12,730
# Trainable params: 12,730
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 1.27
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 0.02
# Params size (MB): 0.05
# Estimated Total Size (MB): 0.39
# ==========================================================================================

# %%
small_model = SmallModel()
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(small_model.parameters(), lr=lr)

# %%
result = fit(train_loader, test_loader, small_model, loss_fn, optimizer, epochs, save_best_model=False, device=device, mode="multi")
# Out:
# Epoch[1/100] - Train loss: 0.42009 Train Accucracy: 0.88583 || Validation Loss: 0.40190 Validation Accuracy: 0.89300
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.31512 Train Accucracy: 0.91075 || Validation Loss: 0.30249 Validation Accuracy: 0.91460
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.28273 Train Accucracy: 0.91830 || Validation Loss: 0.27455 Validation Accuracy: 0.92250
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.25803 Train Accucracy: 0.92485 || Validation Loss: 0.25295 Validation Accuracy: 0.92610
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.24280 Train Accucracy: 0.92945 || Validation Loss: 0.24240 Validation Accuracy: 0.92910
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.22796 Train Accucracy: 0.93437 || Validation Loss: 0.23049 Validation Accuracy: 0.93160
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.21602 Train Accucracy: 0.93775 || Validation Loss: 0.21899 Validation Accuracy: 0.93430
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.20876 Train Accucracy: 0.94007 || Validation Loss: 0.21451 Validation Accuracy: 0.93490
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.19654 Train Accucracy: 0.94298 || Validation Loss: 0.20404 Validation Accuracy: 0.94050
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.18842 Train Accucracy: 0.94477 || Validation Loss: 0.19857 Validation Accuracy: 0.94160
# ====================================================================================================
# Epoch[11/100] - Train loss: 0.18353 Train Accucracy: 0.94560 || Validation Loss: 0.19576 Validation Accuracy: 0.94210
# ====================================================================================================
# Epoch[12/100] - Train loss: 0.17536 Train Accucracy: 0.94833 || Validation Loss: 0.18905 Validation Accuracy: 0.94480
# ====================================================================================================
# Epoch[13/100] - Train loss: 0.17097 Train Accucracy: 0.94967 || Validation Loss: 0.18558 Validation Accuracy: 0.94550
# ====================================================================================================
# Epoch[14/100] - Train loss: 0.16416 Train Accucracy: 0.95197 || Validation Loss: 0.18135 Validation Accuracy: 0.94690
# ====================================================================================================
# Epoch[15/100] - Train loss: 0.16258 Train Accucracy: 0.95128 || Validation Loss: 0.18104 Validation Accuracy: 0.94520
# ====================================================================================================
# Epoch[16/100] - Train loss: 0.15625 Train Accucracy: 0.95322 || Validation Loss: 0.17643 Validation Accuracy: 0.94910
# ====================================================================================================
# Epoch[17/100] - Train loss: 0.15111 Train Accucracy: 0.95480 || Validation Loss: 0.17307 Validation Accuracy: 0.94810
# ====================================================================================================
# Epoch[18/100] - Train loss: 0.14848 Train Accucracy: 0.95545 || Validation Loss: 0.17123 Validation Accuracy: 0.94890
# ====================================================================================================
# Epoch[19/100] - Train loss: 0.14519 Train Accucracy: 0.95623 || Validation Loss: 0.17268 Validation Accuracy: 0.94910
# ====================================================================================================
# Epoch[20/100] - Train loss: 0.14131 Train Accucracy: 0.95753 || Validation Loss: 0.16911 Validation Accuracy: 0.94920
# ====================================================================================================
# Epoch[21/100] - Train loss: 0.13946 Train Accucracy: 0.95827 || Validation Loss: 0.16833 Validation Accuracy: 0.94950
# ====================================================================================================
# Epoch[22/100] - Train loss: 0.13732 Train Accucracy: 0.95783 || Validation Loss: 0.16817 Validation Accuracy: 0.94930
# ====================================================================================================
# Epoch[23/100] - Train loss: 0.13579 Train Accucracy: 0.95883 || Validation Loss: 0.16594 Validation Accuracy: 0.95050
# ====================================================================================================
# Epoch[24/100] - Train loss: 0.13106 Train Accucracy: 0.96023 || Validation Loss: 0.16451 Validation Accuracy: 0.95180
# ====================================================================================================
# Epoch[25/100] - Train loss: 0.13154 Train Accucracy: 0.96033 || Validation Loss: 0.16684 Validation Accuracy: 0.94990
# ====================================================================================================
# Epoch[26/100] - Train loss: 0.12850 Train Accucracy: 0.96142 || Validation Loss: 0.16425 Validation Accuracy: 0.95210
# ====================================================================================================
# Epoch[27/100] - Train loss: 0.12657 Train Accucracy: 0.96132 || Validation Loss: 0.16563 Validation Accuracy: 0.95090
# ====================================================================================================
# Epoch[28/100] - Train loss: 0.12550 Train Accucracy: 0.96168 || Validation Loss: 0.16368 Validation Accuracy: 0.95230
# ====================================================================================================
# Epoch[29/100] - Train loss: 0.12364 Train Accucracy: 0.96268 || Validation Loss: 0.16330 Validation Accuracy: 0.95170
# ====================================================================================================
# Epoch[30/100] - Train loss: 0.12253 Train Accucracy: 0.96227 || Validation Loss: 0.16361 Validation Accuracy: 0.95150
# ====================================================================================================
# Epoch[31/100] - Train loss: 0.12107 Train Accucracy: 0.96280 || Validation Loss: 0.16101 Validation Accuracy: 0.95350
# ====================================================================================================
# Epoch[32/100] - Train loss: 0.11962 Train Accucracy: 0.96338 || Validation Loss: 0.16129 Validation Accuracy: 0.95350
# ====================================================================================================
# Epoch[33/100] - Train loss: 0.11719 Train Accucracy: 0.96343 || Validation Loss: 0.16172 Validation Accuracy: 0.95350
# ====================================================================================================
# Epoch[34/100] - Train loss: 0.11524 Train Accucracy: 0.96468 || Validation Loss: 0.15903 Validation Accuracy: 0.95400
# ====================================================================================================
# Epoch[35/100] - Train loss: 0.11482 Train Accucracy: 0.96523 || Validation Loss: 0.16163 Validation Accuracy: 0.95290
# ====================================================================================================
# Epoch[36/100] - Train loss: 0.11580 Train Accucracy: 0.96430 || Validation Loss: 0.16525 Validation Accuracy: 0.95160
# ====================================================================================================
# Epoch[37/100] - Train loss: 0.11296 Train Accucracy: 0.96505 || Validation Loss: 0.16192 Validation Accuracy: 0.95290
# ====================================================================================================
# Epoch[38/100] - Train loss: 0.11281 Train Accucracy: 0.96518 || Validation Loss: 0.16139 Validation Accuracy: 0.95370
# ====================================================================================================
# Epoch[39/100] - Train loss: 0.11014 Train Accucracy: 0.96633 || Validation Loss: 0.15960 Validation Accuracy: 0.95410
# ====================================================================================================
# Epoch[40/100] - Train loss: 0.11064 Train Accucracy: 0.96585 || Validation Loss: 0.16166 Validation Accuracy: 0.95320
# ====================================================================================================
# Epoch[41/100] - Train loss: 0.10881 Train Accucracy: 0.96662 || Validation Loss: 0.15952 Validation Accuracy: 0.95310
# ====================================================================================================
# Epoch[42/100] - Train loss: 0.10771 Train Accucracy: 0.96608 || Validation Loss: 0.15945 Validation Accuracy: 0.95370
# ====================================================================================================
# Epoch[43/100] - Train loss: 0.10722 Train Accucracy: 0.96715 || Validation Loss: 0.15999 Validation Accuracy: 0.95300
# ====================================================================================================
# Epoch[44/100] - Train loss: 0.10701 Train Accucracy: 0.96643 || Validation Loss: 0.16185 Validation Accuracy: 0.95350
# ====================================================================================================
# Early stopping: Epoch - 43
# 307.74885749816895 초

# %% [markdown]
# 모델이 작아서 학습도 천천히 하면서, 학습도 끝(100번)까지 되지않고 있음.

# %%
plot_fit_result(result[0],result[1],result[2],result[3])

# %% [markdown]
# ## 큰모델

# %%
class BigModel(nn.Module):

    def __init__(self):
        super().__init__()
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(784,2048), nn.ReLU())
        # ()안에 있는 내용이 순서대로 진행되게해줌 = Sequential
        self.b2 = nn.Sequential(nn.Linear(2048,1024), nn.ReLU())
        self.b3 = nn.Sequential(nn.Linear(1024,512), nn.ReLU())
        self.b4 = nn.Sequential(nn.Linear(512,256), nn.ReLU())
        self.b5 = nn.Sequential(nn.Linear(256,128), nn.ReLU())
        self.b6 = nn.Sequential(nn.Linear(128,64), nn.ReLU())
        self.b7 = nn.Sequential(nn.Linear(64,32), nn.ReLU())
        self.out_layer = nn.Linear(32,10)

    def forward(self,X):
        out = self.b1(X)
        out = self.b2(out)
        out = self.b3(out)
        out = self.b4(out)
        out = self.b5(out)
        out = self.b6(out)
        out = self.b7(out)
        out = self.out_layer(out)
        return out

# %%
summary(BigModel(), (100,1,28,28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# BigModel                                 [100, 10]                 --
# ├─Sequential: 1-1                        [100, 2048]               --
# │    └─Flatten: 2-1                      [100, 784]                --
# │    └─Linear: 2-2                       [100, 2048]               1,607,680
# │    └─ReLU: 2-3                         [100, 2048]               --
# ├─Sequential: 1-2                        [100, 1024]               --
# │    └─Linear: 2-4                       [100, 1024]               2,098,176
# │    └─ReLU: 2-5                         [100, 1024]               --
# ├─Sequential: 1-3                        [100, 512]                --
# │    └─Linear: 2-6                       [100, 512]                524,800
# │    └─ReLU: 2-7                         [100, 512]                --
# ├─Sequential: 1-4                        [100, 256]                --
# │    └─Linear: 2-8                       [100, 256]                131,328
# │    └─ReLU: 2-9                         [100, 256]                --
# ├─Sequential: 1-5                        [100, 128]                --
# │    └─Linear: 2-10                      [100, 128]                32,896
# │    └─ReLU: 2-11                        [100, 128]                --
# ├─Sequential: 1-6                        [100, 64]                 --
# │    └─Linear: 2-12                      [100, 64]                 8,256
# │    └─ReLU: 2-13                        [100, 64]                 --
# ├─Sequential: 1-7                        [100, 32]                 --
# │    └─Linear: 2-14                      [100, 32]                 2,080
# │    └─ReLU: 2-15                        [100, 32]                 --
# ├─Linear: 1-8                            [100, 10]                 330
# ==========================================================================================
# Total params: 4,405,546
# Trainable params: 4,405,546
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 440.55
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 3.26
# Params size (MB): 17.62
# Estimated Total Size (MB): 21.20
# ==========================================================================================

# %%
big_model = BigModel().to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(big_model.parameters(), lr=lr)
result = fit(train_loader, test_loader, big_model, loss_fn, optimizer, epochs, save_best_model=False, device=device, mode="multi")
# Out:
# Epoch[1/100] - Train loss: 0.17646 Train Accucracy: 0.94722 || Validation Loss: 0.19404 Validation Accuracy: 0.94190
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.09241 Train Accucracy: 0.97317 || Validation Loss: 0.12470 Validation Accuracy: 0.96230
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.06146 Train Accucracy: 0.98108 || Validation Loss: 0.09776 Validation Accuracy: 0.97100
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.04457 Train Accucracy: 0.98582 || Validation Loss: 0.09221 Validation Accuracy: 0.97380
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.04309 Train Accucracy: 0.98578 || Validation Loss: 0.09001 Validation Accuracy: 0.97170
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.03188 Train Accucracy: 0.98842 || Validation Loss: 0.09594 Validation Accuracy: 0.97400
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.03539 Train Accucracy: 0.98822 || Validation Loss: 0.09365 Validation Accuracy: 0.97620
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.04406 Train Accucracy: 0.98588 || Validation Loss: 0.10594 Validation Accuracy: 0.97270
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.01333 Train Accucracy: 0.99457 || Validation Loss: 0.08003 Validation Accuracy: 0.97990
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.01654 Train Accucracy: 0.99320 || Validation Loss: 0.09829 Validation Accuracy: 0.97700
# ====================================================================================================
# Epoch[11/100] - Train loss: 0.01651 Train Accucracy: 0.99353 || Validation Loss: 0.09095 Validation Accuracy: 0.97700
# ====================================================================================================
# Epoch[12/100] - Train loss: 0.01574 Train Accucracy: 0.99420 || Validation Loss: 0.10741 Validation Accuracy: 0.97760
# ====================================================================================================
# Epoch[13/100] - Train loss: 0.03267 Train Accucracy: 0.99003 || Validation Loss: 0.10831 Validation Accuracy: 0.97680
# ====================================================================================================
# Epoch[14/100] - Train loss: 0.00992 Train Accucracy: 0.99580 || Validation Loss: 0.08823 Validation Accuracy: 0.98190
# ====================================================================================================
# Epoch[15/100] - Train loss: 0.00999 Train Accucracy: 0.99543 || Validation Loss: 0.08678 Validation Accuracy: 0.98110
# ====================================================================================================
# Epoch[16/100] - Train loss: 0.01308 Train Accucracy: 0.99482 || Validation Loss: 0.10571 Validation Accuracy: 0.97920
# ====================================================================================================
# Epoch[17/100] - Train loss: 0.00778 Train Accucracy: 0.99637 || Validation Loss: 0.09932 Validation Accuracy: 0.97860
# ====================================================================================================
# Epoch[18/100] - Train loss: 0.00768 Train Accucracy: 0.99625 || Validation Loss: 0.08343 Validation Accuracy: 0.98120
# ====================================================================================================
# Epoch[19/100] - Train loss: 0.00691 Train Accucracy: 0.99628 || Validation Loss: 0.09234 Validation Accuracy: 0.98280
# ====================================================================================================
# Early stopping: Epoch - 18
# 338.0449936389923 초

# %%
plot_fit_result(result[0],result[1],result[2],result[3])

# %% [markdown]
# # Dropout 예제
#
# -   dropout 각 레이어에 적용
#     -   dropout은 nn.Dropout 객체를 사용
#     -   객체 생성시 dropout_rate 설정: 0.2 ~ 0.5
#     -   Drop시킬 노드를 가진 Layer 뒤에 추가한다.

# %%
# Dropout Layer적용 : nn.Linear → nn.ReLU → nn.Dropout
class DropOutModel(nn.Module):

    def __init__(self, dropout_rate = 0.5):
        super().__init__()
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(784,2048), nn.ReLU(), nn.Dropout(p=dropout_rate))
        # ()안에 있는 내용이 순서대로 진행되게해줌 = Sequential
        self.b2 = nn.Sequential(nn.Linear(2048,1024), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b3 = nn.Sequential(nn.Linear(1024,512), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b4 = nn.Sequential(nn.Linear(512,256), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b5 = nn.Sequential(nn.Linear(256,128), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b6 = nn.Sequential(nn.Linear(128,64), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b7 = nn.Sequential(nn.Linear(64,32), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.out_layer = nn.Linear(32,10)

    def forward(self,X):
        out = self.b1(X)
        out = self.b2(out)
        out = self.b3(out)
        out = self.b4(out)
        out = self.b5(out)
        out = self.b6(out)
        out = self.b7(out)
        out = self.out_layer(out)
        return out

# %%
summary(DropOutModel(),(100,1,28,28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# DropOutModel                             [100, 10]                 --
# ├─Sequential: 1-1                        [100, 2048]               --
# │    └─Flatten: 2-1                      [100, 784]                --
# │    └─Linear: 2-2                       [100, 2048]               1,607,680
# │    └─ReLU: 2-3                         [100, 2048]               --
# │    └─Dropout: 2-4                      [100, 2048]               --
# ├─Sequential: 1-2                        [100, 1024]               --
# │    └─Linear: 2-5                       [100, 1024]               2,098,176
# │    └─ReLU: 2-6                         [100, 1024]               --
# │    └─Dropout: 2-7                      [100, 1024]               --
# ├─Sequential: 1-3                        [100, 512]                --
# │    └─Linear: 2-8                       [100, 512]                524,800
# │    └─ReLU: 2-9                         [100, 512]                --
# │    └─Dropout: 2-10                     [100, 512]                --
# ├─Sequential: 1-4                        [100, 256]                --
# │    └─Linear: 2-11                      [100, 256]                131,328
# │    └─ReLU: 2-12                        [100, 256]                --
# │    └─Dropout: 2-13                     [100, 256]                --
# ├─Sequential: 1-5                        [100, 128]                --
# │    └─Linear: 2-14                      [100, 128]                32,896
# │    └─ReLU: 2-15                        [100, 128]                --
# │    └─Dropout: 2-16                     [100, 128]                --
# ├─Sequential: 1-6                        [100, 64]                 --
# │    └─Linear: 2-17                      [100, 64]                 8,256
# │    └─ReLU: 2-18                        [100, 64]                 --
# │    └─Dropout: 2-19                     [100, 64]                 --
# ├─Sequential: 1-7                        [100, 32]                 --
# │    └─Linear: 2-20                      [100, 32]                 2,080
# │    └─ReLU: 2-21                        [100, 32]                 --
# │    └─Dropout: 2-22                     [100, 32]                 --
# ├─Linear: 1-8                            [100, 10]                 330
# ==========================================================================================
# Total params: 4,405,546
# Trainable params: 4,405,546
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 440.55
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 3.26
# Params size (MB): 17.62
# Estimated Total Size (MB): 21.20
# ==========================================================================================

# %%
d_model = DropOutModel().to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(d_model.parameters(), lr=lr)
result = fit(train_loader, test_loader, d_model, loss_fn, optimizer, epochs, save_best_model=False, device=device, mode="multi")
# Out:
# Epoch[1/100] - Train loss: 1.04421 Train Accucracy: 0.60258 || Validation Loss: 1.05294 Validation Accuracy: 0.60200
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.50324 Train Accucracy: 0.79918 || Validation Loss: 0.52156 Validation Accuracy: 0.79510
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.32108 Train Accucracy: 0.91227 || Validation Loss: 0.34984 Validation Accuracy: 0.90880
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.24840 Train Accucracy: 0.94628 || Validation Loss: 0.30495 Validation Accuracy: 0.94230
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.21094 Train Accucracy: 0.94917 || Validation Loss: 0.25390 Validation Accuracy: 0.94310
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.19085 Train Accucracy: 0.95660 || Validation Loss: 0.24174 Validation Accuracy: 0.95330
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.17239 Train Accucracy: 0.95795 || Validation Loss: 0.23516 Validation Accuracy: 0.95270
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.13152 Train Accucracy: 0.97020 || Validation Loss: 0.20263 Validation Accuracy: 0.96630
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.10768 Train Accucracy: 0.97230 || Validation Loss: 0.18176 Validation Accuracy: 0.96600
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.10553 Train Accucracy: 0.97428 || Validation Loss: 0.19256 Validation Accuracy: 0.96590
# ====================================================================================================
# Epoch[11/100] - Train loss: 0.08975 Train Accucracy: 0.97808 || Validation Loss: 0.17937 Validation Accuracy: 0.96860
# ====================================================================================================
# Epoch[12/100] - Train loss: 0.08068 Train Accucracy: 0.97855 || Validation Loss: 0.17152 Validation Accuracy: 0.96840
# ====================================================================================================
# Epoch[13/100] - Train loss: 0.07400 Train Accucracy: 0.98173 || Validation Loss: 0.16222 Validation Accuracy: 0.97270
# ====================================================================================================
# Epoch[14/100] - Train loss: 0.07554 Train Accucracy: 0.97953 || Validation Loss: 0.15362 Validation Accuracy: 0.97110
# ====================================================================================================
# Epoch[15/100] - Train loss: 0.08025 Train Accucracy: 0.97855 || Validation Loss: 0.16524 Validation Accuracy: 0.96870
# ====================================================================================================
# Epoch[16/100] - Train loss: 0.06072 Train Accucracy: 0.98462 || Validation Loss: 0.16394 Validation Accuracy: 0.97460
# ====================================================================================================
# Epoch[17/100] - Train loss: 0.06295 Train Accucracy: 0.98192 || Validation Loss: 0.15746 Validation Accuracy: 0.97370
# ====================================================================================================
# Epoch[18/100] - Train loss: 0.05061 Train Accucracy: 0.98715 || Validation Loss: 0.16222 Validation Accuracy: 0.97760
# ====================================================================================================
# Epoch[19/100] - Train loss: 0.05412 Train Accucracy: 0.98548 || Validation Loss: 0.17033 Validation Accuracy: 0.97490
# ====================================================================================================
# Epoch[20/100] - Train loss: 0.05486 Train Accucracy: 0.98502 || Validation Loss: 0.15221 Validation Accuracy: 0.97530
# ====================================================================================================
# Epoch[21/100] - Train loss: 0.05281 Train Accucracy: 0.98617 || Validation Loss: 0.17285 Validation Accuracy: 0.97550
# ====================================================================================================
# Epoch[22/100] - Train loss: 0.05095 Train Accucracy: 0.98608 || Validation Loss: 0.15708 Validation Accuracy: 0.97420
# ====================================================================================================
# Epoch[23/100] - Train loss: 0.04051 Train Accucracy: 0.98962 || Validation Loss: 0.17170 Validation Accuracy: 0.97870
# ====================================================================================================
# Epoch[24/100] - Train loss: 0.04155 Train Accucracy: 0.98797 || Validation Loss: 0.13584 Validation Accuracy: 0.97900
# ====================================================================================================
# Epoch[25/100] - Train loss: 0.04462 Train Accucracy: 0.98857 || Validation Loss: 0.20092 Validation Accuracy: 0.97790
# ====================================================================================================
# Epoch[26/100] - Train loss: 0.04262 Train Accucracy: 0.98945 || Validation Loss: 0.19048 Validation Accuracy: 0.97780
# ====================================================================================================
# Epoch[27/100] - Train loss: 0.03905 Train Accucracy: 0.98898 || Validation Loss: 0.18818 Validation Accuracy: 0.97660
# ====================================================================================================
# Epoch[28/100] - Train loss: 0.03747 Train Accucracy: 0.98993 || Validation Loss: 0.17671 Validation Accuracy: 0.97810
# ====================================================================================================
# Epoch[29/100] - Train loss: 0.03394 Train Accucracy: 0.99003 || Validation Loss: 0.15696 Validation Accuracy: 0.97880
# ====================================================================================================
# Epoch[30/100] - Train loss: 0.03919 Train Accucracy: 0.98900 || Validation Loss: 0.15480 Validation Accuracy: 0.97660
# ====================================================================================================
# Epoch[31/100] - Train loss: 0.03287 Train Accucracy: 0.99128 || Validation Loss: 0.15514 Validation Accuracy: 0.97940
# ====================================================================================================
# Epoch[32/100] - Train loss: 0.03066 Train Accucracy: 0.99143 || Validation Loss: 0.19083 Validation Accuracy: 0.98180
# ====================================================================================================
# Epoch[33/100] - Train loss: 0.03278 Train Accucracy: 0.99077 || Validation Loss: 0.17470 Validation Accuracy: 0.98070
# ====================================================================================================
# Epoch[34/100] - Train loss: 0.04289 Train Accucracy: 0.98943 || Validation Loss: 0.19028 Validation Accuracy: 0.97720
# ====================================================================================================
# Early stopping: Epoch - 33
# 2150.567729949951 초

# %% [markdown]
# # Batch Normalization (배치정규화)
#
# - Dense 와 Activation 사이에 정의한다.

# %%
# Batch Norml1d Layer적용 : nn.Linear → nn.BatchNorm1d → nn.ReLU → nn.Dropout
class BatchNormModel(nn.Module):

    def __init__(self, dropout_rate = 0.5):
        super().__init__()
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(784,2048), nn.BatchNorm1d(2048), nn.ReLU(), nn.Dropout(p=dropout_rate))
        # ()안에 있는 내용이 순서대로 진행되게해줌 = Sequential
        self.b2 = nn.Sequential(nn.Linear(2048,1024), nn.BatchNorm1d(1024), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b3 = nn.Sequential(nn.Linear(1024,512), nn.BatchNorm1d(512), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b4 = nn.Sequential(nn.Linear(512,256), nn.BatchNorm1d(256), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b5 = nn.Sequential(nn.Linear(256,128), nn.BatchNorm1d(128), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b6 = nn.Sequential(nn.Linear(128,64), nn.BatchNorm1d(64), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b7 = nn.Sequential(nn.Linear(64,32), nn.BatchNorm1d(32), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.out_layer = nn.Linear(32,10)

    def forward(self,X):
        out = self.b1(X)
        out = self.b2(out)
        out = self.b3(out)
        out = self.b4(out)
        out = self.b5(out)
        out = self.b6(out)
        out = self.b7(out)
        out = self.out_layer(out)
        return out

# %%
summary(BatchNormModel(), (100,1,28,28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# BatchNormModel                           [100, 10]                 --
# ├─Sequential: 1-1                        [100, 2048]               --
# │    └─Flatten: 2-1                      [100, 784]                --
# │    └─Linear: 2-2                       [100, 2048]               1,607,680
# │    └─BatchNorm1d: 2-3                  [100, 2048]               4,096
# │    └─ReLU: 2-4                         [100, 2048]               --
# │    └─Dropout: 2-5                      [100, 2048]               --
# ├─Sequential: 1-2                        [100, 1024]               --
# │    └─Linear: 2-6                       [100, 1024]               2,098,176
# │    └─BatchNorm1d: 2-7                  [100, 1024]               2,048
# │    └─ReLU: 2-8                         [100, 1024]               --
# │    └─Dropout: 2-9                      [100, 1024]               --
# ├─Sequential: 1-3                        [100, 512]                --
# │    └─Linear: 2-10                      [100, 512]                524,800
# │    └─BatchNorm1d: 2-11                 [100, 512]                1,024
# │    └─ReLU: 2-12                        [100, 512]                --
# │    └─Dropout: 2-13                     [100, 512]                --
# ├─Sequential: 1-4                        [100, 256]                --
# │    └─Linear: 2-14                      [100, 256]                131,328
# │    └─BatchNorm1d: 2-15                 [100, 256]                512
# │    └─ReLU: 2-16                        [100, 256]                --
# │    └─Dropout: 2-17                     [100, 256]                --
# ├─Sequential: 1-5                        [100, 128]                --
# │    └─Linear: 2-18                      [100, 128]                32,896
# │    └─BatchNorm1d: 2-19                 [100, 128]                256
# │    └─ReLU: 2-20                        [100, 128]                --
# │    └─Dropout: 2-21                     [100, 128]                --
# ├─Sequential: 1-6                        [100, 64]                 --
# │    └─Linear: 2-22                      [100, 64]                 8,256
# │    └─BatchNorm1d: 2-23                 [100, 64]                 128
# │    └─ReLU: 2-24                        [100, 64]                 --
# │    └─Dropout: 2-25                     [100, 64]                 --
# ├─Sequential: 1-7                        [100, 32]                 --
# │    └─Linear: 2-26                      [100, 32]                 2,080
# │    └─BatchNorm1d: 2-27                 [100, 32]                 64
# │    └─ReLU: 2-28                        [100, 32]                 --
# │    └─Dropout: 2-29                     [100, 32]                 --
# ├─Linear: 1-8                            [100, 10]                 330
# ==========================================================================================
# Total params: 4,413,674
# Trainable params: 4,413,674
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 441.37
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 6.51
# Params size (MB): 17.65
# Estimated Total Size (MB): 24.48
# ==========================================================================================

# %% [markdown]
# # Learning rate decay

# %% [markdown]
# ### Optimizer와 Learning rate scheduler의 속성, 메소드 확인
#
# -   파이토치는 `torch.optim` 모듈에서 다양한 Learning rate 알고리즘을 제공한다.

# %%
import matplotlib.pyplot as plt

def plot_lr(title, lr_list):
    """Learning 스케쥴러(학습도중 LR를 변경시키는 객체.)에 의해 변화되는 Learning Rate값을 시각화.

    Args:
        title (str): title
        lr_list (list): Learning Rate 스케쥴러에 의해 변경된 learning rate값들을 가지는 list
    """
    plt.figure(figsize=(15, 6))
    plt.plot(range(len(lr_list)), lr_list)

    plt.title(title)
    xticks = [x for x in range(len(lr_list)) if x % 10 == 0] # 눈금을 10 배수 자리에 위치.
    plt.xticks(xticks)
    plt.xlabel("Epoch 수 또는 Step 수")
    plt.ylabel("학습률-LR")
    plt.grid(True, linestyle=":")
    plt.show()

# %%
lr = 0.001
model = BatchNormModel()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
# optimizer의 현재 lr 조회
optimizer.param_groups[0]['lr']
# Out:
# 0.001

# %% [markdown]
# #### StepLR

# %%
# 특정 epochs/step 마다 특정 비율로 lr를 볌경(보통 줄여나가는 방법; 계단식)

# 1. learningRate scheduler 객체 생성
step_lr_scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,  # 학습률을 변경할 optimizer
    step_size=30,  # 몇 epoch./step 당 lr를 변경할지 설정. (30 epoch가 될수도 있고 30 step이 될 수도 있음. 이건 호출되는 곳에서 결정됨(epoch에서 하면 30 epch))
    # lr_scheduler.step() - 지정한 횟수(30)만큼 호출하면 변경
    gamma= 0.5  # 변경할 비율. 새 lr = 현재 lr * gamma
)

step_lr_scheduler.get_last_lr() # optimizer의 현재 lr를 조회
# Out:
# [0.001]

# %%
# 학습
lr_list = [] # scheduler에게 lr 변경 요청 후 lr을 저장.
epochs = 300
step_size = 20   # for x, y in dataloader 대신 임의로 지정한 반복 횟수.
                    # dataloader는 데이터를 여러 조각으로 나눠 줌
# 1 epoch 당 몇번 학습할지
for epoch in range(epochs) :
    # 1 에폭 학습
    for step in range(step_size) : # for x, y in dataloader 라고 쓰는게 맞으나 횟수를 임의로 지정해서 형식이 달라짐
        # 배치만큼 학습데이터를 가져와서 1 step 학습
        # 1. x, y를 device로 이동
        # 2. model 추론
        # 3. loss 계산
        # 4. gradient 계산
        # 5. parameter 업데이트
        optimizer.step()
        # 6. parameter의 gradient 초기화
        optimizer.zero_grad()
        # 여기까지가 1 step 
    # lr scheduler를 이용해서 lr를 변경( 스케쥴에 맞춰서 변경 )
    step_lr_scheduler.step()
    lr_list.append(step_lr_scheduler.get_last_lr()[0])

# %%
lr_list[-5:]
# Out:
# [1.953125e-06, 1.953125e-06, 1.953125e-06, 1.953125e-06, 9.765625e-07]

# %%
plt.rcParams["font.family"] = 'Malgun gothic'
plot_lr("StepLR",lr_list)

# %% [markdown]
# #### CosineAnnealingLR
#
# cosine 그래프를 그리면서 learning rate를 변경 하는 방식.
# 최근에는 learning rate를 단순히 감소시키기 보다는 감소와 증가를 반복하여 진동하는 방식으로 최적점을 찾아가는 알고리즘을 많이 사용한다. 이러한 방법 중 가장 간단하면서도 많이 사용되는 방법이 CosineAnnealingLR이다.

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
ca_lr_sch = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=20, # 변화주기(내려가는 주기, 올라가는 주기)
    # 20 epoch/step 동안 내려가고 20 epoch/step 동안 올라가는 주기 변화를 줌.
    eta_min=1e-6 # lr의 최소값을 지정. 어디까지 내릴지.
)
# 초기 lr ~ eta_min 사이를 올라갔다 내려갔다 한다.

# %%
lr_list = []
for epoch in range(epochs) :
    for step in range(step_size) :
        optimizer.step()
        optimizer.zero_grad()

    ca_lr_sch.step()
    lr_list.append(ca_lr_sch.get_last_lr()[0])

# %%
lr_list
# Out:
# [0.0009938503261272714,
#  0.0009755527298894295,
#  0.0009455577588320899,
#  0.0009046039886902865,
#  0.0008536998372026806,
#  0.0007940987335200905,
#  0.0007272682546199038,
#  0.0006548539886902865,
#  0.0005786390152875956,
#  0.0005005000000000002,
#  0.000422360984712405,
#  0.00034614601130971394,
#  0.0002737317453800965,
#  0.00020690126647990978,
#  0.00014730016279731957,
#  9.639601130971382e-05,
#  5.54422411679103e-05,
#  2.5447270110570818e-05,
#  7.149673872728741e-06,
#  1e-06,
#  7.149673872728684e-06,
#  2.5447270110570706e-05,
#  5.544224116791024e-05,
#  9.639601130971376e-05,
#  0.00014730016279731944,
#  0.00020690126647990962,
#  0.00027373174538009633,
#  0.0003461460113097137,
#  0.00042236098471240465,
#  0.0005005,
#  0.0005786390152875953,
#  0.0006548539886902863,
#  0.0007272682546199037,
#  0.0007940987335200903,
#  0.0008536998372026804,
#  0.0009046039886902862,
#  0.0009455577588320897,
#  0.0009755527298894293,
#  0.0009938503261272714,
#  0.001,
#  0.0009938503261272714,
#  0.0009755527298894295,
#  0.00094555775883209,
#  0.0009046039886902868,
#  0.0008536998372026807,
#  0.0007940987335200906,
#  0.0007272682546199035,
#  0.0006548539886902864,
#  0.0005786390152875959,
#  0.0005005000000000001,
#  0.00042236098471240525,
#  0.0003461460113097139,
#  0.00027373174538009606,
#  0.00020690126647990973,
#  0.0001473001627973193,
#  9.639601130971384e-05,
#  5.54422411679105e-05,
#  2.5447270110570862e-05,
#  7.149673872728793e-06,
#  1e-06,
#  7.149673872728684e-06,
#  2.5447270110570536e-05,
#  5.544224116790985e-05,
#  9.639601130971277e-05,
#  0.00014730016279731773,
#  0.00020690126647990764,
#  0.00027373174538009335,
#  0.0003461460113097104,
#  0.0004223609847124011,
#  0.0005004999999999953,
#  0.0005786390152875904,
#  0.0006548539886902801,
#  0.0007272682546198963,
#  0.0007940987335200829,
#  0.0008536998372026722,
#  0.0009046039886902777,
#  0.0009455577588320811,
#  0.0009755527298894201,
#  0.000993850326127262,
#  0.0009999999999999907,
#  0.0009938503261272622,
#  0.0009755527298894207,
#  0.0009455577588320811,
#  0.0009046039886902783,
#  0.0008536998372026727,
#  0.0007940987335200835,
#  0.0007272682546198977,
#  0.0006548539886902815,
#  0.0005786390152875899,
#  0.0005004999999999957,
#  0.00042236098471240167,
#  0.00034614601130971096,
#  0.00027373174538009465,
#  0.00020690126647990732,
#  0.00014730016279731814,
#  9.639601130971306e-05,
#  5.544224116791007e-05,
#  2.5447270110570926e-05,
#  7.149673872728628e-06,
#  1e-06,
#  7.149673872728684e-06,
#  2.5447270110570208e-05,
#  5.5442241167909416e-05,
#  9.639601130971273e-05,
#  0.0001473001627973183,
#  0.00020690126647990827,
#  0.0002737317453800933,
#  0.00034614601130971036,
#  0.00042236098471239934,
#  0.0005004999999999962,
#  0.0005786390152875895,
#  0.0006548539886902802,
#  0.0007272682546198974,
#  0.0007940987335200825,
#  0.0008536998372026738,
#  0.0009046039886902782,
#  0.0009455577588320815,
#  0.0009755527298894203,
#  0.0009938503261272622,
#  0.0009999999999999911,
#  0.0009938503261272625,
#  0.0009755527298894205,
#  0.0009455577588320819,
#  0.0009046039886902785,
#  0.0008536998372026741,
#  0.0007940987335200829,
#  0.0007272682546198979,
#  0.0006548539886902807,
#  0.00057863901528759,
#  0.0005004999999999968,
#  0.0004223609847124,
#  0.00034614601130971106,
#  0.00027373174538009395,
#  0.0002069012664799089,
#  0.00014730016279731881,
#  9.639601130971318e-05,
#  5.5442241167909755e-05,
#  2.544727011057043e-05,
#  7.149673872728796e-06,
#  1e-06,
#  7.149673872728684e-06,
#  2.544727011057203e-05,
#  5.544224116791231e-05,
#  9.639601130971784e-05,
#  0.0001473001627973261,
#  0.00020690126647991794,
#  0.00027373174538010956,
#  0.00034614601130972895,
#  0.0004223609847124238,
#  0.0005005000000000214,
#  0.0005786390152876207,
#  0.0006548539886903157,
#  0.0007272682546199368,
#  0.0007940987335201269,
#  0.0008536998372027188,
#  0.0009046039886903274,
#  0.0009455577588321322,
#  0.0009755527298894739,
#  0.0009938503261273162,
#  0.0010000000000000456,
#  0.0009938503261273167,
#  0.0009755527298894744,
#  0.0009455577588321335,
#  0.000904603988690329,
#  0.0008536998372027209,
#  0.0007940987335201263,
#  0.0007272682546199362,
#  0.0006548539886903167,
#  0.0005786390152876219,
#  0.0005005000000000225,
#  0.000422360984712425,
#  0.00034614601130973015,
#  0.0002737317453801106,
#  0.00020690126647992027,
#  0.00014730016279732692,
#  9.639601130971951e-05,
#  5.5442241167912784e-05,
#  2.544727011057182e-05,
#  7.1496738727288545e-06,
#  1e-06,
#  7.149673872728684e-06,
#  2.544727011057037e-05,
#  5.5442241167909796e-05,
#  9.639601130971342e-05,
#  0.00014730016279731816,
#  0.0002069012664799085,
#  0.00027373174538009715,
#  0.000346146011309715,
#  0.0004223609847124046,
#  0.0005005000000000004,
#  0.0005786390152875945,
#  0.0006548539886902858,
#  0.0007272682546199036,
#  0.0007940987335200892,
#  0.0008536998372026799,
#  0.000904603988690285,
#  0.000945557758832089,
#  0.0009755527298894294,
#  0.0009938503261272714,
#  0.0009999999999999998,
#  0.0009938503261272711,
#  0.0009755527298894291,
#  0.0009455577588320901,
#  0.0009046039886902875,
#  0.0008536998372026818,
#  0.0007940987335200915,
#  0.0007272682546199046,
#  0.0006548539886902868,
#  0.0005786390152875954,
#  0.0005004999999999998,
#  0.00042236098471240394,
#  0.0003461460113097127,
#  0.0002737317453800982,
#  0.00020690126647991092,
#  0.0001473001627973203,
#  9.639601130971411e-05,
#  5.544224116791033e-05,
#  2.5447270110571804e-05,
#  7.149673872728627e-06,
#  1e-06,
#  7.149673872728684e-06,
#  2.5447270110569215e-05,
#  5.544224116790729e-05,
#  9.639601130970907e-05,
#  0.00014730016279731274,
#  0.0002069012664799006,
#  0.0002737317453800816,
#  0.000346146011309696,
#  0.0004223609847123838,
#  0.0005004999999999797,
#  0.0005786390152875683,
#  0.0006548539886902563,
#  0.0007272682546198709,
#  0.0007940987335200549,
#  0.0008536998372026428,
#  0.0009046039886902443,
#  0.0009455577588320467,
#  0.0009755527298893852,
#  0.0009938503261272267,
#  0.0009999999999999554,
#  0.000993850326127227,
#  0.0009755527298893858,
#  0.0009455577588320474,
#  0.0009046039886902453,
#  0.000853699837202644,
#  0.0007940987335200564,
#  0.0007272682546198724,
#  0.0006548539886902578,
#  0.00057863901528757,
#  0.0005004999999999812,
#  0.0004223609847123854,
#  0.00034614601130969746,
#  0.00027373174538008294,
#  0.00020690126647990181,
#  0.00014730016279731385,
#  9.639601130970994e-05,
#  5.544224116790798e-05,
#  2.544727011056967e-05,
#  7.1496738727289096e-06,
#  1e-06,
#  7.149673872728684e-06,
#  2.544727011057269e-05,
#  5.544224116791263e-05,
#  9.639601130971846e-05,
#  0.0001473001627973272,
#  0.0002069012664799209,
#  0.0002737317453801117,
#  0.00034614601130973004,
#  0.0004223609847124254,
#  0.0005005000000000253,
#  0.0005786390152876254,
#  0.000654853988690321,
#  0.0007272682546199426,
#  0.0007940987335201334,
#  0.0008536998372027273,
#  0.0009046039886903358,
#  0.0009455577588321401,
#  0.0009755527298894816,
#  0.000993850326127325,
#  0.0010000000000000542,
#  0.0009938503261273251,
#  0.0009755527298894834,
#  0.0009455577588321409,
#  0.0009046039886903349,
#  0.000853699837202726,
#  0.000794098733520135,
#  0.0007272682546199444,
#  0.0006548539886903227,
#  0.0005786390152876271,
#  0.0005005000000000272,
#  0.00042236098471243067,
#  0.0003461460113097351,
#  0.00027373174538011325,
#  0.00020690126647991943,
#  0.0001473001627973284,
#  9.63960113097195e-05,
#  5.544224116791342e-05,
#  2.5447270110572142e-05,
#  7.149673872728963e-06,
#  1e-06]

# %%
plot_lr("CosineAnnealingLR", lr_list)

# %% [markdown]
# #### CosineAnnealingWarmRestarts
#
# cosine annealing의 스케쥴링에 cosine 주기의 에폭을 점점 늘리거나 줄일 수 있다. (보통 늘린다.)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
cawr_lr_sche = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer,
    T_0 = 10, # 변화주기 (CosineAnnealingLR의 T_max)
    T_mult=2, # 새로운 변화주기.
            # 현재 변화주기(T_0) * T_mult = 새 변화주기(T_0)
    eta_min= 1e-6 # 어디까지 내릴거냐
)

# %%
lr_list = []
for epoch in range(epochs) :


    for step in range(step_size):
        optimizer.step()
        optimizer.zero_grad()
        
    cawr_lr_sche.step()
    lr_list.append(cawr_lr_sche.get_last_lr()[0])

# %%
plot_lr("CosineAnnealingWarmRestart", lr_list)
