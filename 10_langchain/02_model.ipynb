# %% [markdown]
# <!-- # Langchain은 다양한 LLM(대규모 언어 모델)을 지원한다
# -	대규모 언어 모델(LLM, Large Language Model)을 개발하는 회사들은 사용자가 자신의 애플리케이션에서 LLM을 손쉽게 활용할 수 있도록 API(Application Programming Interface) 서비스를 제공하고 있다.
# -	하지만 각 LLM은 고유한 API 호출 라이브러리(Library)를 제공하기 때문에, 개발자는 동일한 작업을 수행하더라도 LLM에 따라 다른 코드를 작성해야 하는 번거로움이 있다.
# -	Langchain은 이러한 문제를 해결하기 위해 다양한 LLM의 API를 통합적으로 지원한다.
# -	여러 LLM을 동일한 인터페이스(interface)로 호출할 수 있게 하여 특정 모델에 종속되지 않도록 하고, 필요에 따라 쉽게 다른 모델로 전환할 수 있다.
# -	Langchain이 지원하는 주요 LLM 목록
#     - https://python.langchain.com/docs/integrations/chat/#featured-providers -->

# %%
# uv venv .venv --python=3.12

# %%
# uv pip install ipykernel ipywidgets

# uv pip install langchain langchain-classic langchain-community python-dotenv

# %% [markdown]
# # OpenAI 모델 사용
# - https://platform.openai.com
#
# ## 결제
# 1. 로그인 후 Billing 페이지로 이동.
#    - **신용카드가 등록된 경우 바로 충전할 수 있다.**
#    - setting -> Billing
#
#    ![openai_payment.png](figures/openai_payment.png)
#    - 금액 입력 후 `continue`
#    - 다음 페이지에서 세금 포함 결제 금액 나오면 `Confirm`  한다.
#
# 2. 신용카드 등록
#    - Payment methods 탭을 선택하고 카드를 등록한다.
#
#    ![openai_payment2.png](figures/openai_payment2.png)
#
#    - 등록이 끝나면 최초 구매를 진행한다. $5 ~ $100 사이의 금액을 선택할 수 있다.
#    - 자동 충전을 설정하고 싶다면 automatic recharge 를 활성화 하고 아래 추가 설정에 입력한다.
#      - 자동 충전은 특정 금액 이하로 떨어지면 자동으로 충전한다. (**비활성화**)
#
#    ![openai_payment3.png](figures/openai_payment3.png)
#
# 3. 수동으로 **추가 결제하기**
#    - Billing 페이지의 Overview에서 `Add to credit balance` 를 클릭한 뒤 금액을 입력하고 결제한다.
#
# ## 사용량 확인
# - profile/설정 -> Usage 에서 확인

# %% [markdown]
# ## API Key 생성
#
# ![openai_create_apikey.png](figures/openai_create_apikey.png)
#
# - 로그인 -> Dashboard -> API Keys -> Create New Secreat Key
# > Settings -> API Keys
#
# ## API Key 등록
# - 환경변수에 등록
#   - 변수이름: OPENAI_API_KEY
#   - 값: 생성된 키
# - dotenv를 이용해서 load
#   - Working directory에  `.env` 파일 생성하고 `OPENAI_API_KEY=생성된키` 추가한다.
#   - load_dotenv() 호출 하면 .env 파일에 있는 값을 읽은 뒤 환경변수로 등록한다.
# - **주의**
#   - 생성된 API Key는 노출되면 안된다.
#   - API Key가 저장된 파일(코드나 설정파일)이 github에 올라가 공개되서는 안된다.
#
# ## 사용 비용 확인
# - settings -> Usage 에서 확인
#
# ## OpenAI LLM 모델들
# -  OpenAI LLM 모델: https://platform.openai.com/docs/models
# -  모델별 가격: https://platform.openai.com/docs/pricing
# -  토큰사이즈 확인: https://platform.openai.com/tokenizer
#    -  1토큰: 영어 3\~4글자 정도, 한글: 대략 1\~2글자 정도
#    -  모델이 업데이트 되면서 토큰 사이즈도 조금씩 커지고 있다.

# %% [markdown]
# ## OpenAI 를 연동하기 위한 package 설치
# ```bash
# pip install langchain-openai
# ```
#
# - OpenAI 자체 라이브러리 설치
#     - `pip install openai`
#     - langchain-openai를 설치하면 같이 설치 된다.

# %%
# API Key Load > OS 환경변수로 등록. (OPENAI_API_KEY)
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os
# os. getenv('OPENAI_API_KEY')

# %% [markdown]
# ## OpenAI Library 를 이용한 API 호출

# %%
from openai import OpenAI

client = OpenAI() #api key가 환경변수에 없으면 직접 입력.
response = client.chat.completions.create(
    model="gpt-5-nano", # 사용할 모델 종류의 이름
    messages=[
        {"role":"user", "content":"OpenAI의 LLM 모델 종류는 뭐가 있어?"}
    ]
)

# chat 요청 프롬프트 형식
# "role" : 누가 말하는지, user, ai, system 등이 있음.
# "content" : 메세지

# %%
print(response)
# Out:
# ChatCompletion(id='chatcmpl-CoQKLJwcL7HgD2PX9O4Hp2owUkhsl', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='대략적으로 OpenAI의 주요 LLM 계열은 다음과 같습니다. API나 ChatGPT에서 사용 가능한 모델은 계획(플랜)과 지역에 따라 다를 수 있습니다.\n\n- GPT-3 계열\n  - text-davinci-003: GPT-3 중 가장 강력한 텍스트 모델의 대표 버전\n  - text-curie-001, text-babbage-001, text-ada-001: 용도와 비용 대 성능의 차이가 있는 하위 모델들\n  - code-davinci-002: Codex 계열, 코드 생성/완성에 특화\n\n- GPT-3.5 계열\n  - gpt-3.5-turbo: 대화형에 최적화된 주력 모델, 속도와 비용의 균형이 좋음\n\n- GPT-4 계열\n  - gpt-4: 최신 멀티모달 가능(일부 입력은 텍스트/이미지), 가장 강력한 일반 GPT 계열\n  - gpt-4-turbo: gpt-4의 비용/속도 최적화 버전\n  - gpt-4o: 멀티모달 버전으로 텍스트 외 이미지 입력 등을 지원하는 확장 모델(플랜에 따라 이용 가능 여부가 다름)\n\n- Codex/코드 특화 계열\n  - code-davinci-002 등 Codex 계열: 코드 작성, 코드 이해에 특화된 모델들\n\n- 기타 관련 모델/도구\n  - 임베딩 모델: text-embedding-*, 예를 들어 검색/추천에 쓰이는 임베딩 생성용 모델들\n  - 음성/이미지 관련 도구들: Whisper(음성 인식), DALL-E(이미지 생성) 등은 LLM은 아니지만 OpenAI의 멀티모달/멀티도구 생태계에 포함\n\n참고\n- ChatGPT에서 어떤 모델이 보이는지는 사용 중인 플랜(예: 무료/프로/기업)과 업데이트 시점에 따라 달라집니다.\n- Azure OpenAI Service를 통해서도 동일한 계열의 모델(예: GPT-3.5-turbo, GPT-4) 등을 사용할 수 있습니다.\n\n원하시면 특정 용도(대화형 봇, 코드 생성, 검색/리트리벌 등)에 맞춰 어떤 모델이 가장 적합한지 간단한 추천도 드릴게요. 어떤 용도로 쓰실지 알려주실래요?', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1766133637, model='gpt-5-nano-2025-08-07', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=3494, prompt_tokens=18, total_tokens=3512, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=2944, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
print(response.choices[0].message.content)
# Out:
# 대략적으로 OpenAI의 주요 LLM 계열은 다음과 같습니다. API나 ChatGPT에서 사용 가능한 모델은 계획(플랜)과 지역에 따라 다를 수 있습니다.
#
# - GPT-3 계열
#   - text-davinci-003: GPT-3 중 가장 강력한 텍스트 모델의 대표 버전
#   - text-curie-001, text-babbage-001, text-ada-001: 용도와 비용 대 성능의 차이가 있는 하위 모델들
#   - code-davinci-002: Codex 계열, 코드 생성/완성에 특화
#
# - GPT-3.5 계열
#   - gpt-3.5-turbo: 대화형에 최적화된 주력 모델, 속도와 비용의 균형이 좋음
#
# - GPT-4 계열
#   - gpt-4: 최신 멀티모달 가능(일부 입력은 텍스트/이미지), 가장 강력한 일반 GPT 계열
#   - gpt-4-turbo: gpt-4의 비용/속도 최적화 버전
#   - gpt-4o: 멀티모달 버전으로 텍스트 외 이미지 입력 등을 지원하는 확장 모델(플랜에 따라 이용 가능 여부가 다름)
#
# - Codex/코드 특화 계열
#   - code-davinci-002 등 Codex 계열: 코드 작성, 코드 이해에 특화된 모델들
#
# - 기타 관련 모델/도구
#   - 임베딩 모델: text-embedding-*, 예를 들어 검색/추천에 쓰이는 임베딩 생성용 모델들
#   - 음성/이미지 관련 도구들: Whisper(음성 인식), DALL-E(이미지 생성) 등은 LLM은 아니지만 OpenAI의 멀티모달/멀티도구 생태계에 포함
#
# 참고
# - ChatGPT에서 어떤 모델이 보이는지는 사용 중인 플랜(예: 무료/프로/기업)과 업데이트 시점에 따라 달라집니다.
# - Azure OpenAI Service를 통해서도 동일한 계열의 모델(예: GPT-3.5-turbo, GPT-4) 등을 사용할 수 있습니다.
#
# 원하시면 특정 용도(대화형 봇, 코드 생성, 검색/리트리벌 등)에 맞춰 어떤 모델이 가장 적합한지 간단한 추천도 드릴게요. 어떤 용도로 쓰실지 알려주실래요?

# %% [markdown]
# ## Langchain을 이용한 OpenAI API 호출
#
# - **ChatOpenAI**
#     - chat (대화-채팅) 기반 모델 model.
#     - Default 로 gpt-3.5-turbo 사용
#     - llm 전달 입력과 llm 응답 출력 타입:  Message
# > - **OpenAI**
# >     - 문장 완성 모델. (text completion) model
# >     - Default로 gpt-3.5-turbo-instruct 사용
# >       - instruct 모델만 사용가능
# >     - llm전달 입력과 llm 응답 출력 타입: str
# - Initializer 주요 파라미터
#     -  **temperature**
#         -  llm 모델의 출력 무작위성을 지정한다.
#         -  0 ~ 2 사이 실수를 설정하며 클 수록 무작위성이 커진다. 기본값: 0.7
#         -  정확한 답변을 얻어야 하는 경우 작은 값을 창작을 해야 하는 경우 큰 값을 지정한다.
#     -  **model_name**
#         -  사용할 openai 모델 지정
#     - **max_tokens**:
#         - llm 모델이 응답할 최대 token 수.
#         - gpt-5 모델은 추론과정을 거칠 수있고 이 경우 토큰을 소비한다. 그래서 max_tokens를 너무 작게 잡으면 응답이 안올 수있다.
#     - **api_key**
#         - OpenAI API key를 직접 입력해 생성시 사용.
#         - API key가 환경변수에 설정 되있으면 생략한다.
# -  메소드
#     - **`invoke(message)`** : LLM에 질의 메세지를 전달하며 LLM의 응답을 반환한다.
# > - **Message**
# >     - Langchain 다양한 상황과 작업 마다 다양한 값들로 구성된 입출력 데이터를 만든다.
# >     - Langchain은 그 상황들에 맞는 다양한 Message 클래스를 제공한다. 이것을 이용하면 특정 작업에 적합한 입력값을 설정할 수 있다.

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-5-nano")
# 질의
response = model.invoke("Langchain은 어떤 Framework인지 설명해줘.")

# %%
print(type(response))
print(response.content)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# LangChain은 LLM(대형 언어 모델)을 활용한 애플리케이션을 쉽게 만들 수 있도록 해주는 오픈소스 프레임워크예요. 단순히 모델 하나를 호출하는 것뿐 아니라, 모델을 외부 도구(API), 데이터 소스, 기억(memory) 등과 연결해 다단계의 대화나 자동화 워크플로우를 구성할 수 있도록 도와주는 라이브러리입니다.
#
# 주요 포인트
# - 프레임워크의 역할: 모델 호출을 중심으로 프롬프트 관리, 도구 사용, 기억 유지, 데이터 검색(RAG) 등을 한곳에서 조합해 실전 애플리케이션으로 만드는 오케스트레이션 도구.
# - 주요 구성요소
#   - Chains: 프롬프트를 순차적으로 연결해 다단계 처리를 구현하는 흐름(예: SimpleChain, SequentialChain, MapReduceChain 등).
#   - Agents and Tools: LLM이 목표를 달성하기 위해 필요한 도구를 선택하고 실행하는 에이전트. Tools는 API 호출, 파일 시스템 조회, 외부 서비스 호출 등 다양한 기능을 래핑.
#   - Prompt templates: 재사용 가능한 프롬프트 형식. Few-shot 프롬프트, 대화형 프롬프트 등 구성 요소 관리.
#   - Memory: 대화의 맥락을 기억하고 유지하는 기능. 예: ConversationBufferMemory, SummaryMemory 등.
#   - Retrieval-Augmented Generation(RAG): 벡터 저장소에서 관련 문서를 검색해 LLM에 제공하여 정보 정확도를 높임.
#   - Vector stores 및 데이터 연동: Chroma, FAISS, Milvus, Weaviate, Pinecone 등과의 연동으로 문서 검색 가능.
#   - 데이터 로더/문서 파싱: 문서 로더나 파서로 다양한 형식의 데이터를 가져와 처리.
#   - LLM 프로바이더 래퍼: OpenAI, Cohere, HuggingFace, Anthropic, Google Vertex AI 등 다양한 LLM 공급자를 추상화해 사용할 수 있음.
#   - 다중 언어 지원: Python 버전과 JavaScript/TypeScript 버전 두 가지로 제공되며, 서로 다른 스택에서 활용 가능.
#   - 콜백/로깅: 실행 중 상태를 모니터링하고 스트리밍 결과를 처리하는 콜백 시스템.
#
# 무엇에 유용한가?
# - 대화형 봇에 기억을 추가하고, 지식 베이스에서 관련 정보를 찾아 답변을 생성
# - 문서 QA 시스템: 벡터 DB에서 문서를 검색하고 Q&A를 수행
# - 자동화 에이전트: API를 호출하고 데이터를 가공해 작업 흐름을 자동화
# - 코드 생성 도우미나 데이터 분석 도구를 여러 API와 조합해 복합 작업 수행
#
# 주의점
# - 프롬프트 품질과 도구 설계에 따라 성능이 크게 좌우됨.
# - 비용 관리(LLM API 사용료)와 데이터 프라이버시를 고려해야 함.
# - 최신 라이브러리 버전에 따라 API나 사용 방식이 바뀔 수 있어 문서를 주기적으로 확인 필요.
#
# 시작 방법(간단)
# - Python: pip install langchain
# - JavaScript/TypeScript: npm install langchain
# - 공식 문서와 예제를 따라 간단한 “챗봇 + 기억 + 벡터 검색” 같은 기본 사례를 먼저 구현해 보는 것이 좋습니다.
#
# 요약하자면, LangChain은 여러 LLM과 외부 도구를 연결해 실용적인 애플리케이션을 빠르게 설계하고 운영할 수 있게 해주는 종합적인 오케스트레이션 프레임워크입니다.

# %%
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-5-nano", streaming=True)

res = model.stream("Langchain은 어떤 Framework인지 설명해줘.")
for token in res:
    print(token.content, end="")
# Out:
# LangChain은 대형 언어 모델(Large Language Model, LLM)을 이용한 애플리케이션을 쉽게 만들 수 있도록 도와주는 프레임워크예요. 모델 호출을 단일 작업이 아니라, 프롬프트 설계, 데이터 흐름(파이프라인), 기억, 외부 도구 연동 등 여러 구성요소로 잘 엮어서 엔드투엔드 애플리케이션으로 구축할 수 있게 해줍니다.
#
# 주요 특징과 구성요소
# - LLM 래퍼(LLM wrappers): OpenAI, Cohere, Anthropic 등 다양한 LLM 공급자의 API를 일관된 인터페이스로 다룰 수 있게 해줍니다.
# - 프롬프트 템플릿(Prompt Templates): 재사용 가능한 프롬프트 구성 요소를 만들어 서로 다른 입력에 쉽게 적용할 수 있습니다.
# - 체인(Chains): 여러 LLM 호출과 데이터 흐름을 연결하는 파이프라인. 예를 들어, 하나의 프롬프트로 질문을 만들고, 그 응답을 또 다른 프롬프트에 전달하는 식으로 구성합니다.
# - 메모리(Memory): 대화 맥락이나 상태를 저장하고 재사용할 수 있습니다. 예: ConversationBufferMemory, 요약 메모리 등.
# - 에이전트와 도구(Agents and Tools): 에이전트가 상황에 따라 외부 API 호출, 데이터 조회, 계산 등 다양한 도구를 선택하고 사용할 수 있게 해줍니다.
# - Retrieval-Augmented Generation(RAG): 벡터 저장소(Vector Stores)에서 관련 문서나 지식을 검색하고 이를 LLM에 제공해 더 정확한 응답을 생성합니다.
# - 벡터 저장소 연동: FAISS, Pinecone, Weaviate 등과의 연동을 지원합니다.
# - 콜백/로깅: 실행 과정의 로깅과 디버깅에 도움되는 콜백 관리 기능.
# - 다중 언어 버전: Python 버전과 JavaScript/TypeScript 버전이 모두 제공됩니다.
#
# 적용 가능한 사용 예
# - 대화형 챗봇 및 컨시어지 서비스: 맥락 기억과 도구 연동으로 실용적인 대화 만들기.
# - 문서 질의응답(Q&A) 시스템: 문서를 인덱싱해 필요한 정보를 벡터 검색으로 찾아 LLM에 공급.
# - 자동화된 워크플로우/데이터 파이프라인: 여러 단계의 의사결정과 API 호출을 자동화.
# - 지식 기반의 리포트 생성, 요약 도구, 자동화된 질문 응답 시스템 등.
#
# 참고할 점
# - 추상화가 강한 프레임워크라 처음 사용할 때 개념과 패턴을 익히는 시간이 필요합니다.
# - 프레임워크를 통한 비용 관리(LLM 호출 비용), 데이터 보안, 프롬프트 설계의 품질이 성능에 큰 영향이 있습니다.
# - LangChain은 프레임워크일 뿐, 모델의 성능 자체를 보장하지 않습니다. 모델과 데이터 품질이 중요합니다.
#
# 간단히 시작하는 방법
# - 파이썬: pip install langchain
# - 자바스크립트/타입스크립트: npm install langchain
# - 필요에 따라 OpenAI 등의 API 키 설정이 필요합니다.
#
# 원하시면 파이썬 또는 JS 버전으로 간단한 예제 흐름(예: LLMChain으로 질의응답 만들기, 또는 RetrievalQA 파이프라인 구성)을 구체적으로 같이 살펴보겠습니다. 어떤 용도나 언어로 먼저 보고 싶으신가요?

# %%
# reasoning 설정 (gpt-5 버전부터 추가됨.)
## reasoning : 어떤식으로 답변할 지에 대한 논리를 세우고 그에 맞에 답변을 만듦.
# >> 문제 전제 → 논리 전개 → 결론 도출하는 과정을 스스로 계획/구성하여 답을 도출하는 방식. 
model = ChatOpenAI(
    model="gpt-5",
    reasoning={
        "effort": "medium", "summary":"auto"
    }
)
# effort : 추론의 깊이(low, medium, high) 
# summary : 추론과정을 출력
# 질의
result = model.invoke("LLM 모델에 대한 내용을 초심자를 위해 최대한 쉽게 설명해줘.")
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[26], line 13
#       4 model = ChatOpenAI(
#       5     model="gpt-5",
#       6     reasoning={
#       7         "effort": "medium", "summary":"auto"
#       8     }
#       9 )
#      10 # effort : 추론의 깊이(low, medium, high)
#      11 # summary : 추론과정을 출력
#      12 # 질의
# ---> 13 result = model.invoke("LLM 모델에 대한 내용을 초심자를 위해 최대한 쉽게 설명해줘.")
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)    391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1117, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1108 @override
#    1109 def generate_prompt(
#    1110     self,
#    (...)   1114     **kwargs: Any,
#    1115 ) -> LLMResult:
#    1116     prompt_messages = [p.to_messages() for p in prompts]
# -> 1117     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:927, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     924 for i, m in enumerate(input_messages):
#     925     try:
#     926         results.append(
# --> 927             self._generate_with_cache(
#     928                 m,
#     929                 stop=stop,
#     930                 run_manager=run_managers[i] if run_managers else None,
#     931                 **kwargs,
#     932             )
#     933         )
#     934     except BaseException as e:
#     935         if run_managers:
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1221, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219     result = generate_from_stream(iter(chunks))
#    1220 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221     result = self._generate(
#    1222         messages, stop=stop, run_manager=run_manager, **kwargs
#    1223     )
#    1224 else:
#    1225     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1382, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1380     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1381         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1382     raise e
#    1383 if (
#    1384     self.include_response_headers
#    1385     and raw_response is not None
#    1386     and hasattr(raw_response, "headers")
#    1387 ):
#    1388     generation_info = {"headers": dict(raw_response.headers)}
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1364, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1360     raw_response = self.root_client.responses.with_raw_response.parse(
#    1361         **payload
#    1362     )
#    1363 else:
# -> 1364     raw_response = self.root_client.responses.with_raw_response.create(
#    1365         **payload
#    1366     )
#    1367 response = raw_response.parse()
#    1368 if self.include_response_headers:
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\openai\_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     360 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\openai\resources\responses\responses.py:866, in Responses.create(self, background, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     828 def create(
#     829     self,
#     830     *,
#    (...)    864     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     865 ) -> Response | Stream[ResponseStreamEvent]:
# --> 866     return self._post(
#     867         "/responses",
#     868         body=maybe_transform(
#     869             {
#     870                 "background": background,
#     871                 "conversation": conversation,
#     872                 "include": include,
#     873                 "input": input,
#     874                 "instructions": instructions,
#     875                 "max_output_tokens": max_output_tokens,
#     876                 "max_tool_calls": max_tool_calls,
#     877                 "metadata": metadata,
#     878                 "model": model,
#     879                 "parallel_tool_calls": parallel_tool_calls,
#     880                 "previous_response_id": previous_response_id,
#     881                 "prompt": prompt,
#     882                 "prompt_cache_key": prompt_cache_key,
#     883                 "prompt_cache_retention": prompt_cache_retention,
#     884                 "reasoning": reasoning,
#     885                 "safety_identifier": safety_identifier,
#     886                 "service_tier": service_tier,
#     887                 "store": store,
#     888                 "stream": stream,
#     889                 "stream_options": stream_options,
#     890                 "temperature": temperature,
#     891                 "text": text,
#     892                 "tool_choice": tool_choice,
#     893                 "tools": tools,
#     894                 "top_logprobs": top_logprobs,
#     895                 "top_p": top_p,
#     896                 "truncation": truncation,
#     897                 "user": user,
#     898             },
#     899             response_create_params.ResponseCreateParamsStreaming
#     900             if stream
#     901             else response_create_params.ResponseCreateParamsNonStreaming,
#     902         ),
#     903         options=make_request_options(
#     904             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     905         ),
#     906         cast_to=Response,
#     907         stream=stream or False,
#     908         stream_cls=Stream[ResponseStreamEvent],
#     909     )
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': 'Your organization must be verified to generate reasoning summaries. Please go to: https://platform.openai.com/settings/organization/general and click on Verify Organization. If you just verified, it can take up to 15 minutes for access to propagate.', 'type': 'invalid_request_error', 'param': 'reasoning.summary', 'code': 'unsupported_value'}}

# %%
# reasoning
# content에 추론 내용과 응답 내용을 묶어서 반환.
# type: reasoning - 추론과정 / text - 최종응답.
result.content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 # reasoning
#       2 # content에 추론 내용과 응답 내용을 묶어서 반환.
#       3 # type: reasoning - 추론과정 / text - 최종응답.
# ----> 4 result.content
#
# NameError: name 'result' is not defined

# %%
model = ChatOpenAI(model = 'gpt-5-mini')

prompt = """
태양계를 구성하는 행성들에 대해 태양에서 가까운 순서대로 알려줘.

결과는 다음 답변형식에 맞춘다.
[답변 형식]
- 행성한국어이름(영어이름) : 간단한 한 줄 설명
"""

res = model.invoke(prompt)

# %%
print(res.content)
# Out:
# - 수성(Mercury) : 태양에 가장 가까운 작은 암석 행성으로 낮과 밤의 온도 차가 매우 큽니다.
# - 금성(Venus) : 두꺼운 이산화탄소 대기와 극심한 온실효과로 매우 뜨거운 지구 크기 행성입니다.
# - 지구(Earth) : 물과 생명이 존재하는 유일하게 알려진 행성으로 다양한 생태계를 가집니다.
# - 화성(Mars) : 붉은 색을 띠는 암석 행성으로 과거 물의 흔적과 탐사 대상이 된 곳입니다.
# - 목성(Jupiter) : 태양계에서 가장 큰 가스 행성으로 강력한 대기와 거대한 적도 소용돌이(대적반)를 가졌습니다.
# - 토성(Saturn) : 눈에 띄는 고리 구조를 가진 가스 행성으로 수많은 위성을 보유합니다.
# - 천왕성(Uranus) : 푸른빛을 띠는 얼음 거성으로 자전축이 거의 옆으로 누워 특이한 계절 변화를 겪습니다.
# - 해왕성(Neptune) : 태양계에서 가장 먼 얼음 거성으로 강한 바람과 깊은 청색을 띠는 행성입니다.

# %% [markdown]
# # Hugging Face 모델 사용
#
# ## Local 에 설치된 모델 사용
# - HuggingFacePipeline 에 Model id를 전달해 Model객체를 생성한다.
# - huggingface transformers 라이브러리를 이용해 model을 생성 한 뒤 HuggingFacePipeline 에 넣어 생성한다.
# - 모델이 local에 없는 경우 다운로드 받는다.
#
# ### HuggingFace 모델을 사용하기 위한 package 설치
# ```bash
# uv pip install torch==2.8
# pip install langchain-huggingface transformers
# ```
# - nvidia GPU가 있는 경우 `torch cuda`  버전을 먼저 설치하고 `langchain-huggingface`를 설치 해야 한다. 아니면 `torch cpu` 버전이 설치된다.

# %%
from langchain_huggingface.llms import HuggingFacePipeline
from transformers import pipeline

model_id = "google/gemma-3-1b-it"
pipe = pipeline(task="text-generation", model=model_id)
model = HuggingFacePipeline.from_model_id(
    task="text-generation",
    model_id=model_id
)
# Out:
# Device set to use cpu
# Device set to use cpu

# %%
res=model.invoke("Huggingface를 소개해줘.")

# %%
print(res)
# Out:
# Huggingface를 소개해줘.
#
# Hugging Face는 딥러닝 모델, 데이터셋, 훈련 프로세스 등을 공유하고 관리하는 플랫폼입니다. 특히 자연어 처리(NLP) 분야에서 매우 유명하며, 다음과 같은 특징을 가지고 있습니다.
#
# **1. 모델 저장소 (Model Hub):**
#
# *   **다양한 모델:** 텍스트 생성, 번역, 질의 응답, 텍스트 분류 등 다양한 NLP 작업에 사용되는 수많은 모델을 제공합니다.
# *   **라이선스 관리:** 각 모델마다 라이선스가 명확하게 지정되어 있어 사용자가 자유롭게 활용할 수 있습니다.
# *   **모델 버전 관리:** 모델 버전 관리를 통해 최신 모델을 쉽게 적용할 수 있습니다.
# *   **모델 검색:**  검색 기능을 통해 원하는 모델을 쉽게 찾을 수 있습니다.
#
# **2.  데이터셋 저장소 (Dataset Hub):**
#
# *   **다양한 데이터셋:** 텍스트 데이터, 이미지 데이터, 오디오 데이터 등 다양한 데이터셋을 제공합니다.
# *   **데이터셋 공유:**  데이터셋을 공유하여 다른 사용자들이 쉽게 활용할 수 있도록 지원합니다.
# *   **데이터셋 버전 관리:** 데이터셋의 버전 관리를 통해

# %%
msg = [
    {
        "role":"user",
        "content":"서울에 주요 여행지 3곳을 알려줘."
    }
]

res = model.invoke(msg)

# %%
print(res)
# Out:
# Human: 서울에 주요 여행지 3곳을 알려줘.
#
# *   **경복궁**
# *   **북촌**
# *   **명동**
#
# **답변:**
#
# 인사드립니다. 서울에 주요 여행지 3곳은 다음과 같습니다.
#
# 1.  **경복궁**
# 2.  **북촌**
# 3.  **명동**
#
# **추가 정보:**
#
# *   **경복궁:** 조선 시대의 아름다운 궁궐로, 역사와 문화의 중심지입니다.
# *   **북촌:** 전통적인 한옥이 밀집된 지역으로, 갤러리, 카페, 음식점 등이 즐비합니다.
# *   **명동:** 한국의 대표적인 쇼핑 거리로, 다양한 브랜드와 볼거리가 있습니다.
#
# **여행 계획:**
#
# *   **경복궁:** 하루에 2~3시간 정도 방문
# *   **북촌:** 하루에 2~3시간 정도 방문
# *   **명동:** 하루에 4~5시간 정도 방문
#
# **여행 팁:**
#
# *   **교통:** 서울은 대중교통이 잘 되어 있어 지하철이나 버스를 이용하면 편리합니다.
# *   **날씨:** 서울의 날씨는 변

# %% [markdown]
# # Anthropic의 Claude 모델 사용
#
# - Anthropic사의 Claude 모델은 (성능 순으로) **Haiku, Sonnet, Opus** 세가지 모델이 있다.
# - [Anthropic사 사이트](https://www.anthropic.com/)
# - [Claude 서비스 사이트](https://claude.ai)
# - API 가격: https://docs.anthropic.com/en/docs/about-claude/pricing
# - Langchain으로 Anthropic claude 모델 사용: https://python.langchain.com/docs/integrations/chat/anthropic/
#
# ## API Key 발급받기
# 1. https://console.anthropic.com/ 이동 후 가입한다.
# 2. 로그인 하면 Dashboard로 이동한다. Dashbord에서 `Get API Keys`를 클릭해 이동한다.
#
# ![anthropic_apikey1.png](figures/anthropic_apikey1.png)
#
# 1. Create key 클릭해서 API Key를 생성한다.
#
# 2. 생성된 API Key를 복사한 뒤 저장. (다시 볼 수 없다.)
#    - 환경변수에 등록
#       - 변수이름: ANTHROPIC_API_KEY
#       - 값: 생성된 키
#
# ## 결제 정보 등록 및 결제 (최소 $5)
#    - Settings -> Billing
#
# ![anthropic_apikey3.png](figures/anthropic_apikey3.png)
#   - 설문조사 후 카드 등록한다.

# %% [markdown]
# ## Anthropic의 Claude 모델 사용
# - 모델 확인: https://docs.anthropic.com/en/docs/about-claude/models

# %% [markdown]
# ### Claude 모델 사용을 위한 package 설치
#
# ```bash
# pip install langchain-anthropic -qU
# ```
# - `anthropic`package도 같이 설치 된다.

# %%
# !uv pip install langchain-anthropic
# Out:
# Resolved 31 packages in 232ms
# Prepared 3 packages in 320ms
# Installed 3 packages in 249ms
#  + anthropic==0.75.0
#  + docstring-parser==0.17.0
#  + langchain-anthropic==1.3.0

# %% [markdown]
# ### Langchain-antropic 사용

# %%
from langchain_anthropic import ChatAnthropic# , Anthropic 지원하는 모델이 다른 것 같다.
from dotenv import load_dotenv
load_dotenv(override=True)
model="claude-sonnet-4-5"
llm = ChatAnthropic(
    model=model,
    temperature=0.2,
    max_tokens=1024,
)
result = llm.invoke("Anthropic의 LLM 모델은 어떤 것이 있는지 알려주고 간단한 설명도 부탁해.")

# %%
print(result.content)

# %% [markdown]
# # Ollama 모델 사용
#
# Ollama는 로컬 환경에서 오픈소스 LLM을 쉽게 실행할 수 있도록 지원하는 플랫폼이다.
#
# - 주요특징
#
#   - **다양한 모델 지원**: Llama 3, Mistral, Phi 3 등 여러 오픈소스 LLM을 지원.
#   - **편리한 모델 설치 및 실행**: 간단한 명령어로 모델을 다운로드하고 실행할 수 있습니다.
#   - **운영체제 호환성**: macOS, Windows, Linux 등 다양한 운영체제에서 사용 가능하다.
#
# ## 설치
# - https://ollama.com/download 에서 운영체제에 맞는 버전을 설치
# -  Windows 버전은 특별한 설정 없이 바로 install 실행하면 된다.
#
# ## 모델 검색
# - https://ollama.com/search
# - 모델을 검색한 후 상세페이지로 이동하면 해당 모델을 실행할 수있는 명령어가 나온다.
#
# ![ollama_down.png](figures/ollama_down.png)
#
#
# ## 실행 명령어
# - `ollama pull 모델명`
#   - 모델을 다운로드 받는다. (다운로드만 받고 실행은 하지 않은다.)
# - `ollama run 모델명`
#   - 모델을 실행한다.
#   - 최초 실행시 모델을 다운로드 받는다.
#   - 명령프롬프트 상에서 `프롬프트`를 입력하면 모델의 응답을 받을 수 있다.
#
# ## Python/Langchain API
# - ollama api
#   - https://github.com/ollama/ollama-python
# - langchain-ollama
#   - https://python.langchain.com/docs/integrations/chat/ollama/
# - 설치
#   - `pip install langchain-ollama`
#   - `ollama` package도 같이 설치 된다.

# %% [markdown]
# ## Langchain-ollama 사용

# %%
# !uv pip install langchain-ollama
# Out:
# Resolved 27 packages in 302ms
# Prepared 2 packages in 67ms
# Installed 2 packages in 60ms
#  + langchain-ollama==1.0.1
#  + ollama==0.6.1

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(
    model ="gemma3:1b" # 명령프롬프트에서 ollema run ~ 하고 실행할 때 사용한 이름.
)

res = model.invoke("안녕하세요")

# %%
print(res.content)
# Out:
# 네, 안녕하세요! 무엇을 도와드릴까요? 😊
#
# 무엇이든 질문하시면 주저하지 말고 하세요!

# %%
res = model.invoke("AI란 무엇인가요?")

res
# Out:
# AIMessage(content='AI(인공지능)는 인간의 지능적인 행동을 모방하는 기계 또는 컴퓨터 시스템을 의미합니다. 단순히 데이터를 처리하는 것 이상으로, 스스로 학습하여 문제를 해결하고 의사 결정 능력을 발휘하며, 인간처럼 생각하거나 창작할 수 있는 능력을 갖는다고 하는데요, 이 이상적인 능력을 갖추기 위해 다양한 기술을 결합하고 있습니다.\n\n**AI의 핵심적인 세 가지 핵심 개념**은 다음과 같아요.\n\n1. **머신러닝(Machine Learning):**\n   * 데이터를 통해 스스로 학습하고 패턴을 발견하여 모델을 만들어나가는 기술입니다.\n   * 예를 들어, 이미지 인식 시스템이 스스로 학습하여 고양이의 특징을 파악하거나, 스팸 메일 분류 시스템이 학습한 데이터를 기반으로 스팸 여부를 판단할 수 있습니다.\n\n2. **딥 러닝(Deep Learning):**\n   * 인공지능의 한 부분으로, 인공 뉴런 구조를 가진 딥 신경망(Neural Network)을 사용하여 데이터를 학습하는 기술입니다.\n   * 이미지, 영상, 음성 등에 대한 정교한 작업을 할 수 있어 이미지 인식, 음성 인식, 텍스트 마이닝 등에서 매우 뛰어난 성능을 보여줍니다.\n\n3. **자연어 처리(NLP):**\n    * 인간이 사용하는 언어를 데이터로 이해하고 처리하는 기술입니다.\n    * 컴퓨터가 사람의 언어를 읽고, 해석하고, 생성할 수 있도록 하는 기술입니다.\n    * 예를 들어, 인공지능이 챗봇이 되어 사용자와 자연어로 대화하거나, 자동 번역 시스템이 다른 언어로 된 문서를 번역해주는 기능을 합니다.\n\n**AI는 더 구체적인 활용 분야도 무궁무진합니다.** \n\n*   **음악:** 작곡, 편곡, 음악 스타일 분석\n*   **의료:** 질병 예측, 이미지 진단\n*   **금융:** 사기 탐지, 주식 거래\n*   **배경:** 검색 엔진, 상품 추천, 자율 주행\n\n**요약하자면, AI는** 데이터를 분석하고, 규칙을 찾고, 결과를 개선하며, 의사 결정 등 인간의 지능적인 행위처럼 행동하는 컴퓨터 시스템이라는 의미를 가집니다.\n\n더 자세히 알아보고 싶은 내용이 있다면, 어떤 점이 더 궁금하신지 알려주시면 더욱 자세히 답변드릴 수 있습니다. 예를 들어, 다음과 같이 질문을 해주시면 도움이 됩니다.\n\n*   AI 개발 방법은 무엇인가요?\n*   딥 러닝은 왜 중요할까요?\n*   AI는 미래 사회에서 어떤 영향을 미칠까요?', additional_kwargs={}, response_metadata={'model': 'gemma3:1b', 'created_at': '2025-12-15T06:10:32.5355144Z', 'done': True, 'done_reason': 'stop', 'total_duration': 15229647600, 'load_duration': 160685300, 'prompt_eval_count': 15, 'prompt_eval_duration': 110194300, 'eval_count': 561, 'eval_duration': 14424640200, 'logprobs': None, 'model_name': 'gemma3:1b', 'model_provider': 'ollama'}, id='lc_run--019b20a1-8e59-7f92-b0d0-3a041cd77b4a-0', usage_metadata={'input_tokens': 15, 'output_tokens': 561, 'total_tokens': 576})

# %%
print(res.content)
# Out:
# AI(인공지능)는 인간의 지능적인 행동을 모방하는 기계 또는 컴퓨터 시스템을 의미합니다. 단순히 데이터를 처리하는 것 이상으로, 스스로 학습하여 문제를 해결하고 의사 결정 능력을 발휘하며, 인간처럼 생각하거나 창작할 수 있는 능력을 갖는다고 하는데요, 이 이상적인 능력을 갖추기 위해 다양한 기술을 결합하고 있습니다.
#
# **AI의 핵심적인 세 가지 핵심 개념**은 다음과 같아요.
#
# 1. **머신러닝(Machine Learning):**
#    * 데이터를 통해 스스로 학습하고 패턴을 발견하여 모델을 만들어나가는 기술입니다.
#    * 예를 들어, 이미지 인식 시스템이 스스로 학습하여 고양이의 특징을 파악하거나, 스팸 메일 분류 시스템이 학습한 데이터를 기반으로 스팸 여부를 판단할 수 있습니다.
#
# 2. **딥 러닝(Deep Learning):**
#    * 인공지능의 한 부분으로, 인공 뉴런 구조를 가진 딥 신경망(Neural Network)을 사용하여 데이터를 학습하는 기술입니다.
#    * 이미지, 영상, 음성 등에 대한 정교한 작업을 할 수 있어 이미지 인식, 음성 인식, 텍스트 마이닝 등에서 매우 뛰어난 성능을 보여줍니다.
#
# 3. **자연어 처리(NLP):**
#     * 인간이 사용하는 언어를 데이터로 이해하고 처리하는 기술입니다.
#     * 컴퓨터가 사람의 언어를 읽고, 해석하고, 생성할 수 있도록 하는 기술입니다.
#     * 예를 들어, 인공지능이 챗봇이 되어 사용자와 자연어로 대화하거나, 자동 번역 시스템이 다른 언어로 된 문서를 번역해주는 기능을 합니다.
#
# **AI는 더 구체적인 활용 분야도 무궁무진합니다.**
#
# *   **음악:** 작곡, 편곡, 음악 스타일 분석
# *   **의료:** 질병 예측, 이미지 진단
# *   **금융:** 사기 탐지, 주식 거래
# *   **배경:** 검색 엔진, 상품 추천, 자율 주행
#
# **요약하자면, AI는** 데이터를 분석하고, 규칙을 찾고, 결과를 개선하며, 의사 결정 등 인간의 지능적인 행위처럼 행동하는 컴퓨터 시스템이라는 의미를 가집니다.
#
# 더 자세히 알아보고 싶은 내용이 있다면, 어떤 점이 더 궁금하신지 알려주시면 더욱 자세히 답변드릴 수 있습니다. 예를 들어, 다음과 같이 질문을 해주시면 도움이 됩니다.
#
# *   AI 개발 방법은 무엇인가요?
# *   딥 러닝은 왜 중요할까요?
# *   AI는 미래 사회에서 어떤 영향을 미칠까요?

# %%
prompt = """
다음 내용을 3문장으로 요약해줘.
<요약할 내용>
AI(인공지능)는 인간의 지능적인 행동을 모방하는 기계 또는 컴퓨터 시스템을 의미합니다. 단순히 데이터를 처리하는 것 이상으로, 스스로 학습하여 문제를 해결하고 의사 결정 능력을 발휘하며, 인간처럼 생각하거나 창작할 수 있는 능력을 갖는다고 하는데요, 이 이상적인 능력을 갖추기 위해 다양한 기술을 결합하고 있습니다.

**AI의 핵심적인 세 가지 핵심 개념**은 다음과 같아요.

1. **머신러닝(Machine Learning):**
   * 데이터를 통해 스스로 학습하고 패턴을 발견하여 모델을 만들어나가는 기술입니다.
   * 예를 들어, 이미지 인식 시스템이 스스로 학습하여 고양이의 특징을 파악하거나, 스팸 메일 분류 시스템이 학습한 데이터를 기반으로 스팸 여부를 판단할 수 있습니다.

2. **딥 러닝(Deep Learning):**
   * 인공지능의 한 부분으로, 인공 뉴런 구조를 가진 딥 신경망(Neural Network)을 사용하여 데이터를 학습하는 기술입니다.
   * 이미지, 영상, 음성 등에 대한 정교한 작업을 할 수 있어 이미지 인식, 음성 인식, 텍스트 마이닝 등에서 매우 뛰어난 성능을 보여줍니다.

3. **자연어 처리(NLP):**
    * 인간이 사용하는 언어를 데이터로 이해하고 처리하는 기술입니다.
    * 컴퓨터가 사람의 언어를 읽고, 해석하고, 생성할 수 있도록 하는 기술입니다.
    * 예를 들어, 인공지능이 챗봇이 되어 사용자와 자연어로 대화하거나, 자동 번역 시스템이 다른 언어로 된 문서를 번역해주는 기능을 합니다.

**AI는 더 구체적인 활용 분야도 무궁무진합니다.** 

*   **음악:** 작곡, 편곡, 음악 스타일 분석
*   **의료:** 질병 예측, 이미지 진단
*   **금융:** 사기 탐지, 주식 거래
*   **배경:** 검색 엔진, 상품 추천, 자율 주행

**요약하자면, AI는** 데이터를 분석하고, 규칙을 찾고, 결과를 개선하며, 의사 결정 등 인간의 지능적인 행위처럼 행동하는 컴퓨터 시스템이라는 의미를 가집니다.
...

*   AI 개발 방법은 무엇인가요?
*   딥 러닝은 왜 중요할까요?
*   AI는 미래 사회에서 어떤 영향을 미칠까요?
</요약할 내용>
"""

res=model.invoke(prompt)

# %%
print(res.content)
# Out:
# 다음과 요약된 내용입니다:
#
# AI는 인간 지능을 모방한 컴퓨터 시스템으로, 데이터를 활용하여 스스로 학습하고 문제 해결 능력을 갖습니다. 이를 통해 다양한 분야에서 활용되며, 현재 머신러닝, 딥 러닝, 자연어 처리 등의 기술을 융합하고 있습니다. 이러한 기술들은 음악, 의료, 금융 등 다양한 분야에서 혁신적인 변화를 가져올 수 있는 잠재력을 지니고 있습니다.
#
# **요약하자면**, AI는 데이터를 분석하고 문제를 해결하는 능력을 가지고 있으며, 그 기술 발전은 미래 사회에 큰 영향을 미칠 것으로 예상됩니다.

# %% [markdown]
# # Gemini
# - 모델: https://ai.google.dev/gemini-api/docs/models?hl=ko
# - 가격정책: https://ai.google.dev/gemini-api/docs/pricing?hl=ko
#
# ## API Key 생성
#
# 1. https://aistudio.google.com/api-keys
#     - 연결 후 로그인(구글계정)
# 2. `API Key 만들기` 선택
#
#     ![img](figures/gemini_api1.png)
#
# 3. `키이름 지정`하고 `가져온 프로젝트 선택`에서 프로젝트 선택(없으면 만든다) 하고 키 만들기
# 4. 키가 생성되면 왼쪽에 복사 아이콘을 클릭하면 키가 복사된다.
#
# ## 환경변수
# - `GOOGLE_API_KEY` 환경변수에 생성된 API Key를 등록한다.
# ## 설치
# - `pip install langchain_google_genai`

# %%
#  !uv pip install langchain_google_genai
# Out:
# Resolved 36 packages in 406ms
# Prepared 9 packages in 328ms
# Installed 9 packages in 1.05s
#  + cachetools==6.2.3
#  + filetype==1.2.0
#  + google-auth==2.43.0
#  + google-genai==1.55.0
#  + langchain-google-genai==4.0.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + rsa==4.9.1
#  + websockets==15.0.1

# %%
load_dotenv(override=True)
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", #무료 : 분당 60회, 하루 1000회 무료.
)

res=model.invoke("gemini와 gemma 모델의 차이는 무엇인가요?")

# %%
print(res.content)
# Out:
# Gemini와 Gemma는 모두 Google에서 개발한 인공지능 모델이지만, **목표, 규모, 기능, 그리고 접근 방식**에서 중요한 차이가 있습니다. 쉽게 비유하자면, Gemini는 Google의 "최첨단 플래그십 슈퍼컴퓨터"이고, Gemma는 개발자와 연구자를 위한 "고성능 미니PC 또는 워크스테이션"이라고 할 수 있습니다.
#
# 다음은 두 모델의 주요 차이점을 비교한 것입니다.
#
# ---
#
# ### Gemini (제미나이)
#
# *   **핵심 목적:** Google의 **가장 강력하고 범용적인(general-purpose) AI 모델**로, 최첨단 성능을 목표로 합니다.
# *   **모델 규모 및 성능:**
#     *   매우 크고 복잡하며, 다양한 크기(Ultra, Pro, Nano 등)로 제공되지만, 일반적으로 공개된 Gemma보다 훨씬 큰 규모를 가집니다.
#     *   최상위 성능을 자랑하며, 복잡한 추론, 문제 해결, 창의적 글쓰기, 코딩 등 다양한 분야에서 최고 수준의 능력을 발휘합니다.
# *   **모달리티:**
#     *   **멀티모달(Multimodal) 모델**입니다. 텍스트뿐만 아니라 이미지, 오디오, 비디오 등 다양한 형태의 정보를 이해하고 생성할 수 있습니다. 이것이 Gemini의 가장 큰 특징 중 하나입니다.
# *   **접근성 및 라이선스:**
#     *   **독점(Proprietary) 모델**입니다. 모델 가중치(weights)가 공개되지 않으며, Google의 API(Vertex AI, Google AI Studio)를 통해 접근하거나, Google의 서비스(예: Gemini 챗봇, Google Workspace 통합 등)를 통해 사용합니다.
#     *   상업적 사용을 위해서는 비용을 지불해야 합니다.
# *   **주요 사용 사례:**
#     *   고급 챗봇 및 대화형 AI 시스템
#     *   복잡한 데이터 분석 및 추론
#     *   고품질 콘텐츠(텍스트, 이미지 등) 생성
#     *   코드 생성 및 디버깅
#     *   기업용 솔루션 및 서비스에 통합
#     *   Google의 핵심 AI 기능 구동
#
# ---
#
# ### Gemma (젬마)
#
# *   **핵심 목적:** Google의 최신 연구를 기반으로 구축된 **경량(lightweight)의 오픈 웨이트(open-weight) 모델**입니다. 개발자와 연구자들이 쉽게 접근하고 커스터마이징하여 혁신을 촉진하는 데 중점을 둡니다.
# *   **모델 규모 및 성능:**
#     *   Gemini에 비해 **규모가 작습니다** (예: 2B, 7B 매개변수).
#     *   작은 규모에도 불구하고 동급 모델 중에서는 뛰어난 성능을 보여주며, 효율성과 속도에 최적화되어 있습니다.
#     *   Gemini와 같은 최상위 모델만큼의 복잡한 추론 능력은 아니지만, 특정 작업에 대한 미세 조정(fine-tuning)을 통해 매우 강력해질 수 있습니다.
# *   **모달리티:**
#     *   주로 **텍스트 기반(text-based) 모델**입니다. Gemini처럼 다양한 모달리티를 직접 처리하지는 않습니다. (물론, 특정 방식으로 이미지/오디오 처리를 위한 통합은 가능할 수 있습니다.)
# *   **접근성 및 라이선스:**
#     *   **오픈 웨이트(Open-weight) 모델**입니다. Google은 모델의 가중치를 공개하여, 개발자와 연구자들이 모델을 다운로드하여 로컬에서 실행하거나, 직접 수정하고 미세 조정할 수 있도록 합니다.
#     *   상업적 사용이 허용되는 라이선스(예: Apache 2.0)로 제공되어, 개발자들이 자신들의 애플리케이션에 통합하여 배포할 수 있습니다.
# *   **주요 사용 사례:**
#     *   온디바이스(on-device) AI 애플리케이션 (스마트폰, IoT 기기 등)
#     *   데이터 프라이버시가 중요한 환경에서의 AI 구현
#     *   특정 도메인 및 작업에 최적화된 맞춤형 모델 개발 (미세 조정을 통해)
#     *   오픈 소스 커뮤니티의 AI 연구 및 개발 촉진
#     *   프로토타이핑 및 교육 목적
#
# ---
#
# ### 요약 비교표
#
# | 특성       | Gemini (제미나이)                                       | Gemma (젬마)                                             |
# | :--------- | :------------------------------------------------------ | :------------------------------------------------------- |
# | **핵심 목적**  | Google의 최첨단 범용 AI, 최고 성능 지향              | 개발자/연구자용 경량 오픈 웨이트 모델, 혁신 촉진        |
# | **모델 규모**  | 매우 큼, 복잡 (Ultra, Pro, Nano 등 다양한 크기)        | 상대적으로 작음 (2B, 7B 등), 효율성에 중점             |
# | **모달리티**  | **멀티모달 (텍스트, 이미지, 오디오, 비디오 등)**         | **주로 텍스트 기반**                                     |
# | **접근성**   | **독점 모델**, Google API 또는 서비스로 접근           | **오픈 웨이트 모델**, 가중치 공개, 다운로드 및 로컬 실행 가능 |
# | **라이선스** | 상업적 API 사용 시 비용 발생                         | 상업적 사용 가능한 오픈 라이선스                       |
# | **주요 용도** | 복잡한 추론, 고급 챗봇, 범용 AI, Google 서비스 통합 | 온디바이스 AI, 미세 조정, 연구, 프로토타이핑, 특정 도메인 앱 |
# | **개발 철학** | AI 기술의 한계 확장, 최고 성능 구현                 | AI의 민주화, 개발자 생태계 활성화, 효율성 및 접근성 제공 |
#
# ---
#
# 결론적으로, **Gemini는 Google의 최전선에서 AI 기술의 정점을 보여주는 종합 솔루션**이라면, **Gemma는 Google의 최신 기술을 바탕으로 개발자들이 더 많은 AI 애플리케이션을 직접 만들고 혁신할 수 있도록 지원하는 도구이자 기반 기술**입니다.

# %%
from IPython.display import Markdown

Markdown(res.content)
# Out:
# Gemini와 Gemma는 모두 Google에서 개발한 인공지능 모델이지만, **목표, 규모, 기능, 그리고 접근 방식**에서 중요한 차이가 있습니다. 쉽게 비유하자면, Gemini는 Google의 "최첨단 플래그십 슈퍼컴퓨터"이고, Gemma는 개발자와 연구자를 위한 "고성능 미니PC 또는 워크스테이션"이라고 할 수 있습니다.
#
# 다음은 두 모델의 주요 차이점을 비교한 것입니다.
#
# ---
#
# ### Gemini (제미나이)
#
# *   **핵심 목적:** Google의 **가장 강력하고 범용적인(general-purpose) AI 모델**로, 최첨단 성능을 목표로 합니다.
# *   **모델 규모 및 성능:**
#     *   매우 크고 복잡하며, 다양한 크기(Ultra, Pro, Nano 등)로 제공되지만, 일반적으로 공개된 Gemma보다 훨씬 큰 규모를 가집니다.
#     *   최상위 성능을 자랑하며, 복잡한 추론, 문제 해결, 창의적 글쓰기, 코딩 등 다양한 분야에서 최고 수준의 능력을 발휘합니다.
# *   **모달리티:**
#     *   **멀티모달(Multimodal) 모델**입니다. 텍스트뿐만 아니라 이미지, 오디오, 비디오 등 다양한 형태의 정보를 이해하고 생성할 수 있습니다. 이것이 Gemini의 가장 큰 특징 중 하나입니다.
# *   **접근성 및 라이선스:**
#     *   **독점(Proprietary) 모델**입니다. 모델 가중치(weights)가 공개되지 않으며, Google의 API(Vertex AI, Google AI Studio)를 통해 접근하거나, Google의 서비스(예: Gemini 챗봇, Google Workspace 통합 등)를 통해 사용합니다.
#     *   상업적 사용을 위해서는 비용을 지불해야 합니다.
# *   **주요 사용 사례:**
#     *   고급 챗봇 및 대화형 AI 시스템
#     *   복잡한 데이터 분석 및 추론
#     *   고품질 콘텐츠(텍스트, 이미지 등) 생성
#     *   코드 생성 및 디버깅
#     *   기업용 솔루션 및 서비스에 통합
#     *   Google의 핵심 AI 기능 구동
#
# ---
#
# ### Gemma (젬마)
#
# *   **핵심 목적:** Google의 최신 연구를 기반으로 구축된 **경량(lightweight)의 오픈 웨이트(open-weight) 모델**입니다. 개발자와 연구자들이 쉽게 접근하고 커스터마이징하여 혁신을 촉진하는 데 중점을 둡니다.
# *   **모델 규모 및 성능:**
#     *   Gemini에 비해 **규모가 작습니다** (예: 2B, 7B 매개변수).
#     *   작은 규모에도 불구하고 동급 모델 중에서는 뛰어난 성능을 보여주며, 효율성과 속도에 최적화되어 있습니다.
#     *   Gemini와 같은 최상위 모델만큼의 복잡한 추론 능력은 아니지만, 특정 작업에 대한 미세 조정(fine-tuning)을 통해 매우 강력해질 수 있습니다.
# *   **모달리티:**
#     *   주로 **텍스트 기반(text-based) 모델**입니다. Gemini처럼 다양한 모달리티를 직접 처리하지는 않습니다. (물론, 특정 방식으로 이미지/오디오 처리를 위한 통합은 가능할 수 있습니다.)
# *   **접근성 및 라이선스:**
#     *   **오픈 웨이트(Open-weight) 모델**입니다. Google은 모델의 가중치를 공개하여, 개발자와 연구자들이 모델을 다운로드하여 로컬에서 실행하거나, 직접 수정하고 미세 조정할 수 있도록 합니다.
#     *   상업적 사용이 허용되는 라이선스(예: Apache 2.0)로 제공되어, 개발자들이 자신들의 애플리케이션에 통합하여 배포할 수 있습니다.
# *   **주요 사용 사례:**
#     *   온디바이스(on-device) AI 애플리케이션 (스마트폰, IoT 기기 등)
#     *   데이터 프라이버시가 중요한 환경에서의 AI 구현
#     *   특정 도메인 및 작업에 최적화된 맞춤형 모델 개발 (미세 조정을 통해)
#     *   오픈 소스 커뮤니티의 AI 연구 및 개발 촉진
#     *   프로토타이핑 및 교육 목적
#
# ---
#
# ### 요약 비교표
#
# | 특성       | Gemini (제미나이)                                       | Gemma (젬마)                                             |
# | :--------- | :------------------------------------------------------ | :------------------------------------------------------- |
# | **핵심 목적**  | Google의 최첨단 범용 AI, 최고 성능 지향              | 개발자/연구자용 경량 오픈 웨이트 모델, 혁신 촉진        |
# | **모델 규모**  | 매우 큼, 복잡 (Ultra, Pro, Nano 등 다양한 크기)        | 상대적으로 작음 (2B, 7B 등), 효율성에 중점             |
# | **모달리티**  | **멀티모달 (텍스트, 이미지, 오디오, 비디오 등)**         | **주로 텍스트 기반**                                     |
# | **접근성**   | **독점 모델**, Google API 또는 서비스로 접근           | **오픈 웨이트 모델**, 가중치 공개, 다운로드 및 로컬 실행 가능 |
# | **라이선스** | 상업적 API 사용 시 비용 발생                         | 상업적 사용 가능한 오픈 라이선스                       |
# | **주요 용도** | 복잡한 추론, 고급 챗봇, 범용 AI, Google 서비스 통합 | 온디바이스 AI, 미세 조정, 연구, 프로토타이핑, 특정 도메인 앱 |
# | **개발 철학** | AI 기술의 한계 확장, 최고 성능 구현                 | AI의 민주화, 개발자 생태계 활성화, 효율성 및 접근성 제공 |
#
# ---
#
# 결론적으로, **Gemini는 Google의 최전선에서 AI 기술의 정점을 보여주는 종합 솔루션**이라면, **Gemma는 Google의 최신 기술을 바탕으로 개발자들이 더 많은 AI 애플리케이션을 직접 만들고 혁신할 수 있도록 지원하는 도구이자 기반 기술**입니다.
