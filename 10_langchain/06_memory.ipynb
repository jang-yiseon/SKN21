# %% [markdown]
# # Langchain의 Memory 기능
#
# **Memory**란 사용자가 대규모 언어 모델(LLM, Large Language Model)과 주고받은 대화 내용을 저장하고 이를 이후의 대화에 활용하는 기능을 말한다.
#
# ## 왜 Memory가 필요한가?
#
# - 기본적으로 LLM은 상태 비저장(stateless) 모델이다.
#   - 의미: 한 번의 질문에 대해 답변을 제공하고, 그 이후에는 해당 질문과 답변 내용을 기억하지 못한다. 따라서 사용자가 이전 대화에 기반한 후속 질문을 하면, 모델은 맥락을 이해하지 못하고 정확한 답변을 하지 못한다.
# - 이 문제를 해결하기 위해, 지금까지의 대화 내용을 저장하고 이후 질문을 할 때 함께 제공하여 맥락을 이어갈 수 있도록 하는 기능이 바로 Memory이다.
#
# ## Memory의 동작 방식
#
# - 사용자의 질문과 LLM의 응답을 저장한다.
# - 이후 사용자가 새로운 질문을 하면, **저장된 이전 대화 내용과 함께 모델에 전달**하여 자연스러운 연속 대화가 가능하도록 한다.
# - **주의**:
#   - 대화 이력이 너무 길어지면 현재 질문과 관련없는 내용이 많아지게 되고 이것이 noise가 되어 LLM이 부정확한 응답을 할 수도 있다.
#   - LLM마다 입력으로 받을 수 있는 [**토큰(Token)** 수에 제한](https://platform.openai.com/docs/models/compare)이 있다. 그래서 대화 내용을 무한정 저장하고 전달할 수 없다.
#   - Close source llm을 사용하는 경우 대화 이력이 길어지면 그많은 많은 토큰을 입력하게 되어 비용이 늘어나게 된다.
#   - 그래서 위와 같은 이유로 대화 이력을 모두 보내기 보다 최근 일부만 보내거나 요약하는 등의 관리가 필요하다.
#
# ![memory.png](figures/memory.png)

# %% [markdown]
# # 메시지 저장소: ChatMessageHistory
# 메시지 기록을 관리하는 객체로 어디에 저장느냐에 따라 여러 클래스들이 구현되어 제공된다.
#
# ## 종류
# - **BaseChatMessageHistory**
#     - 모든 메시지 기록 저장소 클래스의 **기본(최상위) 클래스**이다. 메시지를 저장하고 검색하는 기능을 정의하고 있으며, 이 클래스를 상속받아 다양한 저장소 방식이 구현된다.
# - **InMemoryChatMessageHistory**
#     - 메시지를 **메모리에 저장**하는 방식이다. 속도가 빠르지만, 프로그램을 종료하면 저장된 메시지는 사라진다.
# - 외부 저장소 연동
#     - Langchain은 다양한 **3rd-party 저장소**와 연동할 수 있다. 예를 들어 SQLite, PostgreSQL, Redis, MongoDB 등을 사용해 메시지를 영구적으로 저장할 수 있다.
#     - https://python.langchain.com/docs/integrations/memory/

# %%
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage # Role별 message 객체

# ("user/human", "message") → HummanMessage(content="message")
# ("ai/assistant", "message") → AIMessage(content="message") : LLM 응답 결과가 들어옴
# ("system", "message") → SystemMessage(content="message")

# %%
message_history = InMemoryChatMessageHistory() # 메세지 저장소 객체 생성
# 추가
message_history.add_message(SystemMessage("당신은 여행 가이드 Assistant입니다."))
message_history.add_message(HumanMessage("서울의 여행지 세곳을 추천해주세요."))
message_history.add_message(AIMessage("경복궁, 남산, 창경궁을 추천합니다."))

# %%
# 저장된 messages 조회
message_history.messages
# Out:
# [SystemMessage(content='당신은 여행 가이드 Assistant입니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='서울의 여행지 세곳을 추천해주세요.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='경복궁, 남산, 창경궁을 추천합니다.', additional_kwargs={}, response_metadata={})]

# %%
# Message History로 RDB 사용
from langchain_community.chat_message_histories import SQLChatMessageHistory
from sqlalchemy import create_engine # DB와 연결을위해 필요

# SQLite에 저장.
engine = create_engine("sqlite:///message_history.sqlite")

# mysql -pymysql 설치
# engine = create_engine("mysql+pymysql://username:password@127.0.0.1:3306/DB name")

sql_message_history = SQLChatMessageHistory(
    session_id="caht-1", # 대화 ID. 대화별로 따로 메세지를 저장.
    connection=engine    
)

sql_message_history.add_message(SystemMessage("당신은 여행 가이드 Assistant입니다."))
sql_message_history.add_message(HumanMessage("서울의 여행지 세곳을 추천해주세요."))
sql_message_history.add_message(AIMessage("경복궁, 남산, 창경궁을 추천합니다."))

# %%
sql_message_history.messages
# Out:
# [SystemMessage(content='당신은 여행 가이드 Assistant입니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='서울의 여행지 세곳을 추천해주세요.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='경복궁, 남산, 창경궁을 추천합니다.', additional_kwargs={}, response_metadata={})]

# %%
sql_message_history2 = SQLChatMessageHistory(
    session_id="caht-2",
    connection=engine    
)

sql_message_history2.add_message(SystemMessage("너는 유능한 비서야."))
sql_message_history2.add_message(HumanMessage("안녕."))
sql_message_history2.add_message(AIMessage("무엇을 도와 드릴까요?"))

# %%
sql_message_history2.messages
# Out:
# [SystemMessage(content='너는 유능한 비서야.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='안녕.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='무엇을 도와 드릴까요?', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# # RunnableWithMessageHistory
#
# - **`RunnableWithMessageHistory`**는 `ChatMessageHistory`와 `Runnable Chain`을 이용해 대화 이력을 관리하면서 대화할 수있도록 처리하는 `Runnable` 이다.
#   - 대화형 애플리케이션에서는 사용자와 AI 간의 여러 번의 주고받는 대화를 통해 작업을 수행한다. 이때, 이전 대화 내용을 기억하지 못하면 일관성 없는 응답이 발생할 수 있다.
#   - `RunnableWithMessageHistory`는 이러한 문제를 해결하고 대화 흐름을 자연스럽게 유지하도록 설계되었다.
#
# ## 특징
#
# - 체인이 실행될 때마다 **대화 메시지를 자동으로 기록**하여 개발자가 별도로 상태를 관리하지 않아도 된다.
# - `session_id`(대화 ID)를 사용하여 대화를 구분한다.
#   - 동일한 `session_id`를 사용하면 이전 대화를 이어갈 수 있다.
#   - 새로운 `session_id`를 사용하면 새로운 대화로 인식된다.
#
# ## 생성
#
# `RunnableWithMessageHistory`는 다음과 같은 요소들을 initializer에 전달해 생성한다.
#
# - **runnable**: 실제 작업을 수행하는 체인(`Runnable`) 객체이다.
# - **get_session_history**: 주어진 `session_id`에 해당하는 메시지 기록 저장소(`ChatMessageHistory`) 객체를 반환하는 함수이다.
# - **input_messages_key**: 사용자 입력 메시지를 저장할 입력 필드의 이름이다.
# - **history_messages_key**: 저장된 이전 대화 메시지를 불러올 필드의 이름이다.
#
# 이를 통해 체인을 실행할 때마다 이전 메시지가 자동으로 전달되고, 새로운 메시지도 기록된다.
#
# [Langchain Memory Integration 문서](https://python.langchain.com/docs/integrations/memory/)

# %% [markdown]
# ## RunnableWithMessageHistory를 이용해 Chain 구성

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_openai import ChatOpenAI
from langchain_community.chat_message_histories import SQLChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory
from sqlalchemy import create_engine
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
prompt = ChatPromptTemplate(
    [
        ("system",("당신은 AI 분야의 전문 Assistant입니다." 
                   "답변은 20단어 이내로 해주세요."
                   "정확한 답변을 모를 경우 모른다고 답하세요.")), # ','를 넣으면 튜플이 되어버림!
        MessagesPlaceholder(variable_name="history", optional=True), #("placeholder","{history}") 이렇게 하는거랑 앞에 MessagesPlace랑 같은 역할임.
        ("user","{query}")
    ]
)

model = ChatOpenAI(model="gpt-5-mini")
chain = prompt | model

# %%
def get_message_history(session_id:str) ->  SQLChatMessageHistory:
    """
    session_id의 대화내역을 관리하는 ChatMessageHistory를 반환하는 함수.
    Args :
        session_id(str) : 대화id
    Return
        SQLChatMessagesHistory
    """

    engine = create_engine("sqlite:///chat_message_history.sqkite")
    message_history = SQLChatMessageHistory(
        session_id=session_id,
        connection=engine
    )
    
    return message_history

# %%
# RunnableWithMessageHistory 생성(Runnable)
chain_with_history = RunnableWithMessageHistory(
    runnable=chain, # prompt에 넣으면 model에 전달해줌
    input_messages_key="query", # prompt template에서 사용자 질문을 넣을 input variable
    history_messages_key="history", # 기존 대화 내역을 넣을 input_variable 
    get_session_history=get_message_history # ssesion_id의 대화를 관리하는 ChatMessageHistory를 반환하는 callable
)

# %%
# 호출(llm요청).invoke(input_data, config)
res = chain_with_history.invoke(
    {"query":"내 이름은 장이선입니다."}, # input_data
    {"configurable":{"session_id":"chat-10"}}
)

# %%
print(res.content)
# Out:
# 알겠습니다, 장이선님.

# %%
chain_with_history.invoke(
    {"query":"내 이름이 뭐지?"},
    {"configurable":{"session_id":"chat-11"}}
)
# Out:
# AIMessage(content='모르겠습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 141, 'prompt_tokens': 74, 'total_tokens': 215, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CoNi8p5ZMuETDVQbdXbwHovpgpExu', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b352b-2b55-7fc0-82ed-d066624cc709-0', usage_metadata={'input_tokens': 74, 'output_tokens': 141, 'total_tokens': 215, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})

# %%
# 1. 대화 id를 입력
session_id = input("대화 ID:")
config = {"configurable":{"session_id":session_id}}

# 2. 대화 진행 - !quit 입력시 대화 종료
query = input("User :")
while True:
    if query == "!quit":
        print(">>>>>>>>>종료>>>>>>>>>")
        break
    res = chain_with_history.invoke({"query":query}, config)
    print(">>>USer :",query)
    print("<<<AI: ", res.content)
    query = input("User :")
# Out:
# >>>USer : 내 이름은 장이선이야
# <<<AI:  알겠습니다, 장이선님. 무엇을 도와드릴까요?
# >>>USer : 내 이름이뭐라고?
# <<<AI:  당신의 이름은 장이선입니다.
# >>>>>>>>>종료>>>>>>>>>

# %%
# 메시지 히스토리 줄여서 보내기. 요약처리, 최근 몇개의 대화내역만 보내기.
# 최근 내역만 잘라내는 함수 - trimm_messages()

# 메세지를 trimming하는 runnable
from langchain_core.messages import trim_messages
def trimming_history(input_data:dict) -> dict:
    """
    RunnableWithMessageHistory의 runnable chain의 첫번째 요소로 들어갈 함수.
    input dictionary에 메세지 히스토리와 입력 query를 전달받는다.
    {history_messages_key : 히스토리, input_messages_key : 입력 쿼리, ...}
    message history를 tirmming해서 다음 chain요소(prompt)에 전달
    """
    
    # MAX_token은 대략 어디까지 줄일지의 기준. trimming을 할 때 메세지를 중간에서 자르지 않음.
    messages_history = trim_messages(
        input_data['history'], #전체 메세지 히스토리
        max_tokens=100, # 히스토리를 줄일 기준 token수, 지정한 토큰수가 넘어가면 줄인다.
        strategy="last", # 메세지를 줄일 때 last : 최근 메세지를, first : 오래된 메세지를 남긴다.
        token_counter=model, # 어떤 LLM을 기준으로 토큰을 계산할지, chatmodel을 전달
        include_system=True, # 줄일 때 system message를 포함여부. 
        start_on="human", # 줄일 때 시작메세지가 HumanMessage가 되게 한다.(ai : AIMessage)
    )

    # input_data['history'][-9:] # 그대로 사용
    # input_data['history'][:-9] # llm에 전송해서 요약
    # 이런식으로 logit을 만들 수도 있음! (위 함수 사용안하고)
    return {"history":messages_history, "query":input_data['query']}

runnable = trimming_history | prompt | model

chain_history = RunnableWithMessageHistory(
    runnable=runnable,
    history_messages_key="history",
    input_messages_key="query",
    get_session_history=get_message_history
)

config = {"configurable":{"session_id":"id-100"}}
# chain_history.invoke({"query":"질문"},config=config)
# {"history" : 저장소에서 질문/답변 히스토리 조회, "query":질문} -> runnable

# %%
query = input("User :")
while True:
    if query == "!quit":
        print(">>>>>>>>>종료>>>>>>>>>")
        break
    res = chain_history.invoke({"query":query}, config)
    print(">>>USer :",query)
    print("<<<AI: ", res.content)
    query = input("User :")
# Out:
# >>>USer : 내 이름은 장이선이야
# <<<AI:  만나서 반가워요, 장이선님. 무엇을 도와드릴까요?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 6
#       4     print(">>>>>>>>>종료>>>>>>>>>")
#       5     break
# ----> 6 res = chain_history.invoke({"query":query}, config)
#       7 print(">>>USer :",query)
#       8 print("<<<AI: ", res.content)
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\base.py:5548, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5541 @override
#    5542 def invoke(
#    5543     self,
#    (...)   5546     **kwargs: Any | None,
#    5547 ) -> Output:
# -> 5548     return self.bound.invoke(
#    5549         input,
#    5550         self._merge_configs(config),
#    5551         **{**self.kwargs, **kwargs},
#    5552     )
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\base.py:5548, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5541 @override
#    5542 def invoke(
#    5543     self,
#    (...)   5546     **kwargs: Any | None,
#    5547 ) -> Output:
# -> 5548     return self.bound.invoke(
#    5549         input,
#    5550         self._merge_configs(config),
#    5551         **{**self.kwargs, **kwargs},
#    5552     )
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\base.py:3143, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3141                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3142             else:
# -> 3143                 input_ = context.run(step.invoke, input_, config)
#    3144 # finish the root run
#    3145 except BaseException as e:
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\base.py:5548, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5541 @override
#    5542 def invoke(
#    5543     self,
#    (...)   5546     **kwargs: Any | None,
#    5547 ) -> Output:
# -> 5548     return self.bound.invoke(
#    5549         input,
#    5550         self._merge_configs(config),
#    5551         **{**self.kwargs, **kwargs},
#    5552     )
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\base.py:4871, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4856 """Invoke this `Runnable` synchronously.
#    4857
#    4858 Args:
#    (...)   4868
#    4869 """
#    4870 if hasattr(self, "func"):
# -> 4871     return self._call_with_config(
#    4872         self._invoke,
#    4873         input,
#    4874         ensure_config(config),
#    4875         **kwargs,
#    4876     )
#    4877 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    4878 raise TypeError(msg)
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\base.py:2058, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2054     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2055     with set_config_context(child_config) as context:
#    2056         output = cast(
#    2057             "Output",
# -> 2058             context.run(
#    2059                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2060                 func,
#    2061                 input_,
#    2062                 config,
#    2063                 run_manager,
#    2064                 **kwargs,
#    2065             ),
#    2066         )
#    2067 except BaseException as e:
#    2068     run_manager.on_chain_error(e)
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\config.py:433, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     431 if run_manager is not None and accepts_run_manager(func):
#     432     kwargs["run_manager"] = run_manager
# --> 433 return func(input, **kwargs)
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\base.py:4739, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4735         msg = (
#    4736             f"Recursion limit reached when invoking {self} with input {input_}."
#    4737         )
#    4738         raise RecursionError(msg)
# -> 4739     output = output.invoke(
#    4740         input_,
#    4741         patch_config(
#    4742             config,
#    4743             callbacks=run_manager.get_child(),
#    4744             recursion_limit=recursion_limit - 1,
#    4745         ),
#    4746     )
#    4747 return cast("Output", output)
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\base.py:5548, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5541 @override
#    5542 def invoke(
#    5543     self,
#    (...)   5546     **kwargs: Any | None,
#    5547 ) -> Output:
# -> 5548     return self.bound.invoke(
#    5549         input,
#    5550         self._merge_configs(config),
#    5551         **{**self.kwargs, **kwargs},
#    5552     )
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\base.py:3141, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3139 with set_config_context(config) as context:
#    3140     if i == 0:
# -> 3141         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3142     else:
#    3143         input_ = context.run(step.invoke, input_, config)
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\base.py:4871, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4856 """Invoke this `Runnable` synchronously.
#    4857
#    4858 Args:
#    (...)   4868
#    4869 """
#    4870 if hasattr(self, "func"):
# -> 4871     return self._call_with_config(
#    4872         self._invoke,
#    4873         input,
#    4874         ensure_config(config),
#    4875         **kwargs,
#    4876     )
#    4877 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    4878 raise TypeError(msg)
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\base.py:2058, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2054     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2055     with set_config_context(child_config) as context:
#    2056         output = cast(
#    2057             "Output",
# -> 2058             context.run(
#    2059                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2060                 func,
#    2061                 input_,
#    2062                 config,
#    2063                 run_manager,
#    2064                 **kwargs,
#    2065             ),
#    2066         )
#    2067 except BaseException as e:
#    2068     run_manager.on_chain_error(e)
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\config.py:433, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     431 if run_manager is not None and accepts_run_manager(func):
#     432     kwargs["run_manager"] = run_manager
# --> 433 return func(input, **kwargs)
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\base.py:4728, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4726                 output = chunk
#    4727 else:
# -> 4728     output = call_func_with_variable_args(
#    4729         self.func, input_, config, run_manager, **kwargs
#    4730     )
#    4731 # If the output is a Runnable, invoke it
#    4732 if isinstance(output, Runnable):
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\config.py:433, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     431 if run_manager is not None and accepts_run_manager(func):
#     432     kwargs["run_manager"] = run_manager
# --> 433 return func(input, **kwargs)
#
# Cell In[13], line 15, in trimming_history(input_data)
#       7 """
#       8 RunnableWithMessageHistory의 runnable chain의 첫번째 요소로 들어갈 함수.
#       9 input dictionary에 메세지 히스토리와 입력 query를 전달받는다.
#      10 {history_messages_key : 히스토리, input_messages_key : 입력 쿼리, ...}
#      11 message history를 tirmming해서 다음 chain요소(prompt)에 전달
#      12 """
#      14 # MAX_token은 대략 어디까지 줄일지의 기준. trimming을 할 때 메세지를 중간에서 자르지 않음.
# ---> 15 messages_history = trim_messages(
#      16     input_data['history'], #전체 메세지 히스토리
#      17     max_tokens=100, # 히스토리를 줄일 기준 token수, 지정한 토큰수가 넘어가면 줄인다.
#      18     strategy="last", # 메세지를 줄일 때 last : 최근 메세지를, first : 오래된 메세지를 남긴다.
#      19     token_counter=model, # 어떤 LLM을 기준으로 토큰을 계산할지, chatmodel을 전달
#      20     include_system=True, # 줄일 때 system message를 포함여부.
#      21     start_on="human", # 줄일 때 시작메세지가 HumanMessage가 되게 한다.(ai : AIMessage)
#      22 )
#      24 # input_data['history'][-9:] # 그대로 사용
#      25 # input_data['history'][:-9] # llm에 전송해서 요약
#      26 # 이런식으로 logit을 만들 수도 있음! (위 함수 사용안하고)
#      27 return {"history":messages_history, "query":input_data['query']}
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\messages\utils.py:435, in _runnable_support.<locals>.wrapped(messages, *args, **kwargs)
#     432 from langchain_core.runnables.base import RunnableLambda  # noqa: PLC0415
#     434 if messages is not None:
# --> 435     return func(messages, *args, **kwargs)
#     436 return RunnableLambda(partial(func, **kwargs), name=func.__name__)
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\messages\utils.py:1033, in trim_messages(messages, max_tokens, token_counter, strategy, allow_partial, end_on, start_on, include_system, text_splitter)
#    1024     return _first_max_tokens(
#    1025         messages,
#    1026         max_tokens=max_tokens,
#    (...)   1030         end_on=end_on,
#    1031     )
#    1032 if strategy == "last":
# -> 1033     return _last_max_tokens(
#    1034         messages,
#    1035         max_tokens=max_tokens,
#    1036         token_counter=list_token_counter,
#    1037         allow_partial=allow_partial,
#    1038         include_system=include_system,
#    1039         start_on=start_on,
#    1040         end_on=end_on,
#    1041         text_splitter=text_splitter_fn,
#    1042     )
#    1043 msg = f"Unrecognized {strategy=}. Supported strategies are 'last' and 'first'."
#    1044 raise ValueError(msg)
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\messages\utils.py:1579, in _last_max_tokens(messages, max_tokens, token_counter, text_splitter, allow_partial, include_system, start_on, end_on)
#    1576     system_tokens = token_counter([system_message])
#    1577     remaining_tokens = max(0, max_tokens - system_tokens)
# -> 1579 reversed_result = _first_max_tokens(
#    1580     reversed_messages,
#    1581     max_tokens=remaining_tokens,
#    1582     token_counter=token_counter,
#    1583     text_splitter=text_splitter,
#    1584     partial_strategy="last" if allow_partial else None,
#    1585     end_on=start_on,
#    1586 )
#    1588 # Re-reverse the messages and add back the system message if needed
#    1589 result = reversed_result[::-1]
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_core\messages\utils.py:1439, in _first_max_tokens(messages, max_tokens, token_counter, text_splitter, partial_strategy, end_on)
#    1436     return messages
#    1438 # Check if all messages already fit within token limit
# -> 1439 if token_counter(messages) <= max_tokens:
#    1440     # When all messages fit, only apply end_on filtering if needed
#    1441     if end_on:
#    1442         for _ in range(len(messages)):
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1747, in BaseChatOpenAI.get_num_tokens_from_messages(self, messages, tools)
#    1745 if sys.version_info[1] <= 7:
#    1746     return super().get_num_tokens_from_messages(messages)
# -> 1747 model, encoding = self._get_encoding_model()
#    1748 if model.startswith("gpt-3.5-turbo-0301"):
#    1749     # every message follows <im_start>{role/name}\n{content}<im_end>\n
#    1750     tokens_per_message = 4
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1701, in BaseChatOpenAI._get_encoding_model(self)
#    1698     model = self.model_name
#    1700 try:
# -> 1701     encoding = tiktoken.encoding_for_model(model)
#    1702 except KeyError:
#    1703     model_lower = model.lower()
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\tiktoken\model.py:118, in encoding_for_model(model_name)
#     113 def encoding_for_model(model_name: str) -> Encoding:
#     114     """Returns the encoding used by a model.
#     115
#     116     Raises a KeyError if the model name is not recognised.
#     117     """
# --> 118     return get_encoding(encoding_name_for_model(model_name))
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\tiktoken\registry.py:86, in get_encoding(encoding_name)
#      79     raise ValueError(
#      80         f"Unknown encoding {encoding_name}.\n"
#      81         f"Plugins found: {_available_plugin_modules()}\n"
#      82         f"tiktoken version: {tiktoken.__version__} (are you on latest?)"
#      83     )
#      85 constructor = ENCODING_CONSTRUCTORS[encoding_name]
# ---> 86 enc = Encoding(**constructor())
#      87 ENCODINGS[encoding_name] = enc
#      88 return enc
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\tiktoken_ext\openai_public.py:96, in o200k_base()
#      95 def o200k_base():
# ---> 96     mergeable_ranks = load_tiktoken_bpe(
#      97         "https://openaipublic.blob.core.windows.net/encodings/o200k_base.tiktoken",
#      98         expected_hash="446a9538cb6c348e3516120d7c08b09f57c36495e2acfffe59a5bf8b0cfb1a2d",
#      99     )
#     100     special_tokens = {ENDOFTEXT: 199999, ENDOFPROMPT: 200018}
#     101     # This regex could be made more efficient. If I was the one working on this encoding, I would
#     102     # have done a few other things differently too, e.g. I think you can allocate tokens more
#     103     # efficiently across languages.
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\tiktoken\load.py:162, in load_tiktoken_bpe(tiktoken_bpe_file, expected_hash)
#     160 def load_tiktoken_bpe(tiktoken_bpe_file: str, expected_hash: str | None = None) -> dict[bytes, int]:
#     161     # NB: do not add caching to this function
# --> 162     contents = read_file_cached(tiktoken_bpe_file, expected_hash)
#     163     ret = {}
#     164     for line in contents.splitlines():
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\tiktoken\load.py:67, in read_file_cached(blobpath, expected_hash)
#      64     except OSError:
#      65         pass
# ---> 67 contents = read_file(blobpath)
#      68 if expected_hash and not check_hash(contents, expected_hash):
#      69     raise ValueError(
#      70         f"Hash mismatch for data downloaded from {blobpath} (expected {expected_hash}). "
#      71         f"This may indicate a corrupted download. Please try again."
#      72     )
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\tiktoken\load.py:17, in read_file(blobpath)
#      13 if blobpath.startswith(("http://", "https://")):
#      14     # avoiding blobfile for public files helps avoid auth issues, like MFA prompts.
#      15     import requests
# ---> 17     resp = requests.get(blobpath)
#      18     resp.raise_for_status()
#      19     return resp.content
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\urllib3\connection.py:796, in HTTPSConnection.connect(self)
#     793     # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     794     server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 796     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     797         sock=sock,
#     798         cert_reqs=self.cert_reqs,
#     799         ssl_version=self.ssl_version,
#     800         ssl_minimum_version=self.ssl_minimum_version,
#     801         ssl_maximum_version=self.ssl_maximum_version,
#     802         ca_certs=self.ca_certs,
#     803         ca_cert_dir=self.ca_cert_dir,
#     804         ca_cert_data=self.ca_cert_data,
#     805         cert_file=self.cert_file,
#     806         key_file=self.key_file,
#     807         key_password=self.key_password,
#     808         server_hostname=server_hostname_rm_dot,
#     809         ssl_context=self.ssl_context,
#     810         tls_in_tls=tls_in_tls,
#     811         assert_hostname=self.assert_hostname,
#     812         assert_fingerprint=self.assert_fingerprint,
#     813     )
#     814     self.sock = sock_and_verified.socket
#     816 # If an error occurs during connection/handshake we may need to release
#     817 # our lock so another connection can probe the origin.
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\urllib3\connection.py:975, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     972     if is_ipaddress(normalized):
#     973         server_hostname = normalized
# --> 975 ssl_sock = ssl_wrap_socket(
#     976     sock=sock,
#     977     keyfile=key_file,
#     978     certfile=cert_file,
#     979     key_password=key_password,
#     980     ca_certs=ca_certs,
#     981     ca_cert_dir=ca_cert_dir,
#     982     ca_cert_data=ca_cert_data,
#     983     server_hostname=server_hostname,
#     984     ssl_context=context,
#     985     tls_in_tls=tls_in_tls,
#     986 )
#     988 try:
#     989     if assert_fingerprint:
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\urllib3\util\ssl_.py:483, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     479         context.load_cert_chain(certfile, keyfile, key_password)
#     481 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 483 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     484 return ssl_sock
#
# File c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\urllib3\util\ssl_.py:527, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     524     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     525     return SSLTransport(sock, ssl_context, server_hostname)
# --> 527 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.11-windows-x86_64-none\Lib\ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.11-windows-x86_64-none\Lib\ssl.py:1041, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038             if timeout == 0.0:
#    1039                 # non-blocking
#    1040                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041             self.do_handshake()
#    1042 except:
#    1043     try:
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.11-windows-x86_64-none\Lib\ssl.py:1319, in SSLSocket.do_handshake(self, block)
#    1317     if timeout == 0.0 and block:
#    1318         self.settimeout(None)
# -> 1319     self._sslobj.do_handshake()
#    1320 finally:
#    1321     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
query = input("User :")
while True:
    if query == "!quit":
        print(">>>>>>>>>종료>>>>>>>>>")
        break
    print(">>>USer :",query)
    print("<<<AI: ", end="")

    for token in chain_history.stream({"query":query}, config):
        print(token.content, end="")
    print("\n")
    query = input("User :")
# Out:
# >>>USer : 내 이름은 장이선이야
# <<<AI:  만나서 반가워요, 장이선님. 무엇을 도와드릴까요?
# 알겠습니다, 장이선님. 반갑습니다. 무엇을 도와드릴까요?
# >>>>>>>>>종료>>>>>>>>>
