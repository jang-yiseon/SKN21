# %% [markdown]
# # Agent 개요
# > **Agent는 대형 언어 모델을 두뇌로 사용하여, 목표를 스스로 이해하고 외부 도구와 상호작용하며 실제 작업을 자율적으로 수행하는 지능형 인공지능 시스템이다.**
#
# - Agent는 **대형 언어 모델(LLM, Large Language Model)과 다양한 도구(Tool)를 결합하여, 사용자의 복잡한 요청을 스스로 분석하고 처리하도록 설계된 지능형 인공지능 시스템이다.**
# 기존의 단순한 챗봇이 “질문 → 답변” 구조로 동작한다면,
#   - Agent는 **목표 설정 → 판단 → 실행 → 결과 반영**의 전 과정을 스스로 수행하는 구조를 가진다.
#
# - Agent는 주어진 목표를 달성하기 위해 자율적으로 **외부 환경(도구, API, 데이터베이스, 파일 시스템 등)과 상호작용하며 의사 결정을 내리고 실제 행동을 수행한다.**
# 이때 Agent의 **핵심적인 의사 결정과 추론 과정은 대형 언어 모델(LLM)이 담당**하며, **사람의 개입은 최소화**한다.
#
# - 즉, Agent는 단순히 정보를 말해주는 존재가 아니라, **"문제를 이해하고, 해결 방법을 계획하고, 직접 실행까지 담당하는 인공지능 작업 수행자"이다.**
#
# - AI 시스템을 구현할 때, **워크플로우**(**Workflow**)는 사전에 정의된 절차에 따라 실행 단계가 고정적인 구현 방식이라면, **에이전트**(**Agent**)는 주어진 목표를 달성하기 위해 스스로 계획을 수립하고, 상황을 판단하여 행동을 결정·실행하는 자율적인 방식이다.
#
#
#
# ## Agent의 주요 특징
#
# 1. **자율성** (Autonomy)
#    - Agent는 **사전 정의된 규칙**(Rule-based)에 의존하지 않고, LLM을 통해 현재 상황을 인지하고 추론하여 스스로 결정을 내리고 다음 행동을 계획할 수 있다.
#    - 즉, 사용자가 일일이 수행 단계를 지시하지 않아도, Agent는 **현재 상황을 해석하고 다음 행동을 동적으로 결정한다.**
#
# 2. **목표 지향성** (Goal-Oriented)
#     - Agent는 단순히 질문에 답변하는 **단순한 대화 상대가 아니라, 특정 목표와 복잡한 작업을 달성하기 위해 설계된 시스템**으로 최종 목표에 도달할 때 까지 반복적으로 행동한다.
#     - Agent는 어떤 처리를 할 때 항상 **"이 행동이 목표 달성에 도움이 되는가"를 기준**으로 판단한다.
#
# 3. **도구 활용** (Tool Utilization)
#     - Agent는 대형 언어 모델의 언어 이해 능력, 사전 학습 정보에만 의존하지 않고, 다양한 **외부 도구와 API를 함께 활용하여 실제 작업을 수행**한다.
#     - 이를 통해 LLM이 처리할 수없는 **최신 정보 검색, 복잡한 계산, 외부 시스템 제어**등과 같은 작업이 가능하다. 이를 통해 Agent는 **"말만 하는 AI"가 아니라 "실제로 일을 처리하는 AI"로 기능한다.**
#
# 4. **인간 개입 최소화** (Human-in-the-loop 최소화)
#     - Agent는 **문제 분석, 의사 결정, 행동 실행의 대부분을 스스로 결정하고 수행하도록 설계된다.**
#     - 사람은 **초기 목표 제시, 결과 확인 및 실행 최종 승인** 정도에 만 개입한다.

# %% [markdown]
# ## 다양한 Agent 활용 사례
#
# - **미국 국세청(IRS) 세무처리에 도입된 AI 에이전트**
#     - 미국 국세청(IRS)은 Salesforce Agentforce 기반 AI 에이전트를 도입해 세무 업무에서의 보조·분석 기능을 강화하고 업무 효율을 높이고 있다.
#
# -  **고객 추천 및 개인화된 콘텐츠 제공**
#     - Netflix, Amazon 같은 OTT 플랫폼은 사용자의 취향 변화에 따라 추천 시스템을 적응시키는 학습형 에이전트를 활용해 콘텐츠/제품 추천을 개선해 나간다.
#
# - **영업 지원용 AI 에이전트**
#     - Oracle은 영업 전문가를 위한 AI 에이전트를 도입해 고객 미팅 후 CRM 업데이트, 고객 데이터 분석·보고서 생성 같은 반복 작업을 자동화하고 있다.
#
# - **물류 최적화 및 배송 계획**
#     - Uber Freight, J.B. Hunt 등에서는 AI 에이전트를 활용해 실시간 교통·날씨 데이터 분석을 통해 가장 효율적인 배송 경로를 계산한다.
#
# - **AWS의 클라우드 자동화 에이전트**
#     - Amazon Web Services는 보안, DevOps, 일반 작업을 자동화하는 AI 에이전트들을 출시하며 클라우드 인프라 운영과 보안 모니터링을 강화하고 있다.
#
# - **삼성SDS AI 에이전트 플랫폼**
#     - 삼성SDS는 **사용자 개입 없이 스스로 판단·문제 해결이 가능한 AI 에이전트 플랫폼 ‘패브릭스(Fabrics)’**를 공개했다. 이를 통해 기업 내부에서 자동화된 의사결정과 작업 실행을 지원한다.

# %% [markdown]
# # ReAct 패턴
# - Agent 구현의 바탕이 되는 이론.
#
# ## 1. 개요
#
# ReAct는 **Reasoning**(추론)과 **Acting**(행동)을 결합한 AI Agent의 프롬프팅 패턴이다. 대형 언어 모델(LLM)이 단순히 답변을 생성하는 것이 아니라, 문제를 분석하고(Reasoning)하고 그에 따라 필요한 도구를 선택하여 실행하며(Acting), 결과를 관찰하고(Observation) 다음 추론에 반영하는 과정을 반복하면서 문제를 해결하는  Agent 설계 방식이다.
#
# ### ReAct의 핵심 개념
#
# 전통적인 프롬프팅 방식은 질문에 대해 즉시 답변을 생성한다. 하지만 **ReAct 패턴**은 다음과 같은 순환 구조를 따른다:
#
# ```
# 질문 → 생각(Thought) → 행동(Action) → 관찰(Observation) → 생각 → 행동 →  관찰 → ... → 답변
# ```
#
# - 예)
#   - 질문: "현재 서울의 날씨와 미세먼지 농도를 알려줘":
#
#     - **Thought(생각)**: 날씨 정보를 얻기 위해 날씨 API를 호출해야겠다
#     - **Action(행동)**: WeatherAPI.get_weather("서울")
#     - **Observation(관찰)**: 기온 15도, 맑음
#     - **Thought(생각)**: 이제 미세먼지 정보도 필요하다
#     - **Action(행동)**: AirQualityAPI.get_pm("서울")
#     - **Observation(관찰)**: PM10 농도 20㎍/㎥, 좋음
#     - **Answer(답변)**: 서울의 현재 날씨는 기온 15도로 맑고, 미세먼지 농도는 30㎍/㎥로 좋은 상태이다
#
# 이처럼 ReAct는 Agent가 **사고 과정을 명시적으로 드러내면서** 외부 도구를 활용하여 복잡한 문제를 해결할 수 있도록 한다.
#
# ### ReAct의 장점
#
# 1. **투명성**: Agent의 사고 과정을 추적할 수 있어 디버깅이 용이하다
# 2. **정확성**: 외부 지식과 도구를 활용하여 환각(hallucination)을 줄인다
# 3. **유연성**: 다양한 도구를 조합하여 복잡한 작업을 수행할 수 있다
# 4. **해석 가능성**: 각 단계의 추론 과정을 이해할 수 있다

# %% [markdown]
# ## 동작 단계
# ReAct 패턴은 크게 **5단계**의 순환 구조로 동작한다.
#
# 1. **질문 입력** (Question)
#      - 사용자로부터 해결해야 할 질문이나 작업을 입력받는다.
#      - 예시
#     ```bash
#      User Input: "2024년 노벨 물리학상 수상자는 누구이고, 그들의 주요 업적은 무엇인가?"
#     ```
#
# 2. **사고 단계** (Thought)
#      - 언어 모델이 사용자의 질문(요청)을 분석하고, 문제 해결을 위해 다음에 무엇을 해야 할지 추론한다.(계획을 세운다.)
#      - 이 단계에서 Agent는:
#          - 문제를 이해하고 분해한다
#          - 필요한 정보가 무엇인지 파악한다
#          - 어떤 도구를 사용해야 할지 결정한다
#          - 충분한 정보가 모였는지 판단한다
#
#        ```bash
#        Thought: 2024년 노벨 물리학상 정보는 내 학습 데이터에 없을 수 있다. 최신 정보를 검색해야 한다.
#        ```
#
# 3. **행동 단계** (Action)
#      - 사고 단계에서 결정된 계획을 바탕으로 실제 행동을 실행한다. 행동은 일반적으로 외부 도구(Tool) 호출한다.
#
#         ```bash
#         Action: 검색엔진.검색("2024 노벨 물리학상 수상자")
#         ```
#
# 4. **관찰 단계** (Observation)
#      - 행동(Acttion)의 결과를 관찰하고 얻은 정보를 확인한다.
#
#        ```bash
#        Observation: 2024년 노벨 물리학상은 John Hopfield와 Geoffrey Hinton에게 수여되었다.
#        ```
#
#  5. **반복 또는 종료**
#        - 관찰한 정보가 사용자 질문에 대한 답변을 하는데 충분하지 않다면 2번의 사고 단계로 돌아가 추가 행동을 계획한다.(사고→행동→관찰 반복)
#        - 충분한 정보가 모였다면 그 정보를 바탕으로 최종 답변을 생성한다.
#
#           ```bash
#           Thought: 수상자 이름은 알았지만 구체적인 업적 내용이 필요하다.
#
#           Action: Search("John Hopfield Geoffrey Hinton 노벨상 업적")
#
#           Observation: Hopfield는 연상 메모리를 위한 Hopfield 네트워크를 개발했고, Hinton은 딥러닝의 역전파 알고리즘과 볼츠만 머신을 연구했다.
#
#           Thought: 이제 질문에 답할 충분한 정보가 모였다.
#
#           Action: Finish("2024년 노벨 물리학상은 John Hopfield와 Geoffrey Hinton에게 수여되었다. Hopfield는 연상 메모리를 위한 Hopfield 네트워크를 개발했고, Hinton은 딥러닝의 역전파 알고리즘과 볼츠만 머신 연구로 인공신경망 발전에 기여했다.")
#           ```
#
# ### 동작 흐름도
# ![ReAct](figures/agent-ReAct.png)

# %% [markdown]
# # TOOL
# - **Tool은 하나의 기능을 처리하는 함수이다.**
#     - Tool은 하나의 명확한 기능을 수행하도록 정의된 함수(Function) 형태의 외부 실행 수단이다.
#     - 대형 언어 모델(LLM)은 본래 텍스트를 생성하는 모델이므로, 실제 계산, 검색, 파일 처리, 데이터베이스 조회와 같은 현실 세계의 작업을 직접 수행할 수는 없다. 이런 실제 작업을 대신 수행하는 단위가 Tool 이다.
# - **AI Model은 Tool을 이용해 자체 지식의 한계(Knowlege cutoff)를 넘어서는 정보를 제공할 수 있다.**
# > **Knowledge Cutoff**:
# > - Knowledge cutoff는 AI 모델이 학습한 데이터가 마지막으로 업데이트된 시점을 의미하며, 그 이후에 발생한 정보나 사건에 대해서는 AI 모델이 학습한 지식으로는 알지 못하는 한계를 가지게 된다.
#
# ## Tool Calling 개요
# - **도구 호출**(Tool Calling)은 LLM이 자체적으로 수행할 수 없는 작업을 외부 도구나 API를 활용하여 처리할 수 있게 하는 핵심 기능이다. 이를 통해 **LLM은 자체 지식의 한계를 넘어서는 최신 정보, 정확한 계산, 외부 시스템 제어 등의 능력을 확보**할 수 있다.
#
# - **도구 호출(Tool Calling)의 3단계**
#     1. 도구 바인딩 (Tool Binding): **LLM에 사용가능한 tool들을 등록한다.**
#         - LLM에게 사용 가능한 도구 목록과 각 도구의 기능(설명) 및 필요한 입력 매개변수를 미리 정의하여 제공한다.
#             - Tool 함수
#             - Tool 이름
#             - Tool이 수행하는 기능 설명
#             - 입력 파라미터 type과 설명
#     2. **사용자 질의가 들어오면 LLM이 도구 사용 여부를 판단**한다.
#         - LLM 자체 추론으로 해결가능한 문제인지 Tool을 호출해야 처리할 수있는 문제 인지를 확인한다.
#         - **Tool 사용이 필요한 문제** 라고 판단하면
#           - 도구를 호출 하는 것이 아니라 어떻게 호출해야 하는지 요청정보를 생성한다.
#             - 어떤 Tool을 사용해야 하는지, 그 Tool에 어떤 값을 전달해야하는지를 응답으로 생성한다.
#     3.  **시스템이 Tool 호출 요청정보에 따라 Tool을 실행하고 그 결과를 LLM 에게 전달**한다.
#
#      ![toolcalling_concept](figures/toolcalling_concept.png)
#
# - **TOOL Calling 예**
#     - LLM이 수학 계산을 수행해야 할 때, 직접 계산하는 대신 미리 정의된 '계산' 도구를 호출하여 정확한 결과를 얻을 수 있다.
#   	- LLM에 최신 정보를 요청하는 질문이 들어왔을 때 '검색' 도구나 'Database 연동' 도구를 사용해 최신 뉴스를 검색하거나, 특정 데이터베이스에서 정보를 조회하는 등의 작업을 수행할 수 있다.
#   	- LLM 이 작성한 결과를 google docs와 같은 문서도구나 SNS에 등록한다.
#
# ## Langchain 과 Tool calling
# - Tool calling은 대부분의 LLM 서비스가 지원한다.
#   - [Tool Calling을 지원하는 LLM 모델](https://docs.langchain.com/oss/python/integrations/chat)만 사용할 수 있다.
# - LangChain은 다양한 모델들의 도구 호출 방식을 표준화하여 일관된 인터페이스로 제공한다. 이를 통해 개발자들은 다양한 모델과 도구들을 쉽게 통합할 수있다.
#   - [Langchain Tool Calling Concept](https://docs.langchain.com/oss/python/langchain/tools)
# - Langchain 제공 Built-in tools
#     -  https://docs.langchain.com/oss/python/integrations/tools

# %% [markdown]
# # LangChain Built-in Tools 사용으로 Tool Calling 이해
#
# - Langchain은 다양한 도구들을 미리 구현해서 제공하고 있다. 이것들을 builtin tool이라고 한다.
#   - [Langchain 지원 Built tools](https://docs.langchain.com/oss/python/integrations/tools)
# - Built-In tool 뿐만 아니라 사용자 정의 Tool들을 직접 구현할 수있는 방법도 제공한다.
#
# ## Tavily API 검색 Tool
# > Tavily 웹 검색 도구 사용해 Tool calling을 이해한다.
# - **Tavily** Service: AI을 위한 웹 검색 API Service.
# - https://tavily.com/
# -  LLM과 RAG 시스템에 최적화된 검색 엔진.
#    -  기존의 일반 검색 엔진들과 달리, Tavily는 AI 애플리케이션의 요구사항에 맞춰 설계되었다.
#    -  Tavily는 최대 20개 이상의 신뢰도 높은 웹사이트에서 관련정보를 수집한다.
#    -  수집된 데이터는 AI가 관련성, 신뢰도, 최신성 등을 기준으로 평가해 가장 적합한 정보만 선별해서 요약한다.
#    -  최종적으로 이 정보는 LLM이 바로 활용할 수있도록 컨텐츠 스티펫, 요약, 출처 등의 구조화된 형태로 반환한다.
#    -  월 1000회 무료 사용 가능.
# - **Tavily API Key 받기**
#   - 회원가입 후 로그인 한다.
#   - Overview 화면에서 API Key 생성
#     - default API key 사용할 수있다.
#   - 환경변수에 등록한다.
#       - 변수이름: `TAVILY_API_KEY`
#
# ### TavilySearch
# - Langchain에서 제공하는 tool로 Tavily 의 검색 엔진 API를 사용해 검색을 수행한다.
# - 설치
#   - `pip install langchain-tavily`
# - https://python.langchain.com/docs/integrations/tools/tavily_search/

# %%
# !uv pip install langchain-tavily
# Out:
# Resolved 41 packages in 1.83s
# Prepared 1 package in 66ms
# Installed 1 package in 20ms
#  + langchain-tavily==0.2.16

# %%
from dotenv import load_dotenv
from langchain_tavily import TavilySearch # tavily 검색 tool
load_dotenv()
# Out:
# c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_tavily\tavily_research.py:97: UserWarning: Field name "output_schema" in "TavilyResearch" shadows an attribute in parent "BaseTool"
#   class TavilyResearch(BaseTool):  # type: ignore[override, override]
# c:\Users\Playdata\Documents\SKN21\JYS\10_langchain\.venv\Lib\site-packages\langchain_tavily\tavily_research.py:97: UserWarning: Field name "stream" in "TavilyResearch" shadows an attribute in parent "BaseTool"
#   class TavilyResearch(BaseTool):  # type: ignore[override, override]
# True

# %%
# 객체 생성 - 검색 옵션을 파라미터로 설정.

tavily_search = TavilySearch(
    max_results=3, # 최대 검색 개수.
    # include_raw_content = True, # 원본 내용도 포함
    # include_answer=True, # 검색 결과를 바탕으로 Tavily AI가 종합적 답변을 하도록 한다.
    # include_images=True, # 검색한 문서 내의 이미지(경로)들을 반환
    # time_range='year', # day, week, month, year 등으로 지정 가능 - 현재 시점 기준으로 지정한 기간 내의 문서들만 검색결과로 제공.
)

# 검색 요청
query = "2025년 한국시리즈 우승팀은?"
# result = tavily_search.invoke(query)
result = tavily_search.invoke(
    {
        "query":query,
        "include_images":True# 옵션들을 key : value로 설정해서 실행시 동적으로 설정.
    }
)

# %%
print(type(result))
result
# Out:
# <class 'dict'>
# {'query': '2025년 한국시리즈 우승팀은?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': ['https://blogthumb.pstatic.net/MjAyNTAzMjNfNjYg/MDAxNzQyNzE4ODAxNzkw.oSUS641rn-u5mmRK9X90k3cOu6mV_S-lXEroFC41xc0g.ifwCdPWPHpTasTUsv1lLbaYgl6z8MXOE4Ezbpu0y2WUg.PNG/������-�Է����ּ���__���纻-_27_-001.png?type=w2',
#   'https://www.sportschosun.com/article/html/2025/10/22/2025102301001362100180743_w.jpg',
#   'https://img.etoday.co.kr/pto_db/2024/10/20241029063224_2094589_999_567.jpg',
#   'https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEhIwYdP22bQ2HL4mmF0rsT9O2cpYw8iRkBY4AkpbjujNUkhyphenhyphen-k1BICpkEpj1u1EejbsLIaOld7q40ZSmna-vLCXKj1XNTr8rRHDAB1QhsT-BNRjZkZGPzqPDGc501RlSJyXAx7_HJX2KDCcpZtRWBiUFWbOy6x-MVWIYlHTxsNi6iKnX7ZMjJzvPu6q38jK/s1024/ChatGPT+Image+2025년+10월+11일+오전+11_20_52.png',
#   'https://blog.kakaocdn.net/dn/boRtrn/btsMgUfWOwB/t7Xx4EoLVFU5OrsilmFCmK/img.jpg'],
#  'results': [{'url': 'https://ko.wikipedia.org/wiki/2025%EB%85%84_%ED%95%9C%EA%B5%AD%EC%8B%9C%EB%A6%AC%EC%A6%88',
#    'title': '2025년 한국시리즈',
#    'content': '| 10월 30일(목) | 4차전 | **LG 트윈스** | **7** - 4 | 한화 이글스 | 16,750명 **(매진)** | 김현수 "김현수 (1988년생 야구 선수)") (LG 트윈스) |. | 우승\xa0: LG 트윈스 (4번째), 한국시리즈 MVP\xa0: 김현수 "김현수 (1988년생 야구 선수)") (LG 트윈스) |. 한화가 6회초 1사 2루 상황에서 노시환의 적시타에 이어서 1사 1, 3루 상황에서 하주석의 희생플라이로 2점 추격을 해봤으나 LG는 6회말 공격 1사 만루 상황에서 신민재 "신민재 (1996년)")의 2타점 적시타, 2사 1, 2루에서 김현수 "김현수 (1988년생 야구 선수)")와 문보경의 연속 적시타로 4득점을 추가해 상대의 추격을 완전히 뿌리치며 사실상 승부를 결정지었다. 하지만 LG가 이후 폰세를 상대로 3회초 2사 1루 상황에서 터진 신민재 "신민재 (1996년)")의 1타점 2루타로 동점, 4회초에는 1아웃에서 앞선 2회말 실책을 만회한 김현수 "김현수 (야구 선수)")의 홈런으로 앞서간 가운데 팽팽한 1점 차 승부가 이어졌고 이후 LG는 8회초 1사 1, 3루 오스틴 타석에서 김서현 "김서현 (야구 선수)")이 폭투를 범하여 홍창기의 대주자로 들어온 3루 주자 최원영 "최원영 (야구 선수)")이 득점하며 3:1로 앞서며 LG의 흐름으로 3차전이 흐르고 있었으나 8회말 한화가 대반격을 시작했다.',
#    'score': 0.88822687,
#    'raw_content': None},
#   {'url': 'https://www.youtube.com/watch?v=MmcDtgJ1zqs',
#    'title': '[속보] LG 트윈스, 2025 한국시리즈 우승…2년만에 왕좌 탈환 ...',
#    'content': '프로야구 LG 트윈스가 한화 이글스를 꺾고 2025년 한국시리즈 우승을 차지했습니다. LG는 조금 전 대전에서 열린 한국시리즈 5차전에서 4대1로 승리,',
#    'score': 0.87706697,
#    'raw_content': None},
#   {'url': 'https://www.facebook.com/kbo1982/posts/2025-kbo-%ED%95%9C%EA%B5%AD%EC%8B%9C%EB%A6%AC%EC%A6%88-%EC%9A%B0%EC%8A%B9-lg%ED%8A%B8%EC%9C%88%EC%8A%A4%EC%9E%85%EB%8B%88%EB%8B%A41031-lg%ED%95%9C%ED%99%94%EC%95%BC%EA%B5%AC-baseball-kbo-%ED%8F%AC%EC%8A%A4%ED%8A%B8%EC%8B%9C%EC%A6%8C-%ED%95%9C%EA%B5%AD%EC%8B%9C%EB%A6%AC%EC%A6%88_5%EC%B0%A8%EC%A0%84-lg%ED%8A%B8%EC%9C%88%EC%8A%A4-%EC%9A%B0%EC%8A%B9-kbo2/1315789490588357/',
#    'title': '2025 KBO 한국시리즈 우승! LG트윈스입니다!(10.31. ...',
#    'content': '2025 KBO 한국시리즈 우승! LG트윈스입니다!(10.31. LG: 한화) #야구 #baseball #KBO #포스트시즌 #한국시리즈_5차전 #LG트윈스 #우승 #kbo20251031.',
#    'score': 0.86713725,
#    'raw_content': None}],
#  'response_time': 0.0,
#  'request_id': '32f39d82-193a-4c0f-9c4f-5d3b6c7fed30'}

# %%
# 도구 - 도구 이름, 도구 설명 -> llm이 도구를 사용 여부를 판단할 때 근거가 됨. 
# Tavily(built-in)도구 정보를 확인

print("도구 이름 :",tavily_search.name)
print("도구 설명 :")
print(tavily_search.description)
# Out:
# 도구 이름 : tavily_search
# 도구 설명 :
# A search engine optimized for comprehensive, accurate, and trusted results. Useful for when you need to answer questions about current events. It not only retrieves URLs and snippets, but offers advanced search depths, domain management, time range filters, and image search, this tool delivers real-time, accurate, and citation-backed results.Input should be a search query.

# %%
schema = tavily_search.args_schema.model_json_schema()
schema
# 도구 스키마(섥꼐 구조)
## 도구 호출 시 전달 파라미터 정보.
# Out:
# {'additionalProperties': True,
#  'description': 'Input for [TavilySearch]',
#  'properties': {'query': {'description': 'Search query to look up',
#    'title': 'Query',
#    'type': 'string'},
#   'include_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#     {'type': 'null'}],
#    'default': [],
#    'description': 'A list of domains to restrict search results to.\n\n        Use this parameter when:\n        1. The user explicitly requests information from specific websites (e.g., "Find climate data from nasa.gov")\n        2. The user mentions an organization or company without specifying the domain (e.g., "Find information about iPhones from Apple")\n\n        In both cases, you should determine the appropriate domains (e.g., ["nasa.gov"] or ["apple.com"]) and set this parameter.\n\n        Results will ONLY come from the specified domains - no other sources will be included.\n        Default is None (no domain restriction).\n        ',
#    'title': 'Include Domains'},
#   'exclude_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#     {'type': 'null'}],
#    'default': [],
#    'description': 'A list of domains to exclude from search results.\n\n        Use this parameter when:\n        1. The user explicitly requests to avoid certain websites (e.g., "Find information about climate change but not from twitter.com")\n        2. The user mentions not wanting results from specific organizations without naming the domain (e.g., "Find phone reviews but nothing from Apple")\n\n        In both cases, you should determine the appropriate domains to exclude (e.g., ["twitter.com"] or ["apple.com"]) and set this parameter.\n\n        Results will filter out all content from the specified domains.\n        Default is None (no domain exclusion).\n        ',
#    'title': 'Exclude Domains'},
#   'search_depth': {'anyOf': [{'enum': ['basic',
#       'advanced',
#       'fast',
#       'ultra-fast'],
#      'type': 'string'},
#     {'type': 'null'}],
#    'default': 'basic',
#    'description': 'Controls search thoroughness and result comprehensiveness.\n    \n        Use "basic" for simple queries requiring quick, straightforward answers.\n        \n        Use "advanced" for complex queries, specialized topics, \n        rare information, or when in-depth analysis is needed.\n        \n        Use "fast" for optimized low latency with high relevance.\n        \n        Use "ultra-fast" when latency is prioritized above all else.\n        ',
#    'title': 'Search Depth'},
#   'include_images': {'anyOf': [{'type': 'boolean'}, {'type': 'null'}],
#    'default': False,
#    'description': 'Determines if the search returns relevant images along with text results.\n   \n        Set to True when the user explicitly requests visuals or when images would \n        significantly enhance understanding (e.g., "Show me what black holes look like," \n        "Find pictures of Renaissance art").\n        \n        Leave as False (default) for most informational queries where text is sufficient.\n        ',
#    'title': 'Include Images'},
#   'time_range': {'anyOf': [{'enum': ['day', 'week', 'month', 'year'],
#      'type': 'string'},
#     {'type': 'null'}],
#    'default': None,
#    'description': 'Limits results to content published within a specific timeframe.\n        \n        ONLY set this when the user explicitly mentions a time period \n        (e.g., "latest AI news," "articles from last week").\n        \n        For less popular or niche topics, use broader time ranges \n        ("month" or "year") to ensure sufficient relevant results.\n   \n        Options: "day" (24h), "week" (7d), "month" (30d), "year" (365d).\n        \n        Default is None.\n        ',
#    'title': 'Time Range'},
#   'topic': {'anyOf': [{'enum': ['general', 'news', 'finance'],
#      'type': 'string'},
#     {'type': 'null'}],
#    'default': 'general',
#    'description': 'Specifies search category for optimized results.\n   \n        Use "general" (default) for most queries, INCLUDING those with terms like \n        "latest," "newest," or "recent" when referring to general information.\n\n        Use "finance" for markets, investments, economic data, or financial news.\n\n        Use "news" ONLY for politics, sports, or major current events covered by \n        mainstream media - NOT simply because a query asks for "new" information.\n        ',
#    'title': 'Topic'},
#   'start_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#    'default': None,
#    'description': 'Filters search results to include only content published on or after this date.\n        \n        Use this parameter when you need to:\n        - Find recent developments or updates on a topic\n        - Exclude outdated information from search results\n        - Focus on content within a specific timeframe\n        - Combine with end_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-01-15" for January 15, 2024).\n        \n        Examples:\n        - "2024-01-01" - Results from January 1, 2024 onwards\n        - "2023-12-25" - Results from December 25, 2023 onwards\n        \n        When combined with end_date, creates a precise date range filter.\n        \n        Default is None (no start date restriction).\n        ',
#    'title': 'Start Date'},
#   'end_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#    'default': None,
#    'description': 'Filters search results to include only content published on or before this date.\n        \n        Use this parameter when you need to:\n        - Exclude content published after a certain date\n        - Study historical information or past events\n        - Research how topics were covered during specific time periods\n        - Combine with start_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-03-31" for March 31, 2024).\n        \n        Examples:\n        - "2024-03-31" - Results up to and including March 31, 2024\n        - "2023-12-31" - Results up to and including December 31, 2023\n        \n        When combined with start_date, creates a precise date range filter.\n        For example: start_date="2024-01-01", end_date="2024-03-31" \n        returns results from Q1 2024 only.\n        \n        Default is None (no end date restriction).\n        ',
#    'title': 'End Date'}},
#  'required': ['query'],
#  'title': 'TavilySearchInput',
#  'type': 'object'}

# %%
schema['properties']
# Out:
# {'query': {'description': 'Search query to look up',
#   'title': 'Query',
#   'type': 'string'},
#  'include_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#    {'type': 'null'}],
#   'default': [],
#   'description': 'A list of domains to restrict search results to.\n\n        Use this parameter when:\n        1. The user explicitly requests information from specific websites (e.g., "Find climate data from nasa.gov")\n        2. The user mentions an organization or company without specifying the domain (e.g., "Find information about iPhones from Apple")\n\n        In both cases, you should determine the appropriate domains (e.g., ["nasa.gov"] or ["apple.com"]) and set this parameter.\n\n        Results will ONLY come from the specified domains - no other sources will be included.\n        Default is None (no domain restriction).\n        ',
#   'title': 'Include Domains'},
#  'exclude_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#    {'type': 'null'}],
#   'default': [],
#   'description': 'A list of domains to exclude from search results.\n\n        Use this parameter when:\n        1. The user explicitly requests to avoid certain websites (e.g., "Find information about climate change but not from twitter.com")\n        2. The user mentions not wanting results from specific organizations without naming the domain (e.g., "Find phone reviews but nothing from Apple")\n\n        In both cases, you should determine the appropriate domains to exclude (e.g., ["twitter.com"] or ["apple.com"]) and set this parameter.\n\n        Results will filter out all content from the specified domains.\n        Default is None (no domain exclusion).\n        ',
#   'title': 'Exclude Domains'},
#  'search_depth': {'anyOf': [{'enum': ['basic',
#      'advanced',
#      'fast',
#      'ultra-fast'],
#     'type': 'string'},
#    {'type': 'null'}],
#   'default': 'basic',
#   'description': 'Controls search thoroughness and result comprehensiveness.\n    \n        Use "basic" for simple queries requiring quick, straightforward answers.\n        \n        Use "advanced" for complex queries, specialized topics, \n        rare information, or when in-depth analysis is needed.\n        \n        Use "fast" for optimized low latency with high relevance.\n        \n        Use "ultra-fast" when latency is prioritized above all else.\n        ',
#   'title': 'Search Depth'},
#  'include_images': {'anyOf': [{'type': 'boolean'}, {'type': 'null'}],
#   'default': False,
#   'description': 'Determines if the search returns relevant images along with text results.\n   \n        Set to True when the user explicitly requests visuals or when images would \n        significantly enhance understanding (e.g., "Show me what black holes look like," \n        "Find pictures of Renaissance art").\n        \n        Leave as False (default) for most informational queries where text is sufficient.\n        ',
#   'title': 'Include Images'},
#  'time_range': {'anyOf': [{'enum': ['day', 'week', 'month', 'year'],
#     'type': 'string'},
#    {'type': 'null'}],
#   'default': None,
#   'description': 'Limits results to content published within a specific timeframe.\n        \n        ONLY set this when the user explicitly mentions a time period \n        (e.g., "latest AI news," "articles from last week").\n        \n        For less popular or niche topics, use broader time ranges \n        ("month" or "year") to ensure sufficient relevant results.\n   \n        Options: "day" (24h), "week" (7d), "month" (30d), "year" (365d).\n        \n        Default is None.\n        ',
#   'title': 'Time Range'},
#  'topic': {'anyOf': [{'enum': ['general', 'news', 'finance'],
#     'type': 'string'},
#    {'type': 'null'}],
#   'default': 'general',
#   'description': 'Specifies search category for optimized results.\n   \n        Use "general" (default) for most queries, INCLUDING those with terms like \n        "latest," "newest," or "recent" when referring to general information.\n\n        Use "finance" for markets, investments, economic data, or financial news.\n\n        Use "news" ONLY for politics, sports, or major current events covered by \n        mainstream media - NOT simply because a query asks for "new" information.\n        ',
#   'title': 'Topic'},
#  'start_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#   'default': None,
#   'description': 'Filters search results to include only content published on or after this date.\n        \n        Use this parameter when you need to:\n        - Find recent developments or updates on a topic\n        - Exclude outdated information from search results\n        - Focus on content within a specific timeframe\n        - Combine with end_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-01-15" for January 15, 2024).\n        \n        Examples:\n        - "2024-01-01" - Results from January 1, 2024 onwards\n        - "2023-12-25" - Results from December 25, 2023 onwards\n        \n        When combined with end_date, creates a precise date range filter.\n        \n        Default is None (no start date restriction).\n        ',
#   'title': 'Start Date'},
#  'end_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#   'default': None,
#   'description': 'Filters search results to include only content published on or before this date.\n        \n        Use this parameter when you need to:\n        - Exclude content published after a certain date\n        - Study historical information or past events\n        - Research how topics were covered during specific time periods\n        - Combine with start_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-03-31" for March 31, 2024).\n        \n        Examples:\n        - "2024-03-31" - Results up to and including March 31, 2024\n        - "2023-12-31" - Results up to and including December 31, 2023\n        \n        When combined with start_date, creates a precise date range filter.\n        For example: start_date="2024-01-01", end_date="2024-03-31" \n        returns results from Q1 2024 only.\n        \n        Default is None (no end date restriction).\n        ',
#   'title': 'End Date'}}

# %% [markdown]
# ## LLM ToolCalling 흐름
#
# ### 1. Tool 생성 및 LLM Model에 tool binding
# - `LLM-Model.bind_tools(tools=[tool_1, tool_2, ...])`

# %%
from langchain_openai import ChatOpenAI
from langchain_tavily import TavilySearch

tavily_search = TavilySearch(max_results=5)
model=ChatOpenAI(model="gpt-5-mini") # 뇌 -> 성능 좋은 모델을 사용(판단자)
toolkit = [tavily_search] # tool들 모음
# model에 tool들을 binding
tool_model = model.bind_tools(tools=toolkit)

# print(type(tool_model), type(model))
# <class 'langchain_core.runnables.base.RunnableBinding'> <class 'langchain_openai.chat_models.base.ChatOpenAI'>
# Out:
# <class 'langchain_core.runnables.base.RunnableBinding'> <class 'langchain_openai.chat_models.base.ChatOpenAI'>

# %%
# 질문에 따른 응답 차이.
## tool 호출이 필요없는 질문.
# -> content에 답변 내용이 들어가있고, tool_calls는 빈 리스트가 되어있음 (tool_calls=[])
result = tool_model.invoke("안녕하세요.")

# %%
print(result.content) # LLM의 응답
# Out:
# 안녕하세요! 반갑습니다. 어떻게 도와드릴까요? (정보 검색, 번역, 글쓰기, 코딩, 공부 도움 등 무엇이든 말씀해 주세요.)

# %%
# tool 호출이 필요한 질문
# 답변 - content = "", tool_calls = list[dictionary-호출방식]
result2 = tool_model.invoke("2025/12/30 서울 날씨는 어때?")

# %%
result2
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 240, 'prompt_tokens': 1281, 'total_tokens': 1521, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsOfqVOjn59gy81NqfUHlvdW3Is6F', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b6e36-07b0-7bd1-9bd2-d1ccd4321660-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': '서울 2025-12-30 날씨', 'search_depth': 'fast', 'include_images': False, 'topic': 'general'}, 'id': 'call_OvPY0qckH29dzrTMF2oIvwnc', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1281, 'output_tokens': 240, 'total_tokens': 1521, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}})

# %%
# vars(result2) # vars(객체) -> 객체의 속성들을 dictionary로 반환.
print("응답메세지 :", result2.content) # ""
print("tool calls :", result2.tool_calls) # list[dict]
# Out:
# 응답메세지 :
# tool calls : [{'name': 'tavily_search', 'args': {'query': '서울 2025-12-30 날씨', 'search_depth': 'fast', 'include_images': False, 'topic': 'general'}, 'id': 'call_OvPY0qckH29dzrTMF2oIvwnc', 'type': 'tool_call'}]

# %% [markdown]
# ### 2. Tool 호출
# - LLM 모델이 tool 요청을 결정한 경우 **어떤 tool을 어떻게 호출할 지** AIMessage의 `tool_calls` 속성에 넣어 반환한다.
# - `tool_calls` 의 호출 정보를 넣어 `tool.invoke()` 호출한다.
#    - `tool.invoke(result.tool_calls[0])`
#    - **반환타입**: `ToolMessage`
#      - Tool의 처리결과를 담는 Message Type 이다.

# %%
# llm 응답(AIMessage)에 tool_calls가 있을 경우 tool을 호출

# result2.tools_calls : list[dict] dict-개별 tool 호출 정보, list는 묶어주는 역할.
search_result = tavily_search.invoke(result2.tool_calls[0])
type(search_result)
# Out:
# langchain_core.messages.tool.ToolMessage

# %%
search_result
# Out:
# ToolMessage(content='{"query": "서울 2025-12-30 날씨", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://rtonblog.com/%EC%84%9C%EC%9A%B8-%EB%82%A0%EC%94%A8-2025-12-01/", "title": "서울 날씨 2025-12-01 | Rton\'s Notes", "content": "Skip to content\\n\\n2025년 12월 04일\\n\\nRton’s Notes\\n\\n Home\\n 날씨\\n 서울 날씨 2025-12-01\\n\\n 날씨\\n\\n# 서울 날씨 2025-12-01\\n\\nlorel3572    2025년 12월 01일\\n\\n서울 날씨 2025-12-01에 대한 핵심 내용을 한 문단으로 정리합니다. 본 정리는 서울 날씨 2025-12-01의 맥락과 체크포인트를 함께 담았습니다.\\n\\n### 2025년 12월 1일 서울 날씨 브리핑 — 서울 날씨 2025-12-01\\n\\n오늘 서울의 날씨는 대체로 맑고 온화한 편입니다. 아침부터 저녁까지 강수 확률은 0%로, 비나 눈이 내릴 가능성은 전혀 없습니다. 기온은 최저 0.9도에서 최고 10.9도까지 오르며, 체감 온도는 바람의 영향으로 다소 낮게 느껴질 수 있습니다.\\n\\n### 시간대별 날씨 요약 [...] 아침 (06-11시)\\n  + 기온: 약 0.9도\\n  + 강수 확률: 0%\\n  + 바람: 9.9m/s\\n  + 체감 온도: 낮은 기온과 바람으로 인해 체감 온도는 더 낮게 느껴질 수 있습니다.\\n 오후 (12-17시)\\n  + 기온: 최고 10.9도\\n  + 강수 확률: 0%\\n  + 바람: 여전히 9.9m/s 유지\\n  + 체감 온도: 바람이 불기 때문에 실제 기온보다 더 쌀쌀하게 느껴질 수 있습니다.\\n 저녁 (18-23시)\\n  + 기온: 서서히 떨어짐\\n  + 강수 확률: 0%\\n  + 바람: 계속해서 9.9m/s\\n  + 체감 온도: 저녁에는 기온이 낮아져 체감 온도가 더욱 떨어질 것으로 예상됩니다.\\n\\n### 주의사항\\n\\n오늘은 강수 확률이 전혀 없지만, 바람이 강하게 불고 있어 체감 온도가 실제 기온보다 낮게 느껴질 것입니다. 외출 시 따뜻한 옷을 착용하고, 바람에 노출되지 않도록 주의하시기 바랍니다. 특히 아침과 저녁 시간대에는 기온이 더욱 낮아지므로 보온에 유의해야 합니다.", "score": 0.52071625, "raw_content": null}, {"url": "https://www.tiktok.com/discover/%EA%B8%88%EB%85%8412%EC%9B%9417%EC%9D%BC%EC%84%9C%EC%9A%B8-%EB%82%A0%EC%94%A8", "title": "금년12월17일서울 날씨 | TikTok", "content": "video coming tomorrow! #첫눈 #폭설 #snowfall #seoul #firstsnow. [2025년 12월 17일] 부동산 1분 뉴스 #광명재건축 #광명뉴타운 #안심주택 #종묘논란. ✅ 서울빛초롱축제 (청계천) 🗓️ 2025년 12월 12일 ~ 2026년 1월 4일 🔎청계천 (청계광장 ~ 삼일교 일대) 🕰️ 매일 저녁 18:00 ~ 22:00 청계천 물길을 따라 빛나는 포켓몬 콜라보 한정판 잉어킹과 함께 인생샷을 남겨보세요! (진짜 너무 귀여움😭) 근대 서울의 전차 추억의 판자촌 등 청계천 복원 20주년 기념 레트로 감성 조형물들까지 모두 만날 수 있어요 평범한 서울의 겨울밤 대신 동심과 힐링으로 채워진 특별한 밤 산책은 어떠세요? ✨ 서울 빛초롱 축제 정보🏮 📍청계천(청계광장~삼일교)·우이천 일대 🗓️ 2025년 12월 12일(금) ~ 2026년 1월 4일(일) ⏰ 매일 18:00 ~ 22:00 📸 필수 꿀팁:사람이 많으니 평일 6시 반 전에 도착하는 걸", "score": 0.3699755, "raw_content": null}, {"url": "https://sml1.kosmos2022.com/entry/실시간-서울-날씨-완벽-가이드-오늘-내일-주간-월간-예보-총정리-2025년-최신", "title": "실시간 서울 날씨 완벽 가이드: 오늘, 내일, 주간, 월간 예보 총정리 (2025년 최신)", "content": "시간 절약: 여러 사이트를 돌아다니며 날씨 정보를 찾을 필요 없이, 이 글 하나로 모든 정보가 해결됩니다.\\n 정확도: 대한민국 기상청 날씨누리를 기반으로 가장 신뢰할 수 있는 날씨 정보를 제공합니다.\\n 최신 정보: 실시간 업데이트를 통해 항상 최신의 날씨 정보를 확인할 수 있습니다.\\n 맞춤 정보: 서울시 각 구별 날씨 정보는 물론, 여행, 문화 행사, 교통 정보까지 제공하여 서울 생활에 필요한 모든 정보를 얻을 수 있습니다.\\n\\n지금 바로 확인하세요! 🔍\\n\\n### 1. 대한민국 기상청 날씨누리 기반, 실시간 서울 날씨 예보 완벽 정리\\n\\n서울 날씨, 이제 흩어진 정보를 찾아 헤매지 마세요! 대한민국 기상청 날씨누리를 토대로, 실시간 업데이트되는 서울 날씨 정보를 쉽고 빠르게 확인할 수 있도록 완벽하게 정리했습니다.\\n\\n#### 1.1. 원하는 날씨 정보를 즉시 찾으세요!", "score": 0.32376534, "raw_content": null}, {"url": "https://www.lightors.co.kr/8%EC%9B%9424%EC%9D%BC%20%EC%84%9C%EC%9A%B8%20%EB%82%A0%EC%94%A8", "title": "8월24일 서울 날씨 : 검색결과 | 드림워즈", "content": "서울특별시, 서울시, 대한민국 월별 날씨 - AccuWeather\\n\\n8월 9월 10월 11월 12월. 2025. 2024 2025 2026 · 일별. 일. 월. 화. 수. 목 ... 24. 93°. 78°. 25. 97°. 78°. 26. 99°. 82°. 27. 100°. 83°. 28. 98°. 84°. 29. 98°. 82°.\\n\\nwww.accuweather.com\\n\\n2022년 8월 24일 중·남부 최고 50㎜ 비…서울 낮기온 28도 - 경향신문\\n\\nwww.khan.co.kr\\n\\n경향신문 › article\\n\\n2022년 8월 24일 중·남부 최고 50㎜ 비…서울 낮기온 28도 - 경향신문\\n\\n2022년 8월 24일 중·남부 최고 50㎜ 비…서울 낮기온 28도. 입력 2022.08.23 21:40. [오늘의 날씨]2022년 8월 24일 중·남부 최고 50. 좋아요. 댓글 쓰기.\\n\\nwww.khan.co.kr", "score": 0.31697202, "raw_content": null}, {"url": "https://olivia123.tistory.com/entry/2025%EB%85%84-11%EC%9B%94-%EC%84%9C%EC%9A%B8%EC%9D%98-%EB%82%A0%EC%94%A8-%EC%84%9C%EC%9A%B8-%EB%82%A0%EC%94%A8-%ED%95%9C%EB%8B%AC-%EC%98%88%EB%B3%B4", "title": "2025년 11월 서울의 날씨/ 서울 11월 날씨 예보", "content": "자세히 알아보기\\n\\n날씨 예보\\n\\n서울\\n\\n일기예보\\n\\n서울특별시\\n\\n식료품\\n\\n2025년 11월 서울의 날씨/ 서울 11월 날씨 예보\\n\\n본문 바로가기\\n\\n온달\\n\\n메뉴\\n   홈\\n   태그\\n   방명록\\n\\n  \\n\\n카테고리 없음\\n\\n2025년 11월 서울의 날씨/ 서울 11월 날씨 예보\\n\\n쏘니훈 2025. 10. 4. 17:12\\n\\n반응형\\n\\n서울의 11월은 가을에서 겨울로 넘어가는 과도기로, 날씨 변화가 뚜렷하게 나타납니다.\\n\\n아침저녁은 기온이 5℃ 안팎으로 떨어지고 낮에는 10℃ 이상 오르며 큰 일교차가 특징입니다. 11월 초까지는 단풍의 절정으로 사람들의 이동이 많은 시기이기도 합니다.\ ...

# %%
search_result.content
# Out:
# '{"query": "서울 2025-12-30 날씨", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://rtonblog.com/%EC%84%9C%EC%9A%B8-%EB%82%A0%EC%94%A8-2025-12-01/", "title": "서울 날씨 2025-12-01 | Rton\'s Notes", "content": "Skip to content\\n\\n2025년 12월 04일\\n\\nRton’s Notes\\n\\n Home\\n 날씨\\n 서울 날씨 2025-12-01\\n\\n 날씨\\n\\n# 서울 날씨 2025-12-01\\n\\nlorel3572    2025년 12월 01일\\n\\n서울 날씨 2025-12-01에 대한 핵심 내용을 한 문단으로 정리합니다. 본 정리는 서울 날씨 2025-12-01의 맥락과 체크포인트를 함께 담았습니다.\\n\\n### 2025년 12월 1일 서울 날씨 브리핑 — 서울 날씨 2025-12-01\\n\\n오늘 서울의 날씨는 대체로 맑고 온화한 편입니다. 아침부터 저녁까지 강수 확률은 0%로, 비나 눈이 내릴 가능성은 전혀 없습니다. 기온은 최저 0.9도에서 최고 10.9도까지 오르며, 체감 온도는 바람의 영향으로 다소 낮게 느껴질 수 있습니다.\\n\\n### 시간대별 날씨 요약 [...] 아침 (06-11시)\\n  + 기온: 약 0.9도\\n  + 강수 확률: 0%\\n  + 바람: 9.9m/s\\n  + 체감 온도: 낮은 기온과 바람으로 인해 체감 온도는 더 낮게 느껴질 수 있습니다.\\n 오후 (12-17시)\\n  + 기온: 최고 10.9도\\n  + 강수 확률: 0%\\n  + 바람: 여전히 9.9m/s 유지\\n  + 체감 온도: 바람이 불기 때문에 실제 기온보다 더 쌀쌀하게 느껴질 수 있습니다.\\n 저녁 (18-23시)\\n  + 기온: 서서히 떨어짐\\n  + 강수 확률: 0%\\n  + 바람: 계속해서 9.9m/s\\n  + 체감 온도: 저녁에는 기온이 낮아져 체감 온도가 더욱 떨어질 것으로 예상됩니다.\\n\\n### 주의사항\\n\\n오늘은 강수 확률이 전혀 없지만, 바람이 강하게 불고 있어 체감 온도가 실제 기온보다 낮게 느껴질 것입니다. 외출 시 따뜻한 옷을 착용하고, 바람에 노출되지 않도록 주의하시기 바랍니다. 특히 아침과 저녁 시간대에는 기온이 더욱 낮아지므로 보온에 유의해야 합니다.", "score": 0.52071625, "raw_content": null}, {"url": "https://www.tiktok.com/discover/%EA%B8%88%EB%85%8412%EC%9B%9417%EC%9D%BC%EC%84%9C%EC%9A%B8-%EB%82%A0%EC%94%A8", "title": "금년12월17일서울 날씨 | TikTok", "content": "video coming tomorrow! #첫눈 #폭설 #snowfall #seoul #firstsnow. [2025년 12월 17일] 부동산 1분 뉴스 #광명재건축 #광명뉴타운 #안심주택 #종묘논란. ✅ 서울빛초롱축제 (청계천) 🗓️ 2025년 12월 12일 ~ 2026년 1월 4일 🔎청계천 (청계광장 ~ 삼일교 일대) 🕰️ 매일 저녁 18:00 ~ 22:00 청계천 물길을 따라 빛나는 포켓몬 콜라보 한정판 잉어킹과 함께 인생샷을 남겨보세요! (진짜 너무 귀여움😭) 근대 서울의 전차 추억의 판자촌 등 청계천 복원 20주년 기념 레트로 감성 조형물들까지 모두 만날 수 있어요 평범한 서울의 겨울밤 대신 동심과 힐링으로 채워진 특별한 밤 산책은 어떠세요? ✨ 서울 빛초롱 축제 정보🏮 📍청계천(청계광장~삼일교)·우이천 일대 🗓️ 2025년 12월 12일(금) ~ 2026년 1월 4일(일) ⏰ 매일 18:00 ~ 22:00 📸 필수 꿀팁:사람이 많으니 평일 6시 반 전에 도착하는 걸", "score": 0.3699755, "raw_content": null}, {"url": "https://sml1.kosmos2022.com/entry/실시간-서울-날씨-완벽-가이드-오늘-내일-주간-월간-예보-총정리-2025년-최신", "title": "실시간 서울 날씨 완벽 가이드: 오늘, 내일, 주간, 월간 예보 총정리 (2025년 최신)", "content": "시간 절약: 여러 사이트를 돌아다니며 날씨 정보를 찾을 필요 없이, 이 글 하나로 모든 정보가 해결됩니다.\\n 정확도: 대한민국 기상청 날씨누리를 기반으로 가장 신뢰할 수 있는 날씨 정보를 제공합니다.\\n 최신 정보: 실시간 업데이트를 통해 항상 최신의 날씨 정보를 확인할 수 있습니다.\\n 맞춤 정보: 서울시 각 구별 날씨 정보는 물론, 여행, 문화 행사, 교통 정보까지 제공하여 서울 생활에 필요한 모든 정보를 얻을 수 있습니다.\\n\\n지금 바로 확인하세요! 🔍\\n\\n### 1. 대한민국 기상청 날씨누리 기반, 실시간 서울 날씨 예보 완벽 정리\\n\\n서울 날씨, 이제 흩어진 정보를 찾아 헤매지 마세요! 대한민국 기상청 날씨누리를 토대로, 실시간 업데이트되는 서울 날씨 정보를 쉽고 빠르게 확인할 수 있도록 완벽하게 정리했습니다.\\n\\n#### 1.1. 원하는 날씨 정보를 즉시 찾으세요!", "score": 0.32376534, "raw_content": null}, {"url": "https://www.lightors.co.kr/8%EC%9B%9424%EC%9D%BC%20%EC%84%9C%EC%9A%B8%20%EB%82%A0%EC%94%A8", "title": "8월24일 서울 날씨 : 검색결과 | 드림워즈", "content": "서울특별시, 서울시, 대한민국 월별 날씨 - AccuWeather\\n\\n8월 9월 10월 11월 12월. 2025. 2024 2025 2026 · 일별. 일. 월. 화. 수. 목 ... 24. 93°. 78°. 25. 97°. 78°. 26. 99°. 82°. 27. 100°. 83°. 28. 98°. 84°. 29. 98°. 82°.\\n\\nwww.accuweather.com\\n\\n2022년 8월 24일 중·남부 최고 50㎜ 비…서울 낮기온 28도 - 경향신문\\n\\nwww.khan.co.kr\\n\\n경향신문 › article\\n\\n2022년 8월 24일 중·남부 최고 50㎜ 비…서울 낮기온 28도 - 경향신문\\n\\n2022년 8월 24일 중·남부 최고 50㎜ 비…서울 낮기온 28도. 입력 2022.08.23 21:40. [오늘의 날씨]2022년 8월 24일 중·남부 최고 50. 좋아요. 댓글 쓰기.\\n\\nwww.khan.co.kr", "score": 0.31697202, "raw_content": null}, {"url": "https://olivia123.tistory.com/entry/2025%EB%85%84-11%EC%9B%94-%EC%84%9C%EC%9A%B8%EC%9D%98-%EB%82%A0%EC%94%A8-%EC%84%9C%EC%9A%B8-%EB%82%A0%EC%94%A8-%ED%95%9C%EB%8B%AC-%EC%98%88%EB%B3%B4", "title": "2025년 11월 서울의 날씨/ 서울 11월 날씨 예보", "content": "자세히 알아보기\\n\\n날씨 예보\\n\\n서울\\n\\n일기예보\\n\\n서울특별시\\n\\n식료품\\n\\n2025년 11월 서울의 날씨/ 서울 11월 날씨 예보\\n\\n본문 바로가기\\n\\n온달\\n\\n메뉴\\n   홈\\n   태그\\n   방명록\\n\\n  \\n\\n카테고리 없음\\n\\n2025년 11월 서울의 날씨/ 서울 11월 날씨 예보\\n\\n쏘니훈 2025. 10. 4. 17:12\\n\\n반응형\\n\\n서울의 11월은 가을에서 겨울로 넘어가는 과도기로, 날씨 변화가 뚜렷하게 나타납니다.\\n\\n아침저녁은 기온이 5℃ 안팎으로 떨어지고 낮에는 10℃ 이상 오르며 큰 일교차가 특징입니다. 11월 초까지는 단풍의 절정으로 사람들의 이동이 많은 시기이기도 합니다.\\n\\n살짝 추워지기는 하지만 낮에 ...

# %% [markdown]
# ##### tool_call 이 여러개일 경우
# - 질의에 대해 tool을 여러번 호출 해야 하는 경우 tool_calling 정보를 여러개 반환할 수 있다.
#     - 예) 검색할 키워드가 여러개인 경우.
# - `tool.batch([tool_call1, tool_call2, ..])`

# %%
# tool call이 여러 개인 경우
query = "2025년 KBO, MLB, NPB 리그의 우승팀을 알려줘"
result=tool_model.invoke(query)

# %%
print(result.content) # ""으로 나옴 > tool_calls 호출

# %%
result.tool_calls
# Out:
# [{'name': 'tavily_search',
#   'args': {'query': '2025 KBO 챔피언 2025 한국시리즈 우승팀',
#    'search_depth': 'advanced',
#    'topic': 'general'},
#   'id': 'call_QALJPUzzLxu5HD8IKysP2OQP',
#   'type': 'tool_call'},
#  {'name': 'tavily_search',
#   'args': {'query': '2025 World Series champion 2025 MLB champion World Series winner',
#    'search_depth': 'advanced',
#    'topic': 'general'},
#   'id': 'call_FSphFDEwlkagmHaO377TteQ6',
#   'type': 'tool_call'},
#  {'name': 'tavily_search',
#   'args': {'query': '2025 NPB champion 2025 Japan Series winner 2025 日本シリーズ 優勝',
#    'search_depth': 'advanced',
#    'topic': 'general',
#    'include_images': False},
#   'id': 'call_lVarS8Zbv50dlG0qpZaJtce1',
#   'type': 'tool_call'}]

# %%
# for tool_call in result.tool_calls:
#     tool_model.invoke(tool_call)

# 이렇게 복잡한 과정을 거쳐야하는데 아래의 방법으로 간편하게 해결할 수 있음.

# Runnable : invoke()/stream() - 개별요청, batch() : 한번에 여러개 요청.
search_result_list = tavily_search.batch(result.tool_calls) # [toolcall, toolcall, ...]

# %%
search_result_list # list[ToolMessage]
# Out:
# [ToolMessage(content='{"query": "2025 KBO 챔피언 2025 한국시리즈 우승팀", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://namu.wiki/w/2025%20%EC%8B%A0%ED%95%9C%20SOL%20Bank%20KBO%20%ED%95%9C%EA%B5%AD%EC%8B%9C%EB%A6%AC%EC%A6%88", "title": "2025 신한 SOL Bank KBO 한국시리즈 - 나무위키", "content": "2025 신한 SOL Bank KBO 리그 페넌트 레이스 1위 LG 트윈스와 페넌트 레이스 2위 플레이오프 승리팀 한화 이글스가 맞붙은 역대 43번째 한국시리즈.  \\n  \\nLG는 2023년 통합 우승 이후 2년 만에 다시 한국시리즈에 진출했으며, 통산 4번째 한국시리즈 우승 및 10개 구단 최초의 2020년대 2번째 통합 우승을 노렸다. 한화는 2006년 한국시리즈 이후 19년 만에 한국시리즈에 진출했으며, 1999년 한국시리즈 우승 이후 26년 만의 2번째 한국시리즈 우승을 조준했다. [...] 한국시리즈에서도 LG는 역대 1위인 팀 타선 wRC+ 157.3과 팀 홈런 8개를 집중시키는 어마어마한 파괴력을 바탕으로 우승 트로피를 품에 안았고, 작년 우승팀 KIA 역시 플레이오프를 치르며 지친 삼성 투수진을 상대로 타선의 힘을 바탕으로 우승을 이뤄냈다.\\") [...] LG팀이 트윈스팀을 상대로 3:5 승리를 거두었다.  \\n  \\n부상으로 빠졌던 문성주가 첫 타석부터 안타를 때렸고, 천성호와 박관우, 이주헌 등의 한국시리즈 승선 확률이 높은 백업 선수들 안타를 쳤다. 문보경과 신민재가 무안타인건 불안요소지만, 오지환과 김현수가 좋은 타격감을 보였다. 투수는 장현식과 이정용을 제외하면 모두 준수했다.  \\n  \\n경기 후 주장 박해민은 꼭 우승하겠다는 다짐을 보였다.", "score": 0.99988496, "raw_content": null}, {"url": "https://www.chosun.com/sports/baseball/2025/10/31/MQMV676MQJHLNGD7JEIAKWFMEQ/", "title": "LG, 한화 꺾고 2년 만에 한국시리즈 우승 - 조선일보", "content": "스포츠야구\\n\\n대전=배준용 기자\\n\\n대전=강우석 기자\\n\\n입력 2025.10.31. 21:37업데이트 2025.11.03. 09:48\\n\\n26\\n\\n26\\n\\n2025 KBO(한국야구위원회)리그 최강자가 가려졌다. 2023시즌 29년만의 통합우승을 이뤄낸 LG가 2시즌 만에 정규시즌과 한국시리즈 우승을 모두 탈환, 한국 프로야구 최정상에 다시 섰다.\\n\\nLG는 31일 대전 한화생명볼파크에서 열린 한국시리즈 5차전에서 외인 선발 앤더슨 톨허스트의 눈부신 호투와 3안타 2타점을 몰아친 김현수의 활약으로 한화에 4대1 완승을 거두며 시리즈 전적 4승1패로 2025시즌 통합 챔피언에 등극했다. [...] 9회말 LG 마무리 유영찬이 마운드에 올랐다. 선두타자 리베라토를 3루수 플라이로 잡아냈다. 문현빈이 친 타구도 높게 솟으며 중견수 플라이가 됐다. 2사에 노시환이 좌전 안타로 출루했지만 이어진 채은성의 타구가 3루수 앞으로 힘없이 흘렀다. 유영찬이 이 타구를 재빨리 잡아 1루에 던졌고, 3아웃이 되면서 2025 한국 시리즈는 LG의 통합우승으로 대단원의 막을 내렸다. 5차전 MVP는 선발 투수로 완벽투를 펼친 톨허스트, 2025 한국시리즈 MVP는 지난 4차전 9회말 2사에 역전 적시 2루타를 포함 17타수 9안타(타율 0.529) 1홈런 8타점을 몰아친 김현수다.\\n\\n전문가 대부분은 올 시즌 후반기부터 가장 강력한 우승 후보로 LG를 꼽아왔다. 강팀의 기본 조건이라고 할 수 있는 투수력과 수비가 탁월하고 타선의 조화에 선수단의 뎁스까지 갖췄다는 게 지배적인 평가였다. 결국 정규시즌 우승에 이어 한국시리즈 우승까지 차지하며 ‘무적 LG’를 실력으로 입증했다. [...] “아들에게 한국 이름을 주고 싶은데, 뭐가 좋을까?” 대전을 떠났지만, 한화 이글스를 향한 애정만은 여전히 뜨겁다. 메이저리그에서 제2...\\n\\n100자평\\n\\n26\\n\\n도움말삭제기준\\n\\n최신순관심순\\n\\n고치\\n\\n2025.11.01 18:15\\n\\n뿌린 만큼 거두다, 파이팅\\n\\n0\\n\\n0\\n\\nthe boxer\\n\\n2025.11.01 09:13\\n\\n엘지야구선수들 잘했어 ~김승연이 야구방망이 이겨야해!승연이 요즘 방상주 많이 올랐다고 많이 어시데는데 ~그 아들들 돈 으로 검사님들 을 농락하는데 이것 사람입니까~승연이 하고 두아들 아웃~감사합니다\\n\\n0\\n\\n0\\n\\n산으로\\n\\n2025.11.01 08:17\\n\\nLG우승을 축하한다. 올해 한국시리즈=김경문시리즈 였다.야구 어렵다며 야구 너무 쉽게 생각한 김경문의 인생 최고 작이었다.ㅍㅎㅎㅎㅎㅎ 5차전서도 김서현이 등판시켰어야지.ㅍㅎㅎㅎㅎㅎㅎㅎㅎㅎ\\n\\n0\\n\\n0", "score": 0.9976586, "raw_content": null}, {"url": "https://www.threads.com/@kbo.official/post/DQeeog2k8UB/2025-kbo-%EB%A6%AC%EA%B7%B8-%ED%86%B5%ED%95%A9-%EC%B1%94%ED%94%BC%EC%96%B8-lg%ED%8A%B8%EC%9C%88%EC%8A%A42025-kbo-%EB%A6%AC%EA%B7%B8-%ED%86%B5%ED%95%A9-%EC%9A%B0%EC%8A%B9%EC%9D%98-%EC%A3%BC%EC%9D%B8%EA%B3%B5%EC%9D%80-lg%ED%8A%B8%EC%9C%88%EC%8A%A4%EC%9E%85%EB%8B%88%EB%8B%A42023-%ED%86%B5%ED%95%A9-%EC%9A%B0%EC%8A%B9%EC%97%90-%EC%9D%B4%EC%96%B4-2%EB%85%84-%EB%A7%8C%EC%97%90-lg%ED%8A%B8", "title": "[2025 KBO 리그 통합 챔피언] LG트윈스", "content": "# Thread\\n\\n2.2K views\\n\\nkbo.official\\n\\n[2025 KBO 리그 통합 챔피언] LG트윈스2025 KBO 리그 통합 우승의 주인공은 LG트윈스입니다!2023 통합 우승에 이어 2년 만에 LG트윈스가 다시 한 번 왕좌의 자리에 오릅니다!정규시즌부터 이어진 막강한 전력,\\n추운 가을 응원석을 뜨겁게 녹인 팬들이 모여\\n2025년 가을, 다시 한 번 트윈스의 시대를 열었습니다!2025년 KBO 리그를 정복하며, V4를 달성한 LG트윈스의 통합 우승을 축하드립니다!#야구 #baseball #KBO #KBO리그 #포스트시즌 #가을야구 #한국시리즈 #LG #LG트윈스 #우승 #챔피언\\n\\n149\\n\\n8\\n\\n9\\n\\n1\\n\\nnam\\\\_sun\\\\_2\\n\\n크으 행복합니다 무적엘지\\n\\nTranslate\\n\\n1\\n\\nsem1863\\n\\n스친 엘지야?? 우리도야 ㅋㅋㅋ\\n\\nTranslate\\n\\n1\\n\\n1\\n\\nnam\\\\_sun\\\\_2\\n\\n나 완전 엘지야 ㅋㅋㅋ 그래서 어제 우승파티도 다녀왔엉 ㅋㅋㅋㅋ\\n\\nTranslate\\n\\n1 [...] 1\\n\\nsem1863\\n\\n어제 우승파티 했어? 우리집은 아들이 완전 팬이야\\n\\nTranslate\\n\\n1\\n\\n1\\n\\nnam\\\\_sun\\\\_2\\n\\n어제 우승해서 무려 파티였어 선수들 청백전 진짜 너무 재밌었엉\\n\\nTranslate\\n\\n1\\n\\ntwins\\\\_inspired\\n\\n행복합니다ㅠㅠㅠㅠㅠ\\n\\nTranslate\\n\\nsseokwany\\n\\n이 사진 가져가오~~ 크보 오피셜이자너 ^^/\\n\\nTranslate\\n\\nhy1.rxm\\n\\n히히 대황지🫶\\n\\nTra ...
#  ToolMessage(content='{"query": "2025 World Series champion 2025 MLB champion World Series winner", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://en.wikipedia.org/wiki/2025_World_Series", "title": "2025 World Series", "content": "The 2025 World Series (branded as the 2025 World Series presented by Capital One) was the championship series of Major League Baseball\'s (MLB) 2025 season. The 121st edition of the World Series was a best-of-seven playoff series between the National League \\"National League (baseball)\\") (NL) champion and defending World Series champion Los Angeles Dodgers and the American League (AL) champion Toronto Blue Jays. The series lasted from October 24 to November 1, with the Dodgers defeating the Blue [...] the Tampa Bay Rays on the last day of the season, securing their first AL East division title since 2015. The Blue Jays and Yankees finished tied, but by virtue of their 8–5 regular season head-to-head record against New York, Toronto won the division. [...] [edit]\\n\\nLos Angeles won the series, 4–3.", "score": 0.9418739, "raw_content": null}, {"url": "https://www.mlb.com/news/dodgers-win-2025-world-series-repeating-as-champions", "title": "Dodgers win 2025 World Series, repeating as champions", "content": "While Snell, Yoshinobu Yamamoto, Glasnow and Shohei Ohtani had put up historic numbers in the first three rounds, the Blue Jays made the four-headed monster of a rotation look mortal during the World Series. That laid bare a scuffling Dodgers offense, and the aforementioned bullpen, that had been inconsistent for so much of the year. [...] Some were beyond their control. The injury bug returned, with Snell hitting the IL after two starts, Tyler Glasnow after five and Sasaki after eight. The rotation was not at full strength until August, when it became the best in baseball across the final two months of the regular season. [...] # LA basking in \'golden era of Dodger baseball\'\\n\\nNovember 2nd, 2025\\n\\nSonja Chen\\n\\n@sonjamchen\\n\\nTORONTO -- The Dodgers never expected this to be easy.\\n\\nThe prior 24 World Series champions could have told them: No matter the talent you have, no matter how favorable the situation, repeating as champion is a tall task. Knowing that, the Dodgers set out to do everything in their power to position themselves for a run at another title.", "score": 0.74273956, "raw_content": null}, {"url": "https://www.espn.com/mlb/worldseries/history/winners", "title": "MLB World Series Winners", "content": "| MLB World Series Winners |\\n| SEASON | WINNER | LOSER | SERIES |\\n| 2024 | Los Angeles Dodgers | New York Yankees | 4-1 |\\n| 2023 | Texas Rangers | Arizona Diamondbacks | 4-1 |\\n| 2022 | Houston Astros | Philadelphia Phillies | 4-2 |\\n| 2021 | Atlanta Braves | Houston Astros | 4-2 |\\n| 2020 | Los Angeles Dodgers | Tampa Bay Rays | 4-2 |\\n| 2019 | Washington Nationals | Houston Astros | 4-3 |\\n| 2018 | Boston Red Sox | Los Angeles Dodgers | 4-1 |\\n| 2017 | Houston Astros | Los Angeles Dodgers | 4-3 | [...] Menu\\n\\n## ESPN\\n\\n scores\\n\\nESPN.com: Help | Press | Advertise on ESPN.com | Sales Media Kit | Interest-Based Ads | Do Not Sell or Share My Personal Information | Corrections | Contact Us | Site Map | Jobs at ESPN   \\n© 2025 ESPN Internet Ventures. Terms of Use, Privacy Policy, Your US State Privacy Rights, Children\'s Online Privacy Policy and Interest-Based Ads are applicable to you. All rights reserved. [...] # MLB World Series Winners\\n\\n All-Time Historical Stats »\\n All Star Game History »\\n Draft History »\\n Hall of Fame History »\\n\\n|  |", "score": 0.451448, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=UEv1WTdLpQc", "title": "FULL GAME: Freddie Freeman wins an 18-inning THRILLER ...", "content": "Beautiful Dodger Stadium in Los Angeles. 70° ready for first pitch. Dodgers looking for back-to-back titles in a stadium that is ready to host its 30th World Series game. Only Fenway  ...
#  ToolMessage(content='{"query": "2025 NPB champion 2025 Japan Series winner 2025 日本シリーズ 優勝", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.youtube.com/watch?v=qWLYq_ie2zs", "title": "SoftBank Hawks Win 2025 Japan Series!", "content": "All right, the 2025 season of Nepone Professional Baseball in Japan is history. The South Bank Hawks, for the first time in 5 years and the 12th time overall, are Japan Series champions. Combined with their two championships in the Old Japan Baseball League, their grand total is 14 titles. Doesn\'t sound like much in over 80 years of existence, but eight of those titles have come in the last 15 years. The Hawks are the team of the century in NPB right now. Even though their most dominant days [...] Japan series and made it interesting is the Hokkaido Neponham Fighters, the former team of Shi Otani and Udarvish. They haven\'t won it since 2016. a last place team a couple years ago, but they\'ve turned things around under manager Sioshi Shinjjo. Quite an unconventional manager, especially by NPB standards. They pushed the Hawks to seven games, even though the Hawks started the series with a ghost win. I guess that was the highlight of the NPB postseason this year. So, we were left with Hawks [...] players weren\'t on their last championship team and this was their first Japan series title. Also the first title for the Hawks new manager. So there\'s that. Can\'t hate them for being the best. Just hope that next year a new team rises up and shakes things up a bit. Anyway, that\'s all for this one. Until next time, this is Baseball International. See you.", "score": 0.9997677, "raw_content": null}, {"url": "https://worldbaseball.com/npb-fukuoka-softbank-hawks-win-2025-japan-series/", "title": "NPB: Fukuoka SoftBank Hawks Win 2025 Japan Series", "content": "# NPB: Fukuoka SoftBank Hawks Win 2025 Japan Series\\n\\n Yuri Karasawa\\n October 30, 2025\\n\\nThe Hanshin Tigers faithful were left stunned on Thursday night as the Fukuoka SoftBank Hawks clinched the 2025 Japan Series in front of 41,606 fans at Koshien Stadium with a 3-2 extra-inning victory. [...] After Hanshin took the opener on the road, SoftBank responded emphatically, winning four straight games to capture their first championship since 2020 and 12th Nippon Professional Baseball title and the 14th in franchise history, including their pre-NPB titles before 1950. First baseman Hotaka Yamakawa was named series MVP after homering in Games 2, 3, and 4. [...] Yamakawa tied the game with a solo home run off Saiki in the fourth, and Tatsuru Yanagimachi gave the Hawks the lead with an RBI triple in the sixth. From there, SoftBank’s three-headed dragon in the pen – Kouya Fujii, Yuki Matsumoto, and Kazuki Sugiyama – slammed the door to preserve the victory.", "score": 0.9991768, "raw_content": null}, {"url": "https://japanball.com/japanese-baseball-news/npb-newsletter/softbank-hawks-triumph-in-2025-japan-series/?srsltid=AfmBOopE_zhz10ytBlk668Y4vS5mG5cNIArr9fXTL3gYh6s6Bm7v8tkF", "title": "SoftBank Hawks Triumph in 2025 Japan Series!", "content": "Home Japanese Baseball NewsNPB NewslettersSoftBank Hawks Triumph in 2025 Japan Series!\\n\\n# SoftBank Hawks Triumph in 2025 Japan Series!\\n\\nby Yuri Karasawa\\n\\n1.3K\\n\\nThe 2025 Japan Series and World Series are in the history books as the Fukuoka SoftBank Hawks defeated the Hanshin Tigers in five games, and the Los Angeles Dodgers edged the Toronto Blue Jays in an epic Game 7. [...] Congratulations to former Orix Buffalo Yoshinobu Yamamoto on winning World Series MVP after one of the gutsiest performances in postseason history! Over in NPB, slugger Hotaka Yamakawa was named Japan Series MVP for hitting three home runs as the juggernaut Hawks secured their first title since 2020 and their 12th in franchise history.\\n\\nLet’s look back at the final three games of the Nippon Series at Koshien Stadium.\\n\\n## Game 3: SoftBank 2 – 1 Hanshin [...] in celebrati ...

# %% [markdown]
# ### 3. Tool의 처리(응답) 결과를 LLM 요청시 사용
# - ToolMessage를 prompt 에 추가하여 LLM에 요청한다.
# - ToolMessage 는 Tool Calling 정보를 가진 AIMessage 다음에 들어와야 한다.
# - Prompt 순서
#     1. 일반 prompt (system, 대화 history, .., human)
#     2. AIMessage: tool calling 정보를 가진 AIMessage. (tool_model에 질의 받은 tool calling 정보가 있는 응답)
#     3. ToolMessage:  Tool의 처리 결과

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

prompt = ChatPromptTemplate(
    [
        ("system", "당신은 AI Assistant입니다. 제공된 정보를 바탕으로 답변을 해주세요."),
        ("human","{query}"),
        MessagesPlaceholder(variable_name="tool_messages", optional=True)
    ]
)

chain = prompt | tool_model

final_result = chain.invoke(
    {
        "query":query,
        "tool_messages":[result, *search_result_list]
    }
)

# "tool_messages":[result:toolcall 정보가 있는 AIMessage,
#                   *search_result_list : ToolMessage - tool의 처리 결과]

# %%
print(final_result.content)
# Out:
# 여기요 — 2025 시즌 각 리그 우승팀입니다.
#
# - KBO (한국) : LG 트윈스 — 2025 한국시리즈 우승
# - MLB (미국) : Los Angeles Dodgers — 2025 World Series 우승 (토론토 블루제이스 상대로)
# - NPB (일본) : Fukuoka SoftBank Hawks — 2025 일본시리즈 우승 (한신 타이거즈 상대로)
#
# 더 자세한 시리즈 스코어, MVP, 결정 경기 요약 원하시면 알려주세요.

# %%
print(final_result.tool_calls) # -> tool호출 -> llm 요청
# Out:
# []

# %% [markdown]
# # 사용자 정의 Tool 구현
#
# ## @tool 사용
# - 함수로 구현하고 `@tool` 데코레이터를 사용해 tool(StructuredTool)로 정의한다.
#     - `langchain_core.tools` 모듈에 있다.
# - tool name
#     - 함수의 이름이 tool의 이름이 된다.
# - parameters
#     - 함수의 파라미터가 tool의 파라미터가 된다.
#     - **type hint**를 이용해 타입을 지정한다.
# - description
#     - doctring이 description이 된다.
#     - RunnableBinding이 tool을 잘 찾을 수 있도록 하려면 **tool의 기능을 최대한 구체적**으로 작성한다.
# - **@tool이 적용된 함수(StructuredTool)이 tool**이므로 model에 binding 한다.

# %% [markdown]
# ## Runnable을 tool로 정의
# - `Runnable객체.as_tool()`
#     - name, description, args_schema 파라미터를 이용해 tool의 이름, 설명, 스키마를 설정한다.

# %% [markdown]
# ## Vector Store(Vector 저장소) tool
#
# ### text loading -> Document 생성
# - 레스토랑 메뉴를 vector store에 저장한다.
# 1. 메뉴 text 를 로딩한다.
# 2. 각 메뉴의 내용(음식이름, 메뉴설명, 파일명)을 넣어 Document를 생성한다.

# %%
# 문서 Load
import os
# 메뉴읽어 오기
menu_file_path = "data/restaurant_menu.txt"
with open(menu_file_path, "r", encoding="utf-8") as f:
    menu = f.read()

# %%
# Split - 메뉴별로 분리하기 위해 직접 처리
from langchain_core.documents import Document
import re
from pprint import pprint

def create_documents(menu_all: str, file_name) -> list[Document]:
    """메뉴별로 분리 한뒤 Document로 변환. 변환된 Document들을 리스트로 반환
    metadata: 메뉴이름, 주요 재료, 가격, source(파일이름)
    """
    menu_list = menu_all.split("\n\n")
    menu_documents = []
    for menu_item in menu_list:

        # 메뉴 이름 추출
        menu_name_pattern = r"(^\d+.\s)([가-힣a-zA-Z\d ]+)"
        menu_name_result = re.search(menu_name_pattern, menu_item)
        menu_name = menu_name_result.group(2).strip()  # 메뉴 이름 추출 # 1은 번호

        # 주요재료 추출 - text로 indexing.
        menu_ingredient_pattern = r"(?<=주요 재료: ).+"
        ingredients = re.search(menu_ingredient_pattern, menu_item).group().strip()
    
        # 가격추출
        price_pattern = r"(?<=가격: )[\d,]+(?=원)"
        price_result = re.search(price_pattern, menu_item)
        price = int(price_result.group().replace(",", ""))

        
        # 메뉴 이름을 제외한 나머지는 메뉴 설명으로 간주
        menu_doc = Document(
            page_content=menu_item,     # 메뉴 설명을 page_content에 넣는다. metadata는 나중에 따로 따로 payload filtering 할 수있기 때문에 
            metadata={
                "menu_name": menu_name, # 메뉴 이름
                "price": price,         # 가격
                "ingredients": ingredients, # 재료 리스트
                "source": file_name     # 메뉴가 저장된 파일 이름
            }
        )
        menu_documents.append(menu_doc)
    return menu_documents


menu_documents = create_documents(menu, menu_file_path)
print(len(menu_documents))

# %%
# VectorDB 저장 및 VectorStore 생성
from langchain_qdrant import QdrantVectorStore
from langchain_openai import OpenAIEmbeddings
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams
from dotenv import load_dotenv

load_dotenv()

COLLECTION_NAME = "restaurant_menu"
VECTOR_SIZE = 1536  # OpenAIEmbeddings의 벡터 크기

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

client = QdrantClient(host="localhost", port=6333)
if client.collection_exists(COLLECTION_NAME):
    client.delete_collection(COLLECTION_NAME)

# Collection 생성
client.create_collection(
    collection_name=COLLECTION_NAME,
    # 벡터 저장소에 대한 설정. - vector_config는 default이므로 이름을 안줘도 됨(default 로 잡힘) 이름을 줄 거면 {"이름":VectorParams()} 설정
    vectors_config=VectorParams(
        size=VECTOR_SIZE, 
        distance=Distance.COSINE
    )
)

vectorstore = QdrantVectorStore(
    client=client, # QdrantClient
    embedding=embeddings, # Embedding Model
    collection_name=COLLECTION_NAME # 연결할 Collection 지정.
)
ids = vectorstore.add_documents(menu_documents)
print(f"저장된 문서 개수: {len(ids)}")
##################################################
# Retriever 생성
##################################################
menu_retriever = vectorstore.as_retriever(
    search_kwargs={"k": 3}  # 검색할 결과 개수
)

from langchain_core.runnables import ConfigurableField
retriever = menu_retriever.configurable_fields(
    search_type=ConfigurableField(
        id="search_type"
    ),
    search_kwargs=ConfigurableField(
        id="search_kwargs"
    ),
)

# %% [markdown]
# # create_agent() 를 이용한 Agent 구현
#
# - create_agent()
#   - Agent 생성 및 실행을 표준화, 단순화 하기 위헤 Langchain 1.0에서 도입된 함수
#   - 0.x 버전까지는 Agent 생성 함수는
#     1. model과 tool들을 넣어 Agent를 생성하고
#     2. 그것을 실행하는 Executor를 생성하는 방식으로
#   - 여러 단계를 거쳐야 했다.
#   - create_agent()는 이러한 단계를 1단계로 축약한 API이다.
#
# - create_agent 설계 철학
#     1. Agent를 구성하는 모든 실행단위는 Runnable 이다.
#     2. Agent도 Runnable 이다.
#     3. Agent는 하나의 표준 팩토리 함수(생성함수)로 통합한다.
#
# ## 주요 파라미터
# - https://reference.langchain.com/python/langchain/agents/
# - `model`: LLM 모델. Agent의 두뇌 역할을 하며 추론(Reasoning), 도구 선택, 최종 응답을 담당한다.
# - `tools`: Agent가 사용할 외부 도구모음.
# - `system_prompt`

# %% [markdown]
# # LangChain에서 MCP 연동
#
# ## MCP란
#
# - **MCP**(**Model Context Protocol**)는 Anthropic이 주도하여 2024년 말에 발표한 개방형 표준으로, LLM 애플리케이션이 외부 데이터 소스나 도구에 접근하는 방식을 표준화 하는 프로토콜이다.
#   - Agent가 이용할 수 있는 tool을 구현하는 방법은 framework 마다 다르기 때문에 서로 호환 되지 않는 문제가 있다.
#   - MCP는 이런 문제를 해결하기 위해 만든 표준 프로토콜이다.
#
# ## MCP 아키텍처 구성 요소
# - **MCP 호스트**
#   -  AI 애플리케이션(예: LLM 채팅 애플리케이션)으로 MCP 클라이언트를 통해 여러 서버에 연결한다.
#
# - **MCP 클라이언트**
#   -  각 MCP 서버와의 연결을 유지하는 구성요소로, 서버로부터 도구/리소스/프롬프트를 가져와 LLM 모델에게 전달한다.
#
# - **MCP 서버**
#   -  외부 데이터 소스나 Tool들을 제공하는 프로그램이다. 서버는 도구, 리소스, 프롬프트를 노출하고 클라이언트와 JSON‑RPC 2.0 메시지로 통신한다.
#   -  MCP는 서버 클라이언트 간의 **로컬 프로세스 간 통신을 위한 STDIO**와 **원격 서버 접속을 위한 Streamable HTTP** 두 가지 전송 방식을 지원한다
#   -  **MCP 서버가 제공하는 것**
#      -  **도구**(**Tools**): LLM이 호출할 수 있는 함수형 작업이다. 예를 들어 “queryDatabase”, “sendEmail” 등이 있으며 각 도구는 이름, 설명, 입력 스키마를 포함한다.
#      -  **리소스**(**Resources**): 읽기 전용 데이터 소스로, 검색 색인·파일시스템·데이터베이스 등에서 컨텍스트를 제공한다.
#      -  **프롬프트**(**Prompts**): LLM 프롬프트 템플릿이나 예시를 서버에서 제공해 AI 모델의 질의를 돕는다.
#
#
# ## 사용 가능한 MCP 툴 찾기
#
# - MCP 생태계에는 수천 개의 툴 서버가 이미 공개되어 있으며, 원하는 기능의 툴을 검색하여 사용할 수 있다.
# - MCP 검색 및 서비스 사이트
#   - [PulseMCP](pulsemcp.com)
#   - [MCP 마켓](https://mcpmarket.com/ko)
#   - [MCP Servers](https://mcp.so/)
#   - [smithery](https://smithery.ai/servers)

# %% [markdown]
# ## LangChain에서 MCP 툴 연동하기
#
# - LangChain에서 MCP 서버와 연동하기 위해서는 Adapter lib 설치가 필요하다.
#   - `pip install langchain-mcp-adapters`
#
# ###  MultiServerMCPClient
# - **MCP 클라이언트 객체**로, LangChain에서 **하나 이상의 MCP 서버를 연결하고 Tool 목록을 가져오기 위해 사용**한다.
#     - 여러 개의 MCP 서버를 **동시에 등록하고 연결**할 수 있다.
#     - 서버 설정들을 **하나의 딕셔너리**(**Dictionary**)로 묶어 전달하며, **각 개별 서버 역시 Dictionary로 설정**한다.
#     - MCP 클라이언트에 등록된 모든 서버는 이후 `get_tools()` 호출을 통해 서버가 제공하는 tool들을 **LangChain의 Tool 객체로 자동 변환해 Agent가 호출**(**사용**)할 수있게 한다.
#
# #### 개별 서버 설정 Key 정의
# - **`dict[str: 서버 별칭, dict: 서버 설정]`**
#
# | 설정 Key        | 의미                                                                  | 사용 예                            |
# | --------------- | --------------------------------------------------------------------- | ---------------------------------- |
# | **`transport`** | 서버와 통신하는 방식                                                  | `"stdio"` 또는 `"streamable-http"` |
# | **`command`**   | MCP 서버를 실행할 프로그램(프로세스)                                  | `"python"` 또는 `"npx"`            |
# | **`args`**      | command에 전달할 세부 실행 인자를 **리스트(List)**에 문자열로 순서대로 배치 | `["-m", "mcp_server_time"]`  |
#
# - **transport 값에 따른 동작 구분**
#     - `"stdio"`: 로컬에서 실행되는 서버 연결
#     - `"streamable-http"`: 원격 MCP 서버(서비스형) 연결
#
#     ```json
#         {
#             "time": {
#                 "transport": "stdio",
#                 "command": "python",
#                 "args": ["-m", "mcp_server_time"]
#             }
#
#             "github": {
#                 "transport": "streamable-http",
#                 "url": "https://server.smithery.ai/github",
#             }
#         }
#     ```
#
# #### command + args 와 실행 명령어 관계
#
# | 실제 실행 명령                    | 설정으로 표현되는 방식                                             |
# | --------------------------- | -------------------------------------------------------- |
# | `python -m mcp_server_time` | `"command": "python", "args": ["-m", "mcp_server_time"]` |
# | `npx -y @org/server`        | `"command": "npx", "args": ["-y", "@org/server"]`        |
#
# * **command는 실행 프로그램**, args는 **명령 뒤에 붙는 옵션을 순서 그대로 리스트에 나열**한다.
